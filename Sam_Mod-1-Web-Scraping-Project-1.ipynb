# %%
import requests
from bs4 import BeautifulSoup 
import json
import time
import mysql.connector 
from mysql.connector import errorcode
import config_project1

# %%
#connecting to mysql
        
cnx = mysql.connector .connect(
    host = config_project1.host,
    user = config_project1.user,
    passwd = config_project1.password,
    database = 'Movies'
)
cursor = cnx.cursor()

# %%
URL = "https://www.imdb.com/chart/moviemeter?sort=ir,desc&mode=simple&page=1"
r = requests.get(URL) 



soup = BeautifulSoup(r.content, 'html.parser')
soup
# soup = BeautifulSoup(r.content, 'html5lib') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
#   <style>
#    body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#   </style>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    Most Popular Movies - IMDb
#   </title>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <link href="https://www.imdb.com/chart/moviemeter" rel="canonical"/>
#   <meta content="http://www.imdb.com/chart/moviemeter" property="og:url">
#    <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadIcons", {wb: 1});
#     }
#    </script>
#    <script>
#     (function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);
#    </script>
#    <link href="https://m.media-amazon.com/images/G/01/imdb/images/safari-favicon-517611381._CB483525257_.svg" mask="" rel="icon" sizes="any"/>
#    <link href="https://m.media-amazon.com/images/G/01/imdb/images/favicon-2165806970._CB470047330_.ico" rel="icon" type="image/ico">
#     <meta content="#000000" name="theme-color">
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB484110913_.ico" rel="shortcut icon" type="image/x-icon"/>
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-4151659188._CB483525313_.png" rel="apple-touch-icon"/>
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-76x76-53536248._CB484146059_.png" rel="apple-touch-icon" sizes="76x76"/>
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-120x120-2442878471._CB483525250_.png" rel="apple-touch-icon" sizes="120x120"/>
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-152x152-1475823641._CB470042035_.png" rel="apple-touch-icon" sizes="152x152"/>
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/imdbsearch-3349468880._CB470047351_.xml" rel="search" title="IMDb" type="application/opensearchdescription+xml">
#       <script>
#        (function(t){ (t.events = t.events || {})["csm_head_post_icon"] = new Date().getTime(); })(IMDbTimer);
#       </script>
#       <script>
#        if (typeof uet == 'function') {
#       uet("be", "LoadIcons", {wb: 1});
#     }
#       </script>
#       <script>
#        if (typeof uex == 'function') {
#       uex("ld", "LoadIcons", {wb: 1});
#     }
#       </script>
#       <title>
#        IMDb Top Movie Meter
#       </title>
#       <meta content="Check out the most popular movies on IMDb" name="description">
#        <meta content="index,follow" name="robots"/>
#        <meta content="Check out the most popular movies on IMDb" itemprop="description"/>
#        <meta content="images/logos/imdb_fb_logo.png" itemprop="image"/>
#        <meta content="IMDb Top Movie Meter" itemprop="name"/>
#        <meta content="chart" property="pageType"/>
#        <meta content="moviemeter" property="subpageType"/>
#        <meta content="QXPHWP85KBNR664430PF" name="requestId"/>
#        <meta content="115109575169727" property="fb:app_id"/>
#        <meta content="website" property="og:type"/>
#        <meta content="Check out the most popular movies on IMDb" property="og:description"/>
#        <meta content="images/logos/imdb_fb_logo.png" property="og:image"/>
#        <meta content="IMDb" property="og:site_name"/>
#        <meta content="IMDb Top Movie Meter" property="og:title"/>
#        <meta content="Check out the most popular movies on IMDb" name="twitter:description"/>
#        <meta content="images/logos/imdb_fb_logo.png" name="twitter:image">
#         <meta content="summary_large_image" name="twitter:card"/>
#         <meta content="@IMDb" name="twitter:site"/>
#         <meta content="IMDb Top Movie Meter" name="twitter:title">
#          <script>
#           if (typeof uet == 'function') {
#       uet("bb", "LoadCSS", {wb: 1});
#     }
#          </script>
#          <script>
#           (function(t){ (t.events = t.events || {})["csm_head_pre_css"] = new Date().getTime(); })(IMDbTimer);
#          </script>
#          <!-- h=ics-c52xl-2-1b-302423e0.us-east-1 -->
#          <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/consumer-2-column-283229671._CB448884874_.css" rel="stylesheet" type="text/css">
#           <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/other-3053529766._CB440616809_.css" rel="stylesheet" type="text/css">
#            <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/seenWidget-1193206528._CB461844790_.css" rel="stylesheet" type="text/css">
#             <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/watchlistButton-197279306._CB482060654_.css" rel="stylesheet" type="text/css"/>
#             <noscript>
#              <link href="https://m.media-amazon.com/images/G/01/imdb/css/wheel/nojs-2827156349._CB470041026_.css" rel="stylesheet" type="text/css"/>
#             </noscript>
#             <script>
#              (function(t){ (t.events = t.events || {})["csm_head_post_css"] = new Date().getTime(); })(IMDbTimer);
#             </script>
#             <script>
#              if (typeof uet == 'function') {
#       uet("be", "LoadCSS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uex == 'function') {
#       uex("ld", "LoadCSS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uet == 'function') {
#       uet("bb", "LoadJS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uet == 'function') {
#       uet("bb", "LoadHeaderJS", {wb: 1});
#     }
#             </script>
#             <script>
#              (function(t){ (t.events = t.events || {})["csm_head_pre_ads"] = new Date().getTime(); })(IMDbTimer);
#             </script>
#             <script type="text/javascript">
#              // ensures js doesn't die if ads service fails.
#             // Note that we need to define the js here, since ad js is being rendered inline after this.
#             (function(f) {
#                 // Fallback javascript, when the ad Service call fails.
#
#                 if((window.csm == null || window.generic == null || window.consoleLog == null)) {
#                     if (window.console && console.log) {
#                         console.log("one or more of window.csm, window.generic or window.consoleLog has been stubbed...");
#                     }
#                 }
#
#                 window.csm = window.csm || { measure:f, record:f, duration:f, listen:f, metrics:{} };
#                 window.generic = window.generic || { monitoring: { start_timing: f, stop_timing: f } };
#                 window.consoleLog = window.consoleLog || f;
#             })(function() {});
#             </script>
#             <script type="text/javascript">
#              if (!window.RadWidget) {
#         window.RadWidget = {
#             registerReactWidgetInstance: function(input) {
#                 window.RadWidget[input.widgetName] = window.RadWidget[input.widgetName] || [];
#                 window.RadWidget[input.widgetName].push({
#                     id: input.instanceId,
#                     props: JSON.stringify(input.model)
#                 })
#             },
#             getReactWidgetInstances: function(widgetName) {
#                 return window.RadWidget[widgetName] || []
#             }
#         };
#     }
#             </script>
#             <script>
#              if ('csm' in window) {
#       csm.measure('csm_head_delivery_finished');
#     }
#             </script>
#             <script>
#              if (typeof uet == 'function') {
#       uet("be", "LoadHeaderJS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uex == 'function') {
#       uex("ld", "LoadHeaderJS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uet == 'function') {
#       uet("be", "LoadJS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uex == 'function') {
#       uex("ld", "LoadJS", {wb: 1});
#     }
#             </script>
#            </link>
#           </link>
#          </link>
#         </meta>
#        </meta>
#       </meta>
#      </link>
#     </meta>
#    </link>
#   </meta>
#  </head>
#  <body class="fixed" id="styleguide-v2">
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb");
#     }
#   </script>
#   <script>
#    if ('csm' in window) {
#       csm.measure('csm_body_delivery_started');
#     }
#   </script>
#   <div id="wrapper">
#    <div class="redesign" id="root">
#     <div class="navbarSprite" id="nb20">
#      <div id="supertab">
#       <!-- no content received for slot: top_ad -->
#      </div>
#      <script>
#       if (typeof uet == 'function') {
#       uet("ns");
#     }
#      </script>
#      <div class="navbarSprite" id="navbar">
#       <noscript>
#        <style>
#         #pagecontent{margin-top:-17px}
#        </style>
#       </noscript>
#       <span id="home_img_holder">
#        <a class="navbarSprite" href="/" id="home_img" title="Home">
#        </a>
#        <span class="alt_logo">
#         <a href="/" title="Home">
#          IMDb
#         </a>
#        </span>
#       </span>
#       <form action="/find" class="nav-searchbar-inner" id="navbar-form" method="get">
#        <div id="nb_search">
#         <noscript>
#          <div id="more_if_no_javascript">
#           <a href="/search/">
#            More
#           </a>
#          </div>
#         </noscript>
#         <button aria-label="Submit Search" class="primary btn" id="navbar-submit-button" type="submit">
#          <div class="magnifyingglass navbarSprite">
#          </div>
#         </button>
#         <input name="ref_" type="hidden" value="nv_sr_fn"/>
#         <input autocomplete="off" id="navbar-query" name="q" placeholder="Find Movies, TV shows, Celebrities and more..." type="text" value=""/>
#         <div class="quicksearch_dropdown_wrapper">
#          <select class="quicksearch_dropdown navbarSprite hidden" id="quicksearch" name="s">
#           <option value="all">
#            All
#           </option>
#           <option value="tt">
#            Titles
#           </option>
#           <option value="ep">
#            TV Episodes
#           </option>
#           <option value="nm">
#            Names
#           </option>
#           <option value="co">
#            Companies
#           </option>
#           <option value="kw">
#            Keywords
#           </option>
#          </select>
#         </div>
#         <div cel_widget_id="SuggestionSearchWidget" class="celwidget" id="navbar-suggestionsearch">
#         </div>
#        </div>
#       </form>
#       <div id="megaMenu">
#        <ul class="main_nav" id="consumer_main_nav">
#         <li class="spacer">
#         </li>
#         <li class="css_nav_item freediveNavMenu" id="navFreediveMenu">
#          <p class="navCategory">
#           <a href="/tv/">
#            Watch Now For Free
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="sub_nav freediveNavMenu__container" id="navMenu0">
#           <h5>
#            <span class="headerText">
#             Featured
#            </span>
#            <span class="seeAll">
#             <a href="/tv/">
#              Browse more titles »
#             </a>
#            </span>
#           </h5>
#           <ul class="freediveNavMenu__list" id="freediveNavMenuList">
#           </ul>
#          </div>
#          <script>
#           if (!('imdb' in window)) { window.imdb = {}; }
#                     window.imdb.freediveTitleData = [
#                              {
#                                 imageUrl: "https://m.media-amazon.com/images/M/MV5BZDAwYTlhMDEtNTg0OS00NDY2LWJjOWItNWY3YTZkM2UxYzUzXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY209_CR4,0,140,209_AL_.jpg",
#                                 link: "https://www.imdb.com/tv/watch/tt0110413",
#                                 title: "Léon: The Professional"
#                              },
#                              {
#                                 imageUrl: "https://m.media-amazon.com/images/M/MV5BM2VlNTE1ZmMtOTAyNS00ODYwLWFmY2MtZWEzOTE2YjE1NDE2XkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX140_AL_.jpg",
#                                 link: "https://www.imdb.com/tv/watch/tt0088930",
#                                 title: "Clue"
#                              },
#                              {
#                                 imageUrl: "https://m.media-amazon.com/images/M/MV5BMzUzNDM2NzM2MV5BMl5BanBnXkFtZTgwNTM3NTg4OTE@._V1_SY209_CR0,0,140,209_AL_.jpg",
#                                 link: "https://www.imdb.com/tv/watch/tt3783958",
#                                 title: "La La Land"
#                              },
#                     ];
#          </script>
#         </li>
#         <li class="spacer">
#         </li>
#         <li class="css_nav_item" id="navTitleMenu">
#          <p class="navCategory">
#           <a href="/movies-in-theaters/">
#            Movies
#           </a>
#           ,
#           <a href="/chart/toptv/">
#            TV
#           </a>
#           <br/>
#           &amp;
#           <a href="/showtimes/">
#            Showtimes
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="sub_nav" id="navMenu1">
#           <div id="titleMenuImage" style="background: url('https://ia.media-imdb.com/images/M/MV5BNTc0NTU3NDg4Ml5BMl5BanBnXkFtZTgwOTM0NzQ5MTE@._UY340_CR80,10,410,315_HC_BR10_.jpg')">
#            <a class="fallback" href="/title/tt2582802/?ref_=nv_mv_dflt_1" title="                            Whiplash
# , #45 on IMDb Top Rated Movies">
#            </a>
#            <div class="overlay">
#             <p>
#              <a href="/title/tt2582802/?ref_=nv_mv_dflt_2" id="titleMenuImageClick">
#               <strong>
#                Whiplash
#               </strong>
#               (2014)
#              </a>
#              <br/>
#              <a href="/chart/top?ref_=nv_mv_dflt_3" id="titleMenuImageSecondaryClick">
#               #
#               <strong>
#                45
#               </strong>
#               on IMDb Top Rated Movies
#              </a>
#              »
#             </p>
#            </div>
#           </div>
#           <div class="subNavListContainer">
#            <h5>
#             MOVIES
#            </h5>
#            <ul>
#             <li>
#              <a href="/movies-in-theaters/">
#               In Theaters
#              </a>
#             </li>
#             <li>
#              <a href="/showtimes/">
#               Showtimes &amp; Tickets
#              </a>
#             </li>
#             <li>
#              <a href="/trailers/">
#               Latest Trailers
#              </a>
#             </li>
#             <li>
#              <a href="/movies-coming-soon/">
#               Coming Soon
#              </a>
#             </li>
#             <li>
#              <a href="/calendar/">
#               Release Calendar
#              </a>
#             </li>
#             <li>
#              <a href="/chart/top">
#               Top Rated Movies
#              </a>
#             </li>
#             <li>
#              <a href="/india/top-rated-indian-movies">
#               Top Rated Indian Movies
#              </a>
#             </li>
#             <li>
#              <a href="/chart/moviemeter">
#               Most Popular Movies
#              </a>
#             </li>
#            </ul>
#            <h5>
#             CHARTS &amp; TRENDS
#            </h5>
#            <ul>
#             <li>
#              <a href="/chart/">
#               Box Office
#              </a>
#             </li>
#             <li>
#              <a href="/search/title?count=100&amp;groups=oscar_best_picture_winners&amp;sort=year,desc">
#               Oscar Winners
#              </a>
#             </li>
#             <li>
#              <a href="/genre/">
#               Most Popular by Genre
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="subNavListContainer">
#            <h5>
#             TV &amp; VIDEO
#            </h5>
#            <ul>
#             <li>
#              <a href="/chart/toptv/">
#               Top Rated TV Shows
#              </a>
#             </li>
#             <li>
#              <a href="/chart/tvmeter">
#               Most Popular TV Shows
#              </a>
#             </li>
#             <li>
#              <a href="/sections/dvd/">
#               DVD &amp; Blu-Ray
#              </a>
#             </li>
#            </ul>
#            <h5>
#             SPECIAL FEATURES
#            </h5>
#            <ul>
#             <li>
#              <a href="/amazon-originals/">
#               Amazon Originals
#              </a>
#             </li>
#             <li>
#              <a href="/streaming/">
#               Streaming Now
#              </a>
#             </li>
#             <li>
#              <a href="/scary-good/">
#               Horror Guide
#              </a>
#             </li>
#             <li>
#              <a href="/imdbpicks/">
#               IMDb Picks
#              </a>
#             </li>
#             <li>
#              <a href="/originals/">
#               IMDb Original Series
#              </a>
#             </li>
#             <li>
#              <a href="/family-entertainment-guide/">
#               Family Movie/TV Guide
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#         <li class="spacer">
#         </li>
#         <li class="css_nav_item" id="navNameMenu">
#          <p class="navCategory">
#           <a href="/search/name?gender=male,female">
#            Celebs
#           </a>
#           ,
#           <a href="/awards-central/">
#            Events
#           </a>
#           <br/>
#           &amp;
#           <a href="/gallery/rg1859820288">
#            Photos
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="sub_nav" id="navMenu2">
#           <div id="nameMenuImage" style="background: url('https://ia.media-imdb.com/images/M/MV5BMjA4MDU4MjIyMl5BMl5BanBnXkFtZTcwOTM2OTE0Nw@@._V1._SX250_CR0,0,250,315_.jpg')">
#            <a class="fallback" href="/name/nm0000098/?ref_=nv_cel_dflt_1" title="Jennifer Aniston, #103 on STARmeter">
#            </a>
#            <div class="overlay">
#             <p>
#              <a href="/name/nm0000098/?ref_=nv_cel_dflt_2" id="nameAdClick">
#               <strong>
#                Jennifer Aniston
#               </strong>
#              </a>
#              »
#              <br/>
#              #
#              <strong>
#               103
#              </strong>
#              on STARmeter
#             </p>
#            </div>
#           </div>
#           <div class="subNavListContainer">
#            <h5>
#             CELEBS
#            </h5>
#            <ul>
#             <li>
#              <a href="/search/name?birth_monthday=10-30&amp;refine=birth_monthday">
#               Born Today
#              </a>
#             </li>
#             <li>
#              <a href="/news/celebrity">
#               Celebrity News
#              </a>
#             </li>
#             <li>
#              <a href="/search/name?gender=male,female">
#               Most Popular Celebs
#              </a>
#             </li>
#            </ul>
#            <h5>
#             PHOTOS
#            </h5>
#            <ul>
#             <li>
#              <a href="/gallery/rg1859820288">
#               Latest Stills
#              </a>
#             </li>
#             <li>
#              <a href="/gallery/rg1624939264">
#               Latest Posters
#              </a>
#             </li>
#             <li>
#              <a href="/gallery/rg1641716480">
#               Photos We Love
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="subNavListContainer">
#            <h5>
#             EVENTS
#            </h5>
#            <ul>
#             <li>
#              <a href="/awards-central/">
#               Awards Central
#              </a>
#             </li>
#             <li>
#              <a href="/festival-central/">
#               Festival Central
#              </a>
#             </li>
#             <li>
#              <a href="/oscars/">
#               Oscars
#              </a>
#             </li>
#             <li>
#              <a href="/golden-globes/">
#               Golden Globes
#              </a>
#             </li>
#             <li>
#              <a href="/sundance/">
#               Sundance
#              </a>
#             </li>
#             <li>
#              <a href="/cannes/">
#               Cannes
#              </a>
#             </li>
#             <li>
#              <a href="/nycc/">
#               New York Comic Con
#              </a>
#             </li>
#             <li>
#              <a href="/comic-con/">
#               San Diego Comic-Con
#              </a>
#             </li>
#             <li>
#              <a href="/emmys/">
#               Emmy Awards
#              </a>
#             </li>
#             <li>
#              <a href="/venice/">
#               Venice Film Festival
#              </a>
#             </li>
#             <li>
#              <a href="/toronto/">
#               Toronto Film Festival
#              </a>
#             </li>
#             <li>
#              <a href="/festival-central/tribeca">
#               Tribeca
#              </a>
#             </li>
#             <li>
#              <a href="/event/all/">
#               All Events
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#         <li class="spacer">
#         </li>
#         <li class="css_nav_item" id="navNewsMenu">
#          <p class="navCategory">
#           <a href="/news/top">
#            News
#           </a>
#           &amp;
#           <br/>
#           <a href="/czone/">
#            Community
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="sub_nav" id="navMenu3">
#           <div id="latestHeadlines">
#            <div class="subNavListContainer">
#             <h5>
#              LATEST HEADLINES
#             </h5>
#             <ul class="ipl-simple-list">
#              <li class="news_item">
#               <a href="/news/ni62669695">
#                Andrew Garfield to Star in Lin-Manuel Miranda’s ‘Tick, Tick… Boom!’
#               </a>
#               <br/>
#               <small>
#                <span>
#                 30 October 2019
#                </span>
#                <span>
#                 |
#                </span>
#                <span>
#                 Variety - Film News
#                </span>
#               </small>
#              </li>
#              <li class="news_item">
#               <a href="/news/ni62668811">
#                ‘Game of Thrones’ Prequel ‘House of the Dragon’ Ordered Straight to Series at HBO
#               </a>
#               <br/>
#               <small>
#                <span>
#                 29 October 2019
#                </span>
#                <span>
#                 |
#                </span>
#                <span>
#                 The Wrap
#                </span>
#               </small>
#              </li>
#              <li class="news_item">
#               <a href="/news/ni62668381">
#                ‘Game of Thrones’ Prequel Pilot Starring Naomi Watts Scrapped by HBO
#               </a>
#               <br/>
#               <small>
#                <span>
#                 29 October 2019
#                </span>
#                <span>
#                 |
#                </span>
#                <span>
#                 The Wrap
#                </span>
#               </small>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="subNavListContainer">
#            <h5>
#             NEWS
#            </h5>
#            <ul>
#             <li>
#              <a href="/news/top">
#               Top News
#              </a>
#             </li>
#             <li>
#              <a href="/news/movie">
#               Movie News
#              </a>
#             </li>
#             <li>
#              <a href="/news/tv">
#               TV News
#              </a>
#             </li>
#             <li>
#              <a href="/news/celebrity">
#               Celebrity News
#              </a>
#             </li>
#             <li>
#              <a href="/news/indie">
#               Indie News
#              </a>
#             </li>
#            </ul>
#            <h5>
#             COMMUNITY
#            </h5>
#            <ul>
#             <li>
#              <a href="/czone/">
#               Contributor Zone
#              </a>
#             </li>
#             <li>
#              <a href="/poll/">
#               Polls
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#         <li class="spacer">
#         </li>
#         <li class="css_nav_item" id="navWatchlistMenu">
#          <p class="navCategory singleLine watchlist">
#           <a href="/list/watchlist">
#            Watchlist
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="sub_nav" id="navMenu4">
#           <h5>
#            YOUR WATCHLIST
#           </h5>
#           <ul id="navWatchlist">
#           </ul>
#           <script>
#            if (!('imdb' in window)) { window.imdb = {}; }
#     window.imdb.watchlistTeaserData = [
#                 {
#                         href : "/list/watchlist",
#                 src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot1_logged_out._CB484021159_.jpg"
#                 },
#                 {
#                     href : "/search/title?count=100&title_type=feature,tv_series",
#                 src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot2_popular._CB484021159_.jpg"
#                 },
#                 {
#                     href : "/chart/top",
#                 src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot3_top250._CB484021159_.jpg"
#                 }
#     ];
#           </script>
#          </div>
#         </li>
#         <li class="spacer">
#         </li>
#        </ul>
#       </div>
#       <div id="nb_extra">
#        <ul class="main_nav" id="nb_extra_nav">
#         <li class="css_nav_item" id="navProMenu">
#          <p class="navCategory">
#           <a href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm">
#            <img alt="IMDbPro Menu" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_logo_nb._CB484021162_.png"/>
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="imdb-pro-ad-shared imdb-pro-ad-redesign sub_nav" id="navMenuPro">
#           <a class="imdb-pro-ad__link" href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm">
#            <div class="imdb-pro-ad__image" id="proAd">
#             <img alt="Go to IMDbPro" height="145" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png" srcset="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png 1x, https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user_2x._CB484021157_.png 2x" width="127"/>
#            </div>
#            <section class="imdb-pro-ad__content">
#             <div class="imdb-pro-ad__title">
#              The essential resource for entertainment professionals
#             </div>
#             <p class="imdb-pro-ad__line">
#              Find industry contacts &amp; talent representation
#             </p>
#             <p class="imdb-pro-ad__line">
#              Access in-development titles not available on IMDb
#             </p>
#             <p class="imdb-pro-ad__line">
#              Get the latest news from leading industry trades
#             </p>
#             <p class="imdb-pro-ad__line">
#              Claim your page and control your brand across IMDb &amp; Amazon
#             </p>
#             <div class="imdb-pro-new__button">
#              <svg height="30px" version="1.1" viewbox="0 0 172 29" width="175px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#               <title>
#                TryIMDbProFree
#               </title>
#               <g fill="none" fill-rule="evenodd" id="tryIMDbProFree" stroke="none" stroke-width="1">
#                <rect fill="#F1C241" height="28" id="tryIMDbProFreeButton" rx="3" stroke="#A88734" width="170" x="1" y="1">
#                </rect>
#                <text id="tryIMDbProFreeText">
#                 <tspan x="33" y="19">
#                  Try IMDbPro Free
#                 </tspan>
#                </text>
#               </g>
#              </svg>
#             </div>
#            </section>
#           </a>
#          </div>
#         </li>
#         <li class="spacer">
#          <span class="ghost">
#           |
#          </span>
#         </li>
#         <li>
#          <a href="https://help.imdb.com/imdb">
#           Help
#          </a>
#         </li>
#         <li class="spacer">
#          <span class="ghost">
#           |
#          </span>
#         </li>
#         <li class="nb-social-links">
#          <a class="nb-social-links__link" href="/offsite/?page-action=fol_fb&amp;token=BCYtnU7uB9PoG8xOQLuf5ghrxtE1efRyo6E2eZ5M953RyuKjf5CTNH1VOGICuItLh-pE9NNrvjy9%0D%0A6vRyHx0MGMrCtER_qIzfjJf0G6Se-EOvNEmS-iz9ZVpM1WU2vtNe83ZtsdV3wwYktAiOI03qQlCY%0D%0AX_QyodSK9-b5BsstN3hv65ASRDMLEbwAZFl2q55nbN10VMAiNExVsTuzzTeI1mboUA%0D%0A" target="_blank" title="Follow IMDb on Facebook">
#           <svg class="ipl-icon ipl-facebook-icon ipl-icon--inherit-color ipl-icon--inline" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path d="M20.896 2H3.104C2.494 2 2 2.494 2 3.104v17.792C2 21.506 2.494 22 3.104 22h9.579v-7.745h-2.607v-3.018h2.607V9.01c0-2.584 1.577-3.99 3.882-3.99 1.104 0 2.052.082 2.329.119v2.7h-1.598c-1.254 0-1.496.595-1.496 1.47v1.927h2.989l-.39 3.018h-2.6V22h5.097c.61 0 1.104-.494 1.104-1.104V3.104C22 2.494 21.506 2 20.896 2">

#         </li>
#        </ul>
#       </div>
#      </div>
#      <script>
#       if (typeof uet == 'function') {
#       uet("ne");
#     }
#      </script>
#      <!-- no content received for slot: navstrip -->
#      <!-- no content received for slot: injected_navstrip -->
#     </div>
#     <script>
#      if (typeof uet == 'function') {
#       uet("cf");
#     }
#     </script>
#     <div id="pagecontent">
#      <div class="pagecontent">
#       <!-- no content received for slot: injected_billboard -->
#      </div>
#      <div class="pagecontent" id="top-slot-wrapper">
#      </div>
#      <div class="pagecontent">
#       <div id="content-2-wide">
#        <div id="main">
#         <script>
#          if (typeof uet == 'function') {
#       uet("af");
#     }
#         </script>
#         <a name="slot_center-1">
#         </a>
#         <div class="article">
#          <script type="text/javascript">
#           if(typeof uet === 'function'){uet('bb','ChartWidget',{wb:1});}
#          </script>
#          <span class="ab_widget">
#           <input data-caller="chtmvm" id="seen-config" type="hidden"/>
#           <div class="seen-collection" data-collectionid="moviemeter">
#            <div class="article">
#             <h3>
#              IMDb Charts
#             </h3>
#             <div class="chart-social-sharing-widget" id="social-sharing-widget">
#             </div>
#             <h1 class="header">
#              Most Popular Movies
#             </h1>
#             <div class="byline">
#              As determined by IMDb Users
#             </div>
#             <hr/>
#             <div class="lister">
#              <div>
#               <div class="nav">
#                <div class="controls float-right lister-activated">
#                 <label class="lister-sort-by-label" for="lister-sort-by-options">
#                  Sort by:
#                 </label>
#                 <select class="lister-sort-by" id="lister-sort-by-options" name="sort">
#                  <option value="rk:ascending">
#                   Ranking
#                  </option>
#                  <option selected="selected" value="ir:descending">
#                   IMDb Rating
#                  </option>
#                  <option value="us:descending">
#                   Release Date
#                  </option>
#                  <option value="nv:descending">
#                   Number of Ratings
#                  </option>
#                  <option value="ur:descending">
#                   Your Rating
#                  </option>
#                 </select>
#                 <span class="global-sprite lister-sort-reverse ascending" data-sort="ir:asc">
#                 </span>
#                </div>
#                <div class="desc">
#                 Showing
#                 <span>
#                  100
#                 </span>
#                 Titles
#                </div>
#               </div>
#              </div>
#              <br class="clear"/>
#              <table class="chart full-width" data-caller-name="chart-moviemeter">
#               <colgroup>
#                <col class="chartTableColumnPoster"/>
#                <col class="chartTableColumnTitle"/>
#                <col class="chartTableColumnIMDbRating"/>
#                <col class="chartTableColumnYourRating"/>
#                <col class="chartTableColumnWatchlistRibbon"/>
#               </colgroup>
#               <thead>
#                <tr>
#                 <th>
#                 </th>
#                 <th>
#                  Rank &amp; Title
#                 </th>
#                 <th>
#                  IMDb Rating
#                 </th>
#                 <th>
#                  Your Rating
#                 </th>
#                 <th>
#                 </th>
#                </tr>
#               </thead>
#               <tbody class="lister-list">
#                <tr>
#                 <td class="posterColumn">
#                  <span data-value="84" name="rk">
#                  </span>
#                  <span data-value="9.3" name="ir">
#                  </span>
#                  <span data-value="7.791552E11" name="us">
#                  </span>
#                  <span data-value="2153486" name="nv">
#                  </span>
#                  <span data-value="-1.6999999999999993" name="ur">
#                  </span>
#                  <a href="/title/tt0111161/">
#                   <img alt="The Shawshank Redemption" height="67" src="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#                  </a>
#                 </td>
#                 <td class="titleColumn">
#                  <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">
#                   The Shawshank Redemption
#                  </a>
#                  <span class="secondaryInfo">
#                   (1994)
#                  </span>
#                  <div class="velocity">
#                   83
#                   <span class="secondaryInfo">
#                    (
#                    <span class="global-sprite titlemeter down">
#                    </span>
#                    28)
#                   </span>
#                  </div>
#                 </td>
#                 <td class="ratingColumn imdbRating">
#                  <strong title="9.3 based on 2,153,486 user ratings">
#                   9.3
#                  </strong>
#                 </td>
#                 <td class="ratingColumn">
#                  <div class="seen-widget seen-widget-tt0111161 pending" data-titleid="tt0111161">
#                   <div class="boundary">
#                    <div class="popover">
#                     <span class="delete">
#                     </span>
#                     <ol>
#                      <li>
#                       1
#                       <li>
#                        2
#                        <li>
#                         3
#                         <li>
#                          4
#                          <li>
#                           5
#                           <li>
#                            6
#                            <li>
#                             7
#                             <li>
#                              8
#                              <li>
#                               9
#                               <li>
#                                10
#                               </li>
#                              </li>
#                             </li>
#                            </li>
#                           </li>
#                          </li>
#                         </li>
#                        </li>
#                       </li>
#                      </li>
#                     </ol>
#                    </div>
#                   </div>
#                   <div class="inline">
#                    <div class="pending">
#                    </div>
#                    <div class="unseeable">
#                     NOT YET RELEASED
#                    </div>
#                    <div class="unseen">
#                    </div>
#                    <div class="rating">
#                    </div>
#                    <div class="seen">
#                     Seen
#                    </div>
#                   </div>
#                  </div>
#                 </td>
#                 <td class="watchlistColumn">
#                  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0111161">
#                  </div>
#                 </td>
#                </tr>
#                <tr>
#                 <td class="posterColumn">
#                  <span data-value="28" name="rk">
#                  </span>
#                  <span data-value="9.0" name="ir">
#                  </span>
#                  <span data-value="1.2159936E12" name="us">
#                  </span>
#                  <span data-value="2126122" name="nv">
#                  </span>
#                  <span data-value="-2.0" name="ur">
#                  </span>
#                  <a href="/title/tt0468569/">
#                   <img alt="The Dark Knight" height="67" src="https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#                  </a>
#                 </td>
#                 <td class="titleColumn">
#                  <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">
#                   The Dark Knight
#                  </a>
#                  <span class="secondaryInfo">
#                   (2008)
#                  </span>
#                  <div class="velocity">
#                   28
#                   <span class="secondaryInfo">
#                    (
#                    <span class="global-sprite titlemeter down">
#                    </span>
#                    15)
#                   </span>
#                  </div>
#                 </td>
#                 <td class="ratingColumn imdbRating">
#                  <strong title="9.0 based on 2,126,122 user ratings">
#                   9.0
#                  </strong>
#                 </td>
#                 <td class="ratingColumn">
#                  <div class="seen-widget seen-widget-tt0468569 pending" data-titleid="tt0468569">
#                   <div class="boundary">
#                    <div class="popover">
#                     <span class="delete">
#                     </span>
#                     <ol>
#                      <li>
#                       1
#                       <li>
#                        2
#                        <li>
#                         3
#                         <li>
#                          4
#                          <li>
#                           5
#                           <li>
#                            6
#                            <li>
#                             7
#                             <li>
#                              8
#                              <li>
#                               9
#                               <li>
#                                10
#                               </li>
#                              </li>
#                             </li>
#                            </li>
#                           </li>
#                          </li>
#                         </li>
#                        </li>
#                       </li>
#                      </li>
#                     </ol>
#                    </div>
#                   </div>
#                   <div class="inline">
#                    <div class="pending">
#                    </div>
#                    <div class="unseeable">
#                     NOT YET RELEASED
#                    </div>
#                    <div class="unseen">
#                    </div>
#                    <div class="rating">
#                    </div>
#                    <div class="seen">
#                     Seen
#                    </div>
#                   </div>
#                  </div>
#                 </td>
#                 <td class="watchlistColumn">
#                  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt
0D%0A">
#           <span class="amazon-affiliate-site-name">
#            Amazon India
#           </span>
#           <br/>
#           <span class="amazon-affiliate-site-desc">
#            Buy Movie and
#            <br/>
#            TV Show DVDs
#           </span>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div>
#          <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-dpr&amp;token=BCYjr0JcM1Qhwv93NNXz9TR__AXq0tvWXq0HJOaLLBCCKmt9ooJOO8CLmZm9aGzByF9-sEo3n5Uw%0D%0A_4WS-DKrVNwSo7kJzW1edlGK1XhNvkra7V1XlZ3Ac9zACcsHri5cNnlEtSUl9wPCSk_MGBHIwSZ5%0D%0AYV078zIYAPJuVxh67bnCJDA%0D%0A">
#           <span class="amazon-affiliate-site-name">
#            DPReview
#           </span>
#           <br/>
#           <span class="amazon-affiliate-site-desc">
#            Digital
#            <br/>
#            Photography
#           </span>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div>
#          <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-aud&amp;token=BCYuUCvq4n9ZOsDdLJMYkD6yqvhUU704sBjh6Njyxq1yRujEA-3f8Wstdr3ozXM_Wwn1jwcgSMtq%0D%0AIFN2ChmNpcrPdsG0hi-O-KZyu6amyTWwzH38DWC92-b-YFIC5xp5kbfMJ7M4xZjDIafADY5TSHgC%0D%0A5-KfVOS5UIIbcxrPtZ_veOY%0D%0A">
#           <span class="amazon-affiliate-site-name">
#            Audible
#           </span>
#           <br/>
#           <span class="amazon-affiliate-site-desc">
#            Download
#            <br/>
#            Audio Books
#           </span>
#          </a>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <script>
#      if (typeof uet == 'function') {
#       uet("be", "desktopFooter", {wb: 1});
#     }
#     </script>
#     <script>
#      if (typeof uex == 'function') {
#       uex("ld", "desktopFooter", {wb: 1});
#     }
#     </script>
#     <script type="text/javascript">
#      try {
#             window.lumierePlayer = window.lumierePlayer || {};
#             window.lumierePlayer.weblab = JSON.parse('{"IMDB_TV_REBRAND_212999":"T1","IMDB_VIDEO_PLAYER_162496":"C","IMDB_RELATED_VIDEOS_196868":"T1","IMDB_VIDEO_SINGLE_PAGE_REDIRECT_241512":"C"}');
#         } catch (error) {
#             if (window.ueLogError) {
#                 window.ueLogError(error, {
#                     logLevel: "WARN",
#                     attribution: "videoplayer",
#                     message: "Failed to parse weblabs for video player."
#                 });
#             }
#         }
#     </script>
#    </div>
#   </div>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadHeaderJS", {wb: 1});
#     }
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/common-991210058._CB436754830_.js" type="text/javascript">
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/pagelayout-3281904452._CB448911442_.js" type="text/javascript">
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/other-1526325458._CB450703648_.js" type="text/javascript">
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/seenWidget-1675519461._CB449143927_.js" type="text/javascript">
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/watchlistButton-1850442102._CB450746566_.js" type="text/javascript">
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/chart-share-widget-1048338655._CB461897629_.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function jQueryOnReady(remaining_count) {
#                 if (window.jQuery && typeof $.fn.watchlistRibbon !== 'undefined') {
#                     jQuery(
#                                         function() {
#                     window.imdb.CS.Chart.InitChart();
#                 }
#
#                     );
#                     jQuery(
#                         function() { $('#content-2-wide').watchlistRibbon('.ribbonize'); }
#                     );
#                 } else if (remaining_count > 0) {
#                     setTimeout(function() { jQueryOnReady(remaining_count-1) }, 100);
#                 }
#             }
#             jQueryOnReady(50);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadFooterJS", {wb: 1});
#     }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#       uex("ld", "LoadFooterJS", {wb: 1});
#     }
#   </script>
#   <div id="servertime" time="153">
#   </div>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be");
#     }
#   </script>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['\n',
#  'html',
#  '\n',
#  <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
#  <style>
#                  body#styleguide-v2 {
#                      background: no-repeat fixed center top #000;
#                  }
#              </style>
#  <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadTitle", {wb: 1});
#      }
#  </script>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
#  <title>Most Popular Movies - IMDb</title>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadTitle", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadTitle", {wb: 1});
#      }
#  </script>
#  <link href="https://www.imdb.com/chart/moviemeter" rel="canonical"/>
#  <meta content="http://www.imdb.com/chart/moviemeter" property="og:url">
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadIcons", {wb: 1});
#      }
#  </script>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);</script>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/safari-favicon-517611381._CB483525257_.svg" mask="" rel="icon" sizes="any"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/favicon-2165806970._CB470047330_.ico" rel="icon" type="image/ico">
#  <meta content="#000000" name="theme-color">
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB484110913_.ico" rel="shortcut icon" type="image/x-icon"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-4151659188._CB483525313_.png" rel="apple-touch-icon"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-76x76-53536248._CB484146059_.png" rel="apple-touch-icon" sizes="76x76"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-120x120-2442878471._CB483525250_.png" rel="apple-touch-icon" sizes="120x120"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-152x152-1475823641._CB470042035_.png" rel="apple-touch-icon" sizes="152x152"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/imdbsearch-3349468880._CB470047351_.xml" rel="search" title="IMDb" type="application/opensearchdescription+xml">
#  <script>(function(t){ (t.events = t.events || {})["csm_head_post_icon"] = new Date().getTime(); })(IMDbTimer);</script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadIcons", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadIcons", {wb: 1});
#      }
#  </script>
#  <title>IMDb Top Movie Meter</title>
#  <meta content="Check out the most popular movies on IMDb" name="description">
#  <meta content="index,follow" name="robots"/>
#  <meta content="Check out the most popular movies on IMDb" itemprop="description"/>
#  <meta content="images/logos/imdb_fb_logo.png" itemprop="image"/>
#  <meta content="IMDb Top Movie Meter" itemprop="name"/>
#  <meta content="chart" property="pageType"/>
#  <meta content="moviemeter" property="subpageType"/>
#  <meta content="QXPHWP85KBNR664430PF" name="requestId"/>
#  <meta content="115109575169727" property="fb:app_id"/>
#  <meta content="website" property="og:type"/>
#  <meta content="Check out the most popular movies on IMDb" property="og:description"/>
#  <meta content="images/logos/imdb_fb_logo.png" property="og:image"/>
#  <meta content="IMDb" property="og:site_name"/>
#  <meta content="IMDb Top Movie Meter" property="og:title"/>
#  <meta content="Check out the most popular movies on IMDb" name="twitter:description"/>
#  <meta content="images/logos/imdb_fb_logo.png" name="twitter:image">
#  <meta content="summary_large_image" name="twitter:card"/>
#  <meta content="@IMDb" name="twitter:site"/>
#  <meta content="IMDb Top Movie Meter" name="twitter:title">
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadCSS", {wb: 1});
#      }
#  </script>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_css"] = new Date().getTime(); })(IMDbTimer);</script>
#  <!-- h=ics-c52xl-2-1b-302423e0.us-east-1 -->
#  <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/consumer-2-column-283229671._CB448884874_.css" rel="stylesheet" type="text/css">
#  <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/other-3053529766._CB440616809_.css" rel="stylesheet" type="text/css">
#  <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/seenWidget-1193206528._CB461844790_.css" rel="stylesheet" type="text/css">
#  <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/watchlistButton-197279306._CB482060654_.css" rel="stylesheet" type="text/css"/>
#  <noscript>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/css/wheel/nojs-2827156349._CB470041026_.css" rel="stylesheet" type="text/css"/>
#  </noscript>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_post_css"] = new Date().getTime(); })(IMDbTimer);</script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadCSS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadCSS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadJS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadHeaderJS", {wb: 1});
#      }
#  </script>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_ads"] = new Date().getTime(); })(IMDbTimer);</script>
#  <script type="text/javascript">
#              // ensures js doesn't die if ads service fails.
#              // Note that we need to define the js here, since ad js is being rendered inline after this.
#              (function(f) {
#                  // Fallback javascript, when the ad Service call fails.
#
#                  if((window.csm == null || window.generic == null || window.consoleLog == null)) {
#                      if (window.console && console.log) {
#                          console.log("one or more of window.csm, window.generic or window.consoleLog has been stubbed...");
#                      }
#                  }
#
#                  window.csm = window.csm || { measure:f, record:f, duration:f, listen:f, metrics:{} };
#                  window.generic = window.generic || { monitoring: { start_timing: f, stop_timing: f } };
#                  window.consoleLog = window.consoleLog || f;
#              })(function() {});
#          </script>
#  <script type="text/javascript">
#      if (!window.RadWidget) {
#          window.RadWidget = {
#              registerReactWidgetInstance: function(input) {
#                  window.RadWidget[input.widgetName] = window.RadWidget[input.widgetName] || [];
#                  window.RadWidget[input.widgetName].push({
#                      id: input.instanceId,
#                      props: JSON.stringify(input.model)
#                  })
#              },
#              getReactWidgetInstances: function(widgetName) {
#                  return window.RadWidget[widgetName] || []
#              }
#          };
#      }
#  </script> <script>
#      if ('csm' in window) {
#        csm.measure('csm_head_delivery_finished');
#      }
#    </script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadHeaderJS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadHeaderJS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadJS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadJS", {wb: 1});
#      }
#  </script>
#  </link></link></link></meta></meta></meta></link></meta></link></meta></head>
#  <body class="fixed" id="styleguide-v2">
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb");
#      }
#  </script>
#  <script>
#      if ('csm' in window) {
#        csm.measure('csm_body_delivery_started');
#      }
#    </script>
#  <div id="wrapper">
#  <div class="redesign" id="root">
#  <div class="navbarSprite" id="nb20">
#  <div id="supertab">
#  <!-- no content received for slot: top_ad -->
#  </div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("ns");
#      }
#  </script>
#  <div class="navbarSprite" id="navbar">
#  <noscript>
#  <style>
#          #pagecontent{margin-top:-17px}
#      </style>
#  </noscript>
#  <span id="home_img_holder">
#  <a class="navbarSprite" href="/" id="home_img" title="Home"></a> <span class="alt_logo">
#  <a href="/" title="Home">IMDb</a>
#  </span>
#  </span>
#  <form action="/find" class="nav-searchbar-inner" id="navbar-form" method="get">
#  <div id="nb_search">
#  <noscript><div id="more_if_no_javascript"><a href="/search/">More</a></div></noscript>
#  <button aria-label="Submit Search" class="primary btn" id="navbar-submit-button" type="submit"><div class="magnifyingglass navbarSprite"></div></button>
#  <input name="ref_" type="hidden" value="nv_sr_fn"/>
#  <input autocomplete="off" id="navbar-query" name="q" placeholder="Find Movies, TV shows, Celebrities and more..." type="text" value=""/>
#  <div class="quicksearch_dropdown_wrapper">
#  <select class="quicksearch_dropdown navbarSprite hidden" id="quicksearch" name="s">
#  <option value="all">All</option>
#  <option value="tt">Titles</option>
#  <option value="ep">TV Episodes</option>
#  <option value="nm">Names</option>
#  <option value="co">Companies</option>
#  <option value="kw">Keywords</option>
#  </select>
#  </div>
#  <div cel_widget_id="SuggestionSearchWidget" class="celwidget" id="navbar-suggestionsearch"></div>
#  </div>
#  </form>
#  <div id="megaMenu">
#  <ul class="main_nav" id="consumer_main_nav">
#  <li class="spacer"></li>
#  <li class="css_nav_item freediveNavMenu" id="navFreediveMenu">
#  <p class="navCategory">
#  <a href="/tv/"> Watch Now For Free
#  </a> </p>
#  <span class="downArrow"></span>
#  <div class="sub_nav freediveNavMenu__container" id="navMenu0">
#  <h5>
#  <span class="headerText">Featured</span>
#  <span class="seeAll">
#  <a href="/tv/">Browse more titles »</a>
#  </span>
#  </h5>
#  <ul class="freediveNavMenu__list" id="freediveNavMenuList"></ul>
#  </div>
#  <script>
#                      if (!('imdb' in window)) { window.imdb = {}; }
#                      window.imdb.freediveTitleData = [
#                               {
#                                  imageUrl: "https://m.media-amazon.com/images/M/MV5BZDAwYTlhMDEtNTg0OS00NDY2LWJjOWItNWY3YTZkM2UxYzUzXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY209_CR4,0,140,209_AL_.jpg",
#                                  link: "https://www.imdb.com/tv/watch/tt0110413",
#                                  title: "Léon: The Professional"
#                               },
#                               {
#                                  imageUrl: "https://m.media-amazon.com/images/M/MV5BM2VlNTE1ZmMtOTAyNS00ODYwLWFmY2MtZWEzOTE2YjE1NDE2XkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX140_AL_.jpg",
#                                  link: "https://www.imdb.com/tv/watch/tt0088930",
#                                  title: "Clue"
#                               },
#                               {
#                                  imageUrl: "https://m.media-amazon.com/images/M/MV5BMzUzNDM2NzM2MV5BMl5BanBnXkFtZTgwNTM3NTg4OTE@._V1_SY209_CR0,0,140,209_AL_.jpg",
#                                  link: "https://www.imdb.com/tv/watch/tt3783958",
#                                  title: "La La Land"
#                               },
#                      ];
#                  </script>
#  </li>
#  <li class="spacer"></li>
#  <li class="css_nav_item" id="navTitleMenu">
#  <p class="navCategory">
#  <a href="/movies-in-theaters/">Movies</a>,
#                  <a href="/chart/toptv/">TV</a><br/>
#                  &amp; <a href="/showtimes/">Showtimes</a></p>
#  <span class="downArrow"></span>
#  <div class="sub_nav" id="navMenu1">
#  <div id="titleMenuImage" style="background: url('https://ia.media-imdb.com/images/M/MV5BNTc0NTU3NDg4Ml5BMl5BanBnXkFtZTgwOTM0NzQ5MTE@._UY340_CR80,10,410,315_HC_BR10_.jpg')">
#  <a class="fallback" href="/title/tt2582802/?ref_=nv_mv_dflt_1" title="                            Whiplash
#  , #45 on IMDb Top Rated Movies">
#  </a>
#  <div class="overlay">
#  <p>
#  <a href="/title/tt2582802/?ref_=nv_mv_dflt_2" id="titleMenuImageClick">
#  <strong>                            Whiplash
#  </strong> (2014)
#                                  </a>
#  <br/>
#  <a href="/chart/top?ref_=nv_mv_dflt_3" id="titleMenuImageSecondaryClick">
#                                      #<strong>45</strong> on IMDb Top Rated Movies
#                                  </a> »
#                              </p>
#  </div>
#  </div>
#  <div class="subNavListContainer">
#  <h5>MOVIES</h5>
#  <ul>
#  <li><a href="/movies-in-theaters/">In Theaters</a></li>
#  <li><a href="/showtimes/">Showtimes &amp; Tickets</a></li>
#  <li><a href="/trailers/">Latest Trailers</a></li>
#  <li><a href="/movies-coming-soon/">Coming Soon</a></li>
#  <li><a href="/calendar/">Release Calendar</a></li>
#  <li><a href="/chart/top">Top Rated Movies</a></li>
#  <li><a href="/india/top-rated-indian-movies">Top Rated Indian Movies</a></li>
#  <li><a href="/chart/moviemeter">Most Popular Movies</a></li>
#  </ul>
#  <h5>CHARTS &amp; TRENDS</h5>
#  <ul>
#  <li><a href="/chart/">Box Office</a></li>
#  <li><a href="/search/title?count=100&amp;groups=oscar_best_picture_winners&amp;sort=year,desc">Oscar Winners</a></li>
#  <li><a href="/genre/">Most Popular by Genre</a></li>
#  </ul>
#  </div>
#  <div class="subNavListContainer">
#  <h5>TV &amp; VIDEO</h5>
#  <ul>
#  <li><a href="/chart/toptv/">Top Rated TV Shows</a></li>
#  <li><a href="/chart/tvmeter">Most Popular TV Shows</a></li>
#  <li><a href="/sections/dvd/">DVD &amp; Blu-Ray</a></li>
#  </ul>
#  <h5>SPECIAL FEATURES</h5>
#  <ul>
#  <li><a href="/amazon-originals/">Amazon Originals</a></li>
#  <li><a href="/streaming/">Streaming Now</a></li>
#  <li><a href="/scary-good/">Horror Guide</a></li>
#  <li><a href="/imdbpicks/">IMDb Picks</a></li>
#  <li><a href="/originals/">IMDb Original Series</a></li>
#  <li><a href="/family-entertainment-guide/">Family Movie/TV Guide</a></li>
#  </ul>
#  </div>
#  </div>
#  </li>
#  <li class="spacer"></li>
#  <li class="css_nav_item" id="navNameMenu">
#  <p class="navCategory">
#  <a href="/search/name?gender=male,female">Celebs</a>,
#                  <a href="/awards-central/">Events</a><br/>
#                  &amp; <a href="/gallery/rg1859820288">Photos</a></p>
#  <span class="downArrow"></span>
#  <div class="sub_nav" id="navMenu2">
#  <div id="nameMenuImage" style="background: url('https://ia.media-imdb.com/images/M/MV5BMjA4MDU4MjIyMl5BMl5BanBnXkFtZTcwOTM2OTE0Nw@@._V1._SX250_CR0,0,250,315_.jpg')">
#  <a class="fallback" href="/name/nm0000098/?ref_=nv_cel_dflt_1" title="Jennifer Aniston, #103 on STARmeter">
#  </a>
#  <div class="overlay">
#  <p>
#  <a href="/name/nm0000098/?ref_=nv_cel_dflt_2" id="nameAdClick">
#  <strong>Jennifer Aniston</strong>
#  </a> »
#                                  <br/>
#                                  #<strong>103</strong> on STARmeter
#                              </p>
#  </div>
#  </div>
#  <div class="subNavListContainer">
#  <h5>CELEBS</h5>
#  <ul>
#  <li><a href="/search/name?birth_monthday=10-30&amp;refine=birth_monthday">Born Today</a></li>
#  <li><a href="/news/celebrity">Celebrity News</a></li>
#  <li><a href="/search/name?gender=male,female">Most Popular Celebs</a></li>
#  </ul>
#  <h5>PHOTOS</h5>
#  <ul>
#  <li><a href="/gallery/rg1859820288">Latest Stills</a></li>
#  <li><a href="/gallery/rg1624939264">Latest Posters</a></li>
#  <li><a href="/gallery/rg1641716480">Photos We Love</a></li>
#  </ul>
#  </div>
#  <div class="subNavListContainer">
#  <h5>EVENTS</h5>
#  <ul>
#  <li><a href="/awards-central/">Awards Central</a></li>
#  <li><a href="/festival-central/">Festival Central</a></li>
#  <li><a href="/oscars/">Oscars</a></li>
#  <li><a href="/golden-globes/">Golden Globes</a></li>
#  <li><a href="/sundance/">Sundance</a></li>
#  <li><a href="/cannes/">Cannes</a></li>
#  <li><a href="/nycc/">New York Comic Con</a></li>
#  <li><a href="/comic-con/">San Diego Comic-Con</a></li>
#  <li><a href="/emmys/">Emmy Awards</a></li>
#  <li><a href="/venice/">Venice Film Festival</a></li>
#  <li><a href="/toronto/">Toronto Film Festival</a></li>
#  <li><a href="/festival-central/tribeca">Tribeca</a></li>
#  <li><a href="/event/all/">All Events</a></li>
#  </ul>
#  </div>
#  </div>
#  </li>
#  <li class="spacer"></li>
#  <li class="css_nav_item" id="navNewsMenu">
#  <p class="navCategory">
#  <a href="/news/top">News</a> &amp;<br/>
#  <a href="/czone/">Community</a>
#  </p>
#  <span class="downArrow"></span>
#  <div class="sub_nav" id="navMenu3">
#  <div id="latestHeadlines">
#  <div class="subNavListContainer">
#  <h5>LATEST HEADLINES</h5>
#  <ul class="ipl-simple-list">
#  <li class="news_item">
#  <a href="/news/ni62669695"> Andrew Garfield to Star in Lin-Manuel Miranda’s ‘Tick, Tick… Boom!’
#  </a><br/>
#  <small>
#  <span>30 October 2019</span>
#  <span>|</span>
#  <span>Variety - Film News</span>
#  </small>
#  </li>
#  <li class="news_item">
#  <a href="/news/ni62668811"> ‘Game of Thrones’ Prequel ‘House of the Dragon’ Ordered Straight to Series at HBO
#  </a><br/>
#  <small>
#  <span>29 October 2019</span>
#  <span>|</span>
#  <span>The Wrap</span>
#  </small>
#  </li>
#  <li class="news_item">
#  <a href="/news/ni62668381"> ‘Game of Thrones’ Prequel Pilot Starring Naomi Watts Scrapped by HBO
#  </a><br/>
#  <small>
#  <span>29 October 2019</span>
#  <span>|</span>
#  <span>The Wrap</span>
#  </small>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <div class="subNavListContainer">
#  <h5>NEWS</h5>
#  <ul>
#  <li><a href="/news/top">Top News</a></li>
#  <li><a href="/news/movie">Movie News</a></li>
#  <li><a href="/news/tv">TV News</a></li>
#  <li><a href="/news/celebrity">Celebrity News</a></li>
#  <li><a href="/news/indie">Indie News</a></li>
#  </ul>
#  <h5>COMMUNITY</h5>
#  <ul>
#  <li><a href="/czone/">Contributor Zone</a></li>
#  <li><a href="/poll/">Polls</a></li>
#  </ul>
#  </div>
#  </div>
#  </li>
#  <li class="spacer"></li>
#  <li class="css_nav_item" id="navWatchlistMenu">
#  <p class="navCategory singleLine watchlist">
#  <a href="/list/watchlist">Watchlist</a>
#  </p>
#  <span class="downArrow"></span>
#  <div class="sub_nav" id="navMenu4">
#  <h5>
#              YOUR WATCHLIST
#      </h5>
#  <ul id="navWatchlist">
#  </ul>
#  <script>
#      if (!('imdb' in window)) { window.imdb = {}; }
#      window.imdb.watchlistTeaserData = [
#                  {
#                          href : "/list/watchlist",
#                  src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot1_logged_out._CB484021159_.jpg"
#                  },
#                  {
#                      href : "/search/title?count=100&title_type=feature,tv_series",
#                  src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot2_popular._CB484021159_.jpg"
#                  },
#                  {
#                      href : "/chart/top",
#                  src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot3_top250._CB484021159_.jpg"
#                  }
#      ];
#      </script>
#  </div>
#  </li>
#  <li class="spacer"></li>
#  </ul>
#  </div>
#  <div id="nb_extra">
#  <ul class="main_nav" id="nb_extra_nav">
#  <li class="css_nav_item" id="navProMenu">
#  <p class="navCategory">
#  <a href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm"> <img alt="IMDbPro Menu" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_logo_nb._CB484021162_.png"/>
#  </a> </p>
#  <span class="downArrow"></span>
#  <div class="imdb-pro-ad-shared imdb-pro-ad-redesign sub_nav" id="navMenuPro">
#  <a class="imdb-pro-ad__link" href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm"> <div class="imdb-pro-ad__image" id="proAd">
#  <img alt="Go to IMDbPro" height="145" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png" srcset="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png 1x, https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user_2x._CB484021157_.png 2x" width="127"/>
#  </div>
#  <section class="imdb-pro-ad__content">
#  <div class="imdb-pro-ad__title">The essential resource for entertainment professionals</div>
#  <p class="imdb-pro-ad__line">Find industry contacts &amp; talent representation</p>
#  <p class="imdb-pro-ad__line">Access in-development titles not available on IMDb</p>
#  <p class="imdb-pro-ad__line">Get the latest news from leading industry trades</p>
#  <p class="imdb-pro-ad__line">Claim your page and control your brand across IMDb &amp; Amazon</p>
#  <div class="imdb-pro-new__button">
#  <svg height="30px" version="1.1" viewbox="0 0 172 29" width="175px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  
#  <a class="nb-social-links__link" href="/offsite/?page-action=fol_yt&amp;token=BCYvQ8LBnAOBEz44V5Ks6PEbNpEBGxIfM5ggyreaBt5GrsJiJi8ZccDT-9qz9wP-O9XGCt4Hm3AG%0D%0AIGi9iH2dJKoE1fmrunznh-CVRCDXgE1ihBezt6QlAtp7dN3Yce5rrYSpPOVDh3qVjXw4IL-MgS9q%0D%0A7qLT8iiyID_oiUJ7JoiNrqDepSWwCSZQ0hgFkuGPwyz9kdjS9r0pd483iK9dPeyyXg%0D%0A" target="_blank" title="Follow IMDb on YouTube"> <svg class="ipl-icon ipl-youtube-icon ipl-icon--inherit-color ipl-icon--inline" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="M9.955 14.955v-5.91L15.182 12l-5.227 2.955zm11.627-7.769a2.505 2.505 0 0 0-1.768-1.768C18.254 5 12 5 12 5s-6.254 0-7.814.418c-.86.23-1.538.908-1.768 1.768C2 8.746 2 12 2 12s0 3.254.418 4.814c.23.86.908 1.538 1.768 1.768C5.746 19 12 19 12 19s6.254 0 7.814-.418a2.505 2.505 0 0 0 1.768-1.768C22 15.254 22 12 22 12s0-3.254-.418-4.814z"></path>
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  </svg>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div id="nb_personal">
#  <ul class="main_nav" id="consumer_user_nav">
#  <li class="css_nav_menu no_arrow" id="navUserMenu">
#  <p class="navCategory singleLine">
#  <a class="signin-button" href="/registration/signin?u=https%3A//www.imdb.com/chart/moviemeter%3Fsort%3Dir,desc%26mode%3Dsimple%26page%3D1" id="imdb-signin-link"> <span class="signin-imdb-text">Sign in</span>
#  </a> </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("ne");
#      }
#  </script>
#  <!-- no content received for slot: navstrip -->
#  <!-- no content received for slot: injected_navstrip -->
#  </div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("cf");
#      }
#  </script>
#  <div id="pagecontent">
#  <div class="pagecontent">
#  <!-- no content received for slot: injected_billboard -->
#  </div>
#  <div class="pagecontent" id="top-slot-wrapper">
#  </div>
#  <div class="pagecontent">
#  <div id="content-2-wide">
#  <div id="main">
#  <script>
#      if (typeof uet == 'function') {
#        uet("af");
#      }
#  </script>
#  <a name="slot_center-1"></a>
#  <div class="article">
#  <script type="text/javascript">if(typeof uet === 'function'){uet('bb','ChartWidget',{wb:1});}</script>
#  <span class="ab_widget">
#  <input data-caller="chtmvm" id="seen-config" type="hidden"/><div class="seen-collection" data-collectionid="moviemeter">
#  <div class="article">
#  <h3>IMDb Charts</h3>
#  <div class="chart-social-sharing-widget" id="social-sharing-widget"></div>
#  <h1 class="header">Most Popular Movies</h1>
#  <div class="byline">As determined by IMDb Users</div>
#  <hr/>
#  <div class="lister">
#  <div>
#  <div class="nav">
#  <div class="controls float-right lister-activated">
#  <label class="lister-sort-by-label" for="lister-sort-by-options">Sort by: </label>
#  <select class="lister-sort-by" id="lister-sort-by-options" name="sort">
#  <option value="rk:ascending">
#            Ranking
#          </option>
#  <option selected="selected" value="ir:descending">
#            IMDb Rating
#          </option>
#  <option value="us:descending">
#            Release Date
#          </option>
#  <option value="nv:descending">
#            Number of Ratings
#          </option>
#  <option value="ur:descending">
#            Your Rating
#          </option>
#  </select>
#  <span class="global-sprite lister-sort-reverse ascending" data-sort="ir:asc">
#  </span>
#  </div>
#  <div class="desc">Showing <span>100</span> Titles</div>
#  </div>
#  </div>
#  <br class="clear"/>
#  <table class="chart full-width" data-caller-name="chart-moviemeter">
#  <colgroup>
#  <col class="chartTableColumnPoster"/>
#  <col class="chartTableColumnTitle"/>
#  <col class="chartTableColumnIMDbRating"/>
#  <col class="chartTableColumnYourRating"/>
#  <col class="chartTableColumnWatchlistRibbon"/>
#  </colgroup>
#  <thead>
#  <tr>
#  <th></th>
#  <th>Rank &amp; Title</th>
#  <th>IMDb Rating</th>
#  <th>Your Rating</th>
#  <th></th>
#  </tr>
#  </thead>
#  <tbody class="lister-list">
#  <tr>
#  <td class="posterColumn">
#  <span data-value="84" name="rk"></span>
#  <span data-value="9.3" name="ir"></span>
#  <span data-value="7.791552E11" name="us"></span>
#  <span data-value="2153486" name="nv"></span>
#  <span data-value="-1.6999999999999993" name="ur"></span>
#  <a href="/title/tt0111161/"> <img alt="The Shawshank Redemption" height="67" src="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
#  <span class="secondaryInfo">(1994)</span>
#  <div class="velocity">83
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  28)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="9.3 based on 2,153,486 user ratings">9.3</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt0111161 pending" data-titleid="tt0111161">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0111161"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="28" name="rk"></span>
#  <span data-value="9.0" name="ir"></span>
#  <span data-value="1.2159936E12" name="us"></span>
#  <span data-value="2126122" name="nv"></span>
#  <span data-value="-2.0" name="ur"></span>
#  <a href="/title/tt0468569/"> <img alt="The Dark Knight" height="67" src="https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
#  <span class="secondaryInfo">(2008)</span>
#  <div class="velocity">28
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  15)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 2,126,122 user ratings">9.0</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt0468569 pending" data-titleid="tt0468569">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0468569"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="1" name="rk"></span>
#  <span data-value="8.8" name="ir"></span>
#  <span data-value="1.5672096E12" name="us"></span>
#  <span data-value="401160" name="nv"></span>
#  <span data-value="-2.1999999999999993" name="ur"></span>
#  <a href="/title/tt7286456/"> <img alt="Joker" height="67" src="https://m.media-amazon.com/images/M/MV5BNGVjNWI4ZGUtNzE0MS00YTJmLWE0ZDctN2ZiYTk2YmI3NTYyXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt7286456/" title="Todd Phillips (dir.), Joaquin Phoenix, Robert De Niro">Joker</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">1
#  (no change)
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.8 based on 401,160 user ratings">8.8</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt7286456 pending" data-titleid="tt7286456">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt7286456"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="13" name="rk"></span>
#  <span data-value="8.6" name="ir"></span>
#  <span data-value="1.5695424E12" name="us"></span>
#  <span data-value="3684" name="nv"></span>
#  <span data-value="-2.4000000000000004" name="ur"></span>
#  <a href="/title/tt1302006/"> <img alt="The Irishman" height="67" src="https://m.media-amazon.com/images/M/MV5BMGUyM2ZiZmUtMWY0OC00NTQ4LThkOGUtNjY2NjkzMDJiMWMwXkEyXkFqcGdeQXVyMzY0MTE3NzU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt1302006/" title="Martin Scorsese (dir.), Jesse Plemons, Robert De Niro">The Irishman</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">13
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  4)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.6 based on 3,684 user ratings">8.6</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt1302006 pending" data-titleid="tt1302006">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1302006"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="15" name="rk"></span>
#  <span data-value="8.5" name="ir"></span>
#  <span data-value="1.5583968E12" name="us"></span>
#  <span data-value="53185" name="nv"></span>
#  <span data-value="-2.5" name="ur"></span>
#  <a href="/title/tt6751668/"> <img alt="Parasite" height="67" src="https://m.media-amazon.com/images/M/MV5BOWVmODY4MjYtZGViYS00MzJjLWI3NmItMGFmMDRkMzI1OTU3XkEyXkFqcGdeQXVyNTQ0NTUxOTA@._V1_UY67_CR2,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt6751668/" title="Bong Joon Ho (dir.), Kang-ho Song, Yeo-jeong Jo">Parasite</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">15
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  6)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.5 based on 53,185 user ratings">8.5</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt6751668 pending" data-titleid="tt6751668">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt6751668"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="36" name="rk"></span>
#  <span data-value="8.5" name="ir"></span>
#  <span data-value="1.5558912E12" name="us"></span>
#  <span data-value="591202" name="nv"></span>
#  <span data-value="-2.5" name="ur"></span>
#  <a href="/title/tt4154796/"> <img alt="Avengers: Endgame" height="67" src="https://m.media-amazon.com/images/M/MV5BMTc5MDE2ODcwNV5BMl5BanBnXkFtZTgwMzI2NzQ2NzM@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt4154796/" title="Anthony Russo (dir.), Robert Downey Jr., Chris Evans">Avengers: Endgame</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">36
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  4)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.5 based on 591,202 user ratings">8.5</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt4154796 pending" data-titleid="tt4154796">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt4154796"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="74" name="rk"></span>
#  <span data-value="8.5" name="ir"></span>
#  <span data-value="6.783264E11" name="us"></span>
#  <span data-value="929988" name="nv"></span>
#  <span data-value="-2.5" name="ur"></span>
#  <a href="/title/tt0103064/"> <img alt="Terminator 2: Judgment Day" height="67" src="https://m.media-amazon.com/images/M/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt0103064/" title="James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton">Terminator 2: Judgment Day</a>
#  <span class="secondaryInfo">(1991)</span>
#  <div class="velocity">73
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  60)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.5 based on 929,988 user ratings">8.5</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt0103064 pending" data-titleid="tt0103064">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0103064"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="86" name="rk"></span>
#  <span data-value="8.5" name="ir"></span>
#  <span data-value="9.571392E11" name="us"></span>
#  <span data-value="1243233" name="nv"></span>
#  <span data-value="-2.5" name="ur"></span>
#  <a href="/title/tt0172495/"> <img alt="Gladiator" height="67" src="https://m.media-amazon.com/images/M/MV5BMDliMmNhNDEtODUyOS00MjNlLTgxODEtN2U3NzIxMGVkZTA1L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt0172495/" title="Ridley Scott (dir.), Russell Crowe, Joaquin Phoenix">Gladiator</a>
#  <span class="secondaryInfo">(2000)</span>
#  <div class="velocity">85
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  16)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.5 based on 1,243,233 user ratings">8.5</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt0172495 pending" data-titleid="tt0172495">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0172495"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="9" name="rk"></span>
#  <span data-value="8.4" name="ir"></span>
#  <span data-value="1.558224E12" name="us"></span>
#  <span data-value="7652" name="nv"></span>
#  <span data-value="-2.5999999999999996" name="ur"></span>
#  <a href="/title/tt7984734/"> <img alt="The Lighthouse" height="67" src="https://m.media-amazon.com/images/M/MV5BZmE0MGJhNmYtOWNjYi00Njc5LWE2YjEtMWMxZTVmODUwMmMxXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt7984734/" title="Robert Eggers (dir.), Willem Dafoe, Robert Pattinson">The Lighthouse</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">9
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  11)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.4 based on 7,652 user ratings">8.4</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt7984734 pending" data-titleid="tt7984734">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt7984734"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="43" name="rk"></span>
#  <span data-value="8.4" name="ir"></span>
#  <span data-value="3.27888E11" name="us"></span>
#  <span data-value="807229" name="nv"></span>
#  <span data-value="-2.5999999999999996" name="ur"></span>
#  <a href="/title/tt0081505/"> <img alt="The Shining" height="67" src="https://m.media-amazon.com/images/M/MV5BZWFlYmY2MGEtZjVkYS00YzU4LTg0YjQtYzY1ZGE3NTA5NGQxXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt0081505/" title="Stanley Kubrick (dir.), Jack Nicholson, Shelley Duvall">The Shining</a>
#  <span class="secondaryInfo">(1980)</span>
#  <div class="velocity">42
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  32)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.4 based on 807,229 user ratings">8.4</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt0081505 pending" data-titleid="tt0081505">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0081505"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="99" name="rk"></span>
#  <span data-value="8.4" name="ir"></span>
#  <span data-value="1.3423968E12" name="us"></span>
#  <span data-value="1417792" name="nv"></span>
#  <span data-value="-2.5999999999999996" name="ur"></span>
#  <a href="/title/tt1345836/"> <img alt="The Dark Knight Rises" height="67" src="https://m.media-amazon.com/images/M/MV5BMTk4ODQzNDY3Ml5BMl5BanBnXkFtZTcwODA0NTM4Nw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt1345836/" title="Christopher Nolan (dir.), Christian Bale, Tom Hardy">The Dark Knight Rises</a>
#  <span class="secondaryInfo">(2012)</span>
#  <div class="velocity">98
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  27)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.4 based on 1,417,792 user ratings">8.4</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt1345836 pending" data-titleid="tt1345836">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>

#  <td>
#  <div>
#  <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-fr&amp;token=BCYqdUTG--CCvgusHg2qCghiG2BKWeilFyeKBKfyNii_1CruqJBzqTMhSsOu1xH_UNhTE6e86SPJ%0D%0AnNRoYpFCegq2RYAZtfn3PNCbPCfrnplmAJCfgbErQCKhKAhfcbJ8xizfrCuIdc_crUThyAUeiQRi%0D%0ASQxb27KDf-vbTpyvGYxf0t054DnACuNflLi2Wfh_Ux-uduHJsneH3eYd4LTdWYgEDNtIkc9oa_64%0D%0AnPWPvi4FcoI%0D%0A">
#  <span class="amazon-affiliate-site-name">Amazon France</span><br/>
#  <span class="amazon-affiliate-site-desc">Buy Movies on<br/>DVD &amp; Blu-ray</span>
#  </a>
#  </div>
#  </td>
#  <td>
#  <div>
#  <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-in&amp;token=BCYqRbMUzFOs_rWAfxw9N42E6huGz0PXdQQk3z5lRbw_BpUdbqk2bIXVDao9tRgHDchSYU-sFZc0%0D%0Awu67gyzwWuhncpHXrqIaQjCExNGejQYFpbm70ibX3Wi67PJdGDZcdCf9EIWkWLnnLBpWL7VhnJVT%0D%0AgmUNXu6UfT7_B-tGX_oQrKk1jarI9m91h4BV2e0Xath_FBK1WtxSgFTLBkNnX0O4LRX5dLAxTOCc%0D%0AiDz2xztaXkEYIlv980lf6tilLTBPH6Cr%0D%0A">
#  <span class="amazon-affiliate-site-name">Amazon India</span><br/>
#  <span class="amazon-affiliate-site-desc">Buy Movie and<br/>TV Show DVDs</span>
#  </a>
#  </div>
#  </td>
#  <td>
#  <div>
#  <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-dpr&amp;token=BCYjr0JcM1Qhwv93NNXz9TR__AXq0tvWXq0HJOaLLBCCKmt9ooJOO8CLmZm9aGzByF9-sEo3n5Uw%0D%0A_4WS-DKrVNwSo7kJzW1edlGK1XhNvkra7V1XlZ3Ac9zACcsHri5cNnlEtSUl9wPCSk_MGBHIwSZ5%0D%0AYV078zIYAPJuVxh67bnCJDA%0D%0A">
#  <span class="amazon-affiliate-site-name">DPReview</span><br/>
#  <span class="amazon-affiliate-site-desc">Digital<br/>Photography</span>
#  </a>
#  </div>
#  </td>
#  <td>
#  <div>
#  <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-aud&amp;token=BCYuUCvq4n9ZOsDdLJMYkD6yqvhUU704sBjh6Njyxq1yRujEA-3f8Wstdr3ozXM_Wwn1jwcgSMtq%0D%0AIFN2ChmNpcrPdsG0hi-O-KZyu6amyTWwzH38DWC92-b-YFIC5xp5kbfMJ7M4xZjDIafADY5TSHgC%0D%0A5-KfVOS5UIIbcxrPtZ_veOY%0D%0A">
#  <span class="amazon-affiliate-site-name">Audible</span><br/>
#  <span class="amazon-affiliate-site-desc">Download<br/>Audio Books</span>
#  </a>
#  </div>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "desktopFooter", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "desktopFooter", {wb: 1});
#      }
#  </script>
#  <script type="text/javascript">
#          try {
#              window.lumierePlayer = window.lumierePlayer || {};
#              window.lumierePlayer.weblab = JSON.parse('{"IMDB_TV_REBRAND_212999":"T1","IMDB_VIDEO_PLAYER_162496":"C","IMDB_RELATED_VIDEOS_196868":"T1","IMDB_VIDEO_SINGLE_PAGE_REDIRECT_241512":"C"}');
#          } catch (error) {
#              if (window.ueLogError) {
#                  window.ueLogError(error, {
#                      logLevel: "WARN",
#                      attribution: "videoplayer",
#                      message: "Failed to parse weblabs for video player."
#                  });
#              }
#          }
#      </script>
#  </div>
#  </div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadHeaderJS", {wb: 1});
#      }
#  </script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/common-991210058._CB436754830_.js" type="text/javascript"></script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/pagelayout-3281904452._CB448911442_.js" type="text/javascript"></script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/other-1526325458._CB450703648_.js" type="text/javascript"></script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/seenWidget-1675519461._CB449143927_.js" type="text/javascript"></script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/watchlistButton-1850442102._CB450746566_.js" type="text/javascript"></script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/chart-share-widget-1048338655._CB461897629_.js" type="text/javascript"></script>
#  <script type="text/javascript">
#              function jQueryOnReady(remaining_count) {
#                  if (window.jQuery && typeof $.fn.watchlistRibbon !== 'undefined') {
#                      jQuery(
#                                          function() {
#                      window.imdb.CS.Chart.InitChart();
#                  }
#
#                      );
#                      jQuery(
#                          function() { $('#content-2-wide').watchlistRibbon('.ribbonize'); }
#                      );
#                  } else if (remaining_count > 0) {
#                      setTimeout(function() { jQueryOnReady(remaining_count-1) }, 100);
#                  }
#              }
#              jQueryOnReady(50);
#              </script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadFooterJS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadFooterJS", {wb: 1});
#      }
#  </script>
#  <div id="servertime" time="153"></div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be");
#      }
#  </script>
#  </body>
#  </html>,
#  '\n']

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.NavigableString,
#  bs4.element.Doctype,
#  bs4.element.NavigableString,
#  bs4.element.Tag,
#  bs4.element.NavigableString]

# %%
html = list(soup.children)[3]

# %%
list(html.children)
# Out:
# ['\n', <head>
#  <meta charset="utf-8"/>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
#  <style>
#                  body#styleguide-v2 {
#                      background: no-repeat fixed center top #000;
#                  }
#              </style>
#  <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadTitle", {wb: 1});
#      }
#  </script>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
#  <title>Most Popular Movies - IMDb</title>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadTitle", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadTitle", {wb: 1});
#      }
#  </script>
#  <link href="https://www.imdb.com/chart/moviemeter" rel="canonical"/>
#  <meta content="http://www.imdb.com/chart/moviemeter" property="og:url">
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadIcons", {wb: 1});
#      }
#  </script>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);</script>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/safari-favicon-517611381._CB483525257_.svg" mask="" rel="icon" sizes="any"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/favicon-2165806970._CB470047330_.ico" rel="icon" type="image/ico">
#  <meta content="#000000" name="theme-color">
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB484110913_.ico" rel="shortcut icon" type="image/x-icon"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-4151659188._CB483525313_.png" rel="apple-touch-icon"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-76x76-53536248._CB484146059_.png" rel="apple-touch-icon" sizes="76x76"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-120x120-2442878471._CB483525250_.png" rel="apple-touch-icon" sizes="120x120"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-152x152-1475823641._CB470042035_.png" rel="apple-touch-icon" sizes="152x152"/>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/images/imdbsearch-3349468880._CB470047351_.xml" rel="search" title="IMDb" type="application/opensearchdescription+xml">
#  <script>(function(t){ (t.events = t.events || {})["csm_head_post_icon"] = new Date().getTime(); })(IMDbTimer);</script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadIcons", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadIcons", {wb: 1});
#      }
#  </script>
#  <title>IMDb Top Movie Meter</title>
#  <meta content="Check out the most popular movies on IMDb" name="description">
#  <meta content="index,follow" name="robots"/>
#  <meta content="Check out the most popular movies on IMDb" itemprop="description"/>
#  <meta content="images/logos/imdb_fb_logo.png" itemprop="image"/>
#  <meta content="IMDb Top Movie Meter" itemprop="name"/>
#  <meta content="chart" property="pageType"/>
#  <meta content="moviemeter" property="subpageType"/>
#  <meta content="QXPHWP85KBNR664430PF" name="requestId"/>
#  <meta content="115109575169727" property="fb:app_id"/>
#  <meta content="website" property="og:type"/>
#  <meta content="Check out the most popular movies on IMDb" property="og:description"/>
#  <meta content="images/logos/imdb_fb_logo.png" property="og:image"/>
#  <meta content="IMDb" property="og:site_name"/>
#  <meta content="IMDb Top Movie Meter" property="og:title"/>
#  <meta content="Check out the most popular movies on IMDb" name="twitter:description"/>
#  <meta content="images/logos/imdb_fb_logo.png" name="twitter:image">
#  <meta content="summary_large_image" name="twitter:card"/>
#  <meta content="@IMDb" name="twitter:site"/>
#  <meta content="IMDb Top Movie Meter" name="twitter:title">
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadCSS", {wb: 1});
#      }
#  </script>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_css"] = new Date().getTime(); })(IMDbTimer);</script>
#  <!-- h=ics-c52xl-2-1b-302423e0.us-east-1 -->
#  <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/consumer-2-column-283229671._CB448884874_.css" rel="stylesheet" type="text/css">
#  <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/other-3053529766._CB440616809_.css" rel="stylesheet" type="text/css">
#  <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/seenWidget-1193206528._CB461844790_.css" rel="stylesheet" type="text/css">
#  <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/watchlistButton-197279306._CB482060654_.css" rel="stylesheet" type="text/css"/>
#  <noscript>
#  <link href="https://m.media-amazon.com/images/G/01/imdb/css/wheel/nojs-2827156349._CB470041026_.css" rel="stylesheet" type="text/css"/>
#  </noscript>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_post_css"] = new Date().getTime(); })(IMDbTimer);</script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadCSS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadCSS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadJS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadHeaderJS", {wb: 1});
#      }
#  </script>
#  <script>(function(t){ (t.events = t.events || {})["csm_head_pre_ads"] = new Date().getTime(); })(IMDbTimer);</script>
#  <script type="text/javascript">
#              // ensures js doesn't die if ads service fails.
#              // Note that we need to define the js here, since ad js is being rendered inline after this.
#              (function(f) {
#                  // Fallback javascript, when the ad Service call fails.
#
#                  if((window.csm == null || window.generic == null || window.consoleLog == null)) {
#                      if (window.console && console.log) {
#                          console.log("one or more of window.csm, window.generic or window.consoleLog has been stubbed...");
#                      }
#                  }
#
#                  window.csm = window.csm || { measure:f, record:f, duration:f, listen:f, metrics:{} };
#                  window.generic = window.generic || { monitoring: { start_timing: f, stop_timing: f } };
#                  window.consoleLog = window.consoleLog || f;
#              })(function() {});
#          </script>
#  <script type="text/javascript">
#      if (!window.RadWidget) {
#          window.RadWidget = {
#              registerReactWidgetInstance: function(input) {
#                  window.RadWidget[input.widgetName] = window.RadWidget[input.widgetName] || [];
#                  window.RadWidget[input.widgetName].push({
#                      id: input.instanceId,
#                      props: JSON.stringify(input.model)
#                  })
#              },
#              getReactWidgetInstances: function(widgetName) {
#                  return window.RadWidget[widgetName] || []
#              }
#          };
#      }
#  </script> <script>
#      if ('csm' in window) {
#        csm.measure('csm_head_delivery_finished');
#      }
#    </script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadHeaderJS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadHeaderJS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadJS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadJS", {wb: 1});
#      }
#  </script>
#  </link></link></link></meta></meta></meta></link></meta></link></meta></head>, '\n', <body class="fixed" id="styleguide-v2">
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb");
#      }
#  </script>
#  <script>
#      if ('csm' in window) {
#        csm.measure('csm_body_delivery_started');
#      }
#    </script>
#  <div id="wrapper">
#  <div class="redesign" id="root">
#  <div class="navbarSprite" id="nb20">
#  <div id="supertab">
#  <!-- no content received for slot: top_ad -->
#  </div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("ns");
#      }
#  </script>
#  <div class="navbarSprite" id="navbar">
#  <noscript>
#  <style>
#          #pagecontent{margin-top:-17px}
#      </style>
#  </noscript>
#  <span id="home_img_holder">
#  <a class="navbarSprite" href="/" id="home_img" title="Home"></a> <span class="alt_logo">
#  <a href="/" title="Home">IMDb</a>
#  </span>
#  </span>
#  <form action="/find" class="nav-searchbar-inner" id="navbar-form" method="get">
#  <div id="nb_search">
#  <noscript><div id="more_if_no_javascript"><a href="/search/">More</a></div></noscript>
#  <button aria-label="Submit Search" class="primary btn" id="navbar-submit-button" type="submit"><div class="magnifyingglass navbarSprite"></div></button>
#  <input name="ref_" type="hidden" value="nv_sr_fn"/>
#  <input autocomplete="off" id="navbar-query" name="q" placeholder="Find Movies, TV shows, Celebrities and more..." type="text" value=""/>
#  <div class="quicksearch_dropdown_wrapper">
#  <select class="quicksearch_dropdown navbarSprite hidden" id="quicksearch" name="s">
#  <option value="all">All</option>
#  <option value="tt">Titles</option>
#  <option value="ep">TV Episodes</option>
#  <option value="nm">Names</option>
#  <option value="co">Companies</option>
#  <option value="kw">Keywords</option>
#  </select>
#  </div>
#  <div cel_widget_id="SuggestionSearchWidget" class="celwidget" id="navbar-suggestionsearch"></div>
#  </div>
#  </form>
#  <div id="megaMenu">
#  <ul class="main_nav" id="consumer_main_nav">
#  <li class="spacer"></li>
#  <li class="css_nav_item freediveNavMenu" id="navFreediveMenu">
#  <p class="navCategory">
#  <a href="/tv/"> Watch Now For Free
#  </a> </p>
#  <span class="downArrow"></span>
#  <div class="sub_nav freediveNavMenu__container" id="navMenu0">
#  <h5>
#  <span class="headerText">Featured</span>
#  <span class="seeAll">
#  <a href="/tv/">Browse more titles »</a>
#  </span>
#  </h5>
#  <ul class="freediveNavMenu__list" id="freediveNavMenuList"></ul>
#  </div>
#  <script>
#                      if (!('imdb' in window)) { window.imdb = {}; }
#                      window.imdb.freediveTitleData = [
#                               {
#                                  imageUrl: "https://m.media-amazon.com/images/M/MV5BZDAwYTlhMDEtNTg0OS00NDY2LWJjOWItNWY3YTZkM2UxYzUzXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY209_CR4,0,140,209_AL_.jpg",
#                                  link: "https://www.imdb.com/tv/watch/tt0110413",
#                                  title: "Léon: The Professional"
#                               },
#                               {
#                                  imageUrl: "https://m.media-amazon.com/images/M/MV5BM2VlNTE1ZmMtOTAyNS00ODYwLWFmY2MtZWEzOTE2YjE1NDE2XkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX140_AL_.jpg",
#                                  link: "https://www.imdb.com/tv/watch/tt0088930",
#                                  title: "Clue"
#                               },
#                               {
#                                  imageUrl: "https://m.media-amazon.com/images/M/MV5BMzUzNDM2NzM2MV5BMl5BanBnXkFtZTgwNTM3NTg4OTE@._V1_SY209_CR0,0,140,209_AL_.jpg",
#                                  link: "https://www.imdb.com/tv/watch/tt3783958",
#                                  title: "La La Land"
#                               },
#                      ];
#                  </script>
#  </li>
#  <li class="spacer"></li>
#  <li class="css_nav_item" id="navTitleMenu">
#  <p class="navCategory">
#  <a href="/movies-in-theaters/">Movies</a>,
#                  <a href="/chart/toptv/">TV</a><br/>
#                  &amp; <a href="/showtimes/">Showtimes</a></p>
#  <span class="downArrow"></span>
#  <div class="sub_nav" id="navMenu1">
#  <div id="titleMenuImage" style="background: url('https://ia.media-imdb.com/images/M/MV5BNTc0NTU3NDg4Ml5BMl5BanBnXkFtZTgwOTM0NzQ5MTE@._UY340_CR80,10,410,315_HC_BR10_.jpg')">
#  <a class="fallback" href="/title/tt2582802/?ref_=nv_mv_dflt_1" title="                            Whiplash
#  , #45 on IMDb Top Rated Movies">
#  </a>
#  <div class="overlay">
#  <p>
#  <a href="/title/tt2582802/?ref_=nv_mv_dflt_2" id="titleMenuImageClick">
#  <strong>                            Whiplash
#  </strong> (2014)
#                                  </a>
#  <br/>
#  <a href="/chart/top?ref_=nv_mv_dflt_3" id="titleMenuImageSecondaryClick">
#                                      #<strong>45</strong> on IMDb Top Rated Movies
#                                  </a> »
#                              </p>
#  </div>
#  </div>
#  <div class="subNavListContainer">
#  <h5>MOVIES</h5>
#  <ul>
#  <li><a href="/movies-in-theaters/">In Theaters</a></li>
#  <li><a href="/showtimes/">Showtimes &amp; Tickets</a></li>
#  <li><a href="/trailers/">Latest Trailers</a></li>
#  <li><a href="/movies-coming-soon/">Coming Soon</a></li>
#  <li><a href="/calendar/">Release Calendar</a></li>
#  <li><a href="/chart/top">Top Rated Movies</a></li>
#  <li><a href="/india/top-rated-indian-movies">Top Rated Indian Movies</a></li>
#  <li><a href="/chart/moviemeter">Most Popular Movies</a></li>
#  </ul>
#  <h5>CHARTS &amp; TRENDS</h5>
#  <ul>
#  <li><a href="/chart/">Box Office</a></li>
#  <li><a href="/search/title?count=100&amp;groups=oscar_best_picture_winners&amp;sort=year,desc">Oscar Winners</a></li>
#  <li><a href="/genre/">Most Popular by Genre</a></li>
#  </ul>
#  </div>
#  <div class="subNavListContainer">
#  <h5>TV &amp; VIDEO</h5>
#  <ul>
#  <li><a href="/chart/toptv/">Top Rated TV Shows</a></li>
#  <li><a href="/chart/tvmeter">Most Popular TV Shows</a></li>
#  <li><a href="/sections/dvd/">DVD &amp; Blu-Ray</a></li>
#  </ul>
#  <h5>SPECIAL FEATURES</h5>
#  <ul>
#  <li><a href="/amazon-originals/">Amazon Originals</a></li>
#  <li><a href="/streaming/">Streaming Now</a></li>
#  <li><a href="/scary-good/">Horror Guide</a></li>
#  <li><a href="/imdbpicks/">IMDb Picks</a></li>
#  <li><a href="/originals/">IMDb Original Series</a></li>
#  <li><a href="/family-entertainment-guide/">Family Movie/TV Guide</a></li>
#  </ul>
#  </div>
#  </div>
#  </li>
#  <li class="spacer"></li>
#  <li class="css_nav_item" id="navNameMenu">
#  <p class="navCategory">
#  <a href="/search/name?gender=male,female">Celebs</a>,
#                  <a href="/awards-central/">Events</a><br/>
#                  &amp; <a href="/gallery/rg1859820288">Photos</a></p>
#  <span class="downArrow"></span>
#  <div class="sub_nav" id="navMenu2">
#  <div id="nameMenuImage" style="background: url('https://ia.media-imdb.com/images/M/MV5BMjA4MDU4MjIyMl5BMl5BanBnXkFtZTcwOTM2OTE0Nw@@._V1._SX250_CR0,0,250,315_.jpg')">
#  <a class="fallback" href="/name/nm0000098/?ref_=nv_cel_dflt_1" title="Jennifer Aniston, #103 on STARmeter">
#  </a>
#  <div class="overlay">
#  <p>
#  <a href="/name/nm0000098/?ref_=nv_cel_dflt_2" id="nameAdClick">
#  <strong>Jennifer Aniston</strong>
#  </a> »
#                                  <br/>
#                                  #<strong>103</strong> on STARmeter
#  </ul>
#  </div>
#  </div>
#  </li>
#  <li class="spacer"></li>
#  <li class="css_nav_item" id="navWatchlistMenu">
#  <p class="navCategory singleLine watchlist">
#  <a href="/list/watchlist">Watchlist</a>
#  </p>
#  <span class="downArrow"></span>
#  <div class="sub_nav" id="navMenu4">
#  <h5>
#              YOUR WATCHLIST
#      </h5>
#  <ul id="navWatchlist">
#  </ul>
#  <script>
#      if (!('imdb' in window)) { window.imdb = {}; }
#      window.imdb.watchlistTeaserData = [
#                  {
#                          href : "/list/watchlist",
#                  src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot1_logged_out._CB484021159_.jpg"
#                  },
#                  {
#                      href : "/search/title?count=100&title_type=feature,tv_series",
#                  src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot2_popular._CB484021159_.jpg"
#                  },
#                  {
#                      href : "/chart/top",
#                  src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot3_top250._CB484021159_.jpg"
#                  }
#      ];
#      </script>
#  </div>
#  </li>
#  <li class="spacer"></li>
#  </ul>
#  </div>
#  <div id="nb_extra">
#  <ul class="main_nav" id="nb_extra_nav">
#  <li class="css_nav_item" id="navProMenu">
#  <p class="navCategory">
#  <a href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm"> <img alt="IMDbPro Menu" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_logo_nb._CB484021162_.png"/>
#  </a> </p>
#  <span class="downArrow"></span>
#  <div class="imdb-pro-ad-shared imdb-pro-ad-redesign sub_nav" id="navMenuPro">
#  <a class="imdb-pro-ad__link" href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm"> <div class="imdb-pro-ad__image" id="proAd">
#  <img alt="Go to IMDbPro" height="145" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png" srcset="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png 1x, https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user_2x._CB484021157_.png 2x" width="127"/>
#  </div>
#  <section class="imdb-pro-ad__content">
#  <div class="imdb-pro-ad__title">The essential resource for entertainment professionals</div>
#  <p class="imdb-pro-ad__line">Find industry contacts &amp; talent representation</p>
#  <p class="imdb-pro-ad__line">Access in-development titles not available on IMDb</p>
#  <p class="imdb-pro-ad__line">Get the latest news from leading industry trades</p>
#  <p class="imdb-pro-ad__line">Claim your page and control your brand across IMDb &amp; Amazon</p>
#  <div class="imdb-pro-new__button">
#  <svg height="30px" version="1.1" viewbox="0 0 172 29" width="175px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <title>TryIMDbProFree</title>
#  <g fill="none" fill-rule="evenodd" id="tryIMDbProFree" stroke="none" stroke-width="1">
#  <rect fill="#F1C241" height="28" id="tryIMDbProFreeButton" rx="3" stroke="#A88734" width="170" x="1" y="1"></rect>
#  <text id="tryIMDbProFreeText">
#  <tspan x="33" y="19">Try IMDbPro Free</tspan>
#  </text>
#  </g>
#  </svg>
#  </div>
#  </section>
#  </a></div>
#  </li>
#  <li class="spacer"><span class="ghost">|</span></li>
#  <li>
#  <a href="https://help.imdb.com/imdb">Help</a>
#  </li>
#  <li class="spacer"><span class="ghost">|</span></li>
#  <li class="nb-social-links">
#  <a class="nb-social-links__link" href="/offsite/?page-action=fol_fb&amp;token=BCYtnU7uB9PoG8xOQLuf5ghrxtE1efRyo6E2eZ5M953RyuKjf5CTNH1VOGICuItLh-pE9NNrvjy9%0D%0A6vRyHx0MGMrCtER_qIzfjJf0G6Se-EOvNEmS-iz9ZVpM1WU2vtNe83ZtsdV3wwYktAiOI03qQlCY%0D%0AX_QyodSK9-b5BsstN3hv65ASRDMLEbwAZFl2q55nbN10VMAiNExVsTuzzTeI1mboUA%0D%0A" target="_blank" title="Follow IMDb on Facebook"> <svg class="ipl-icon ipl-facebook-icon ipl-icon--inherit-color ipl-icon--inline" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path d="
#  <path d="M0 0h24v24H0z" fill="none"></path>
#  </svg>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <div id="nb_personal">
#  <ul class="main_nav" id="consumer_user_nav">
#  <li class="css_nav_menu no_arrow" id="navUserMenu">
#  <p class="navCategory singleLine">
#  <a class="signin-button" href="/registration/signin?u=https%3A//www.imdb.com/chart/moviemeter%3Fsort%3Dir,desc%26mode%3Dsimple%26page%3D1" id="imdb-signin-link"> <span class="signin-imdb-text">Sign in</span>
#  </a> </p>
#  </li>
#  </ul>
#  </div>
#  </div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("ne");
#      }
#  </script>
#  <!-- no content received for slot: navstrip -->
#  <!-- no content received for slot: injected_navstrip -->
#  </div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("cf");
#      }
#  </script>
#  <div id="pagecontent">
#  <div class="pagecontent">
#  <!-- no content received for slot: injected_billboard -->
#  </div>
#  <div class="pagecontent" id="top-slot-wrapper">
#  </div>
#  <div class="pagecontent">
#  <div id="content-2-wide">
#  <div id="main">
#  <script>
#      if (typeof uet == 'function') {
#        uet("af");
#      }
#  </script>
#  <a name="slot_center-1"></a>
#  <div class="article">
#  <script type="text/javascript">if(typeof uet === 'function'){uet('bb','ChartWidget',{wb:1});}</script>
#  <span class="ab_widget">
#  <input data-caller="chtmvm" id="seen-config" type="hidden"/><div class="seen-collection" data-collectionid="moviemeter">
#  <div class="article">
#  <h3>IMDb Charts</h3>
#  <div class="chart-social-sharing-widget" id="social-sharing-widget"></div>
#  <h1 class="header">Most Popular Movies</h1>
#  <div class="byline">As determined by IMDb Users</div>
#  <hr/>
#  <div class="lister">
#  <div>
#  <div class="nav">
#  <div class="controls float-right lister-activated">
#  <label class="lister-sort-by-label" for="lister-sort-by-options">Sort by: </label>
#  <select class="lister-sort-by" id="lister-sort-by-options" name="sort">
#  <option value="rk:ascending">
#            Ranking
#          </option>
#  <option selected="selected" value="ir:descending">
#            IMDb Rating
#          </option>
#  <option value="us:descending">
#            Release Date
#          </option>
#  <option value="nv:descending">
#            Number of Ratings
#          </option>
#  <option value="ur:descending">
#            Your Rating
#          </option>
#  </select>
#  <span class="global-sprite lister-sort-reverse ascending" data-sort="ir:asc">
#  </span>
#  </div>
#  <div class="desc">Showing <span>100</span> Titles</div>
#  </div>
#  </div>
#  <br class="clear"/>
#  <table class="chart full-width" data-caller-name="chart-moviemeter">
#  <colgroup>
#  <col class="chartTableColumnPoster"/>
#  <col class="chartTableColumnTitle"/>
#  <col class="chartTableColumnIMDbRating"/>
#  <col class="chartTableColumnYourRating"/>
#  <col class="chartTableColumnWatchlistRibbon"/>
#  </colgroup>
#  <thead>
#  <tr>
#  <th></th>
#  <th>Rank &amp; Title</th>
#  <th>IMDb Rating</th>
#  <th>Your Rating</th>
#  <th></th>
#  </tr>
#  </thead>
#  <tbody class="lister-list">
#  <tr>
#  <td class="posterColumn">
#  <span data-value="84" name="rk"></span>
#  <span data-value="9.3" name="ir"></span>
#  <span data-value="7.791552E11" name="us"></span>
#  <span data-value="2153486" name="nv"></span>
#  <span data-value="-1.6999999999999993" name="ur"></span>
#  <a href="/title/tt0111161/"> <img alt="The Shawshank Redemption" height="67" src="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
#  <span class="secondaryInfo">(1994)</span>
#  <div class="velocity">83
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  28)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="9.3 based on 2,153,486 user ratings">9.3</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt0111161 pending" data-titleid="tt0111161">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0111161"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="28" name="rk"></span>
#  <span data-value="9.0" name="ir"></span>
#  <span data-value="1.2159936E12" name="us"></span>
#  <span data-value="2126122" name="nv"></span>
#  <span data-value="-2.0" name="ur"></span>
#  <a href="/title/tt0468569/"> <img alt="The Dark Knight" height="67" src="https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
#  <span class="secondaryInfo">(2008)</span>
#  <div class="velocity">28
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  15)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 2,126,122 user ratings">9.0</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt0468569 pending" data-titleid="tt0468569">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0468569"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="1" name="rk"></span>
#  <span data-value="8.8" name="ir"></span>
#  <span data-value="1.5672096E12" name="us"></span>
#  <span data-value="401160" name="nv"></span>
#  <span data-value="-2.1999999999999993" name="ur"></span>
#  <a href="/title/tt7286456/"> <img alt="Joker" height="67" src="https://m.media-amazon.com/images/M/MV5BNGVjNWI4ZGUtNzE0MS00YTJmLWE0ZDctN2ZiYTk2YmI3NTYyXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt7286456/" title="Todd Phillips (dir.), Joaquin Phoenix, Robert De Niro">Joker</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">1
#  (no change)
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.8 based on 401,160 user ratings">8.8</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt7286456 pending" data-titleid="tt7286456">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt7286456"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="13" name="rk"></span>
#  <span data-value="8.6" name="ir"></span>
#  <span data-value="1.5695424E12" name="us"></span>
#  <span data-value="3684" name="nv"></span>
#  <span data-value="-2.4000000000000004" name="ur"></span>
#  <a href="/title/tt1302006/"> <img alt="The Irishman" height="67" src="https://m.media-amazon.com/images/M/MV5BMGUyM2ZiZmUtMWY0OC00NTQ4LThkOGUtNjY2NjkzMDJiMWMwXkEyXkFqcGdeQXVyMzY0MTE3NzU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt1302006/" title="Martin Scorsese (dir.), Jesse Plemons, Robert De Niro">The Irishman</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">13
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  4)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.6 based on 3,684 user ratings">8.6</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt1302006 pending" data-titleid="tt1302006">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1302006"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="15" name="rk"></span>
#  <span data-value="8.5" name="ir"></span>
#  <span data-value="1.5583968E12" name="us"></span>
#  <span data-value="53185" name="nv"></span>
#  <span data-value="-2.5" name="ur"></span>
#  <a href="/title/tt6751668/"> <img alt="Parasite" height="67" src="https://m.media-amazon.com/images/M/MV5BOWVmODY4MjYtZGViYS00MzJjLWI3NmItMGFmMDRkMzI1OTU3XkEyXkFqcGdeQXVyNTQ0NTUxOTA@._V1_UY67_CR2,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt6751668/" title="Bong Joon Ho (dir.), Kang-ho Song, Yeo-jeong Jo">Parasite</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">15
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  6)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.5 based on 53,185 user ratings">8.5</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt6751668 pending" data-titleid="tt6751668">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt6751668"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="36" name="rk"></span>
#  <span data-value="8.5" name="ir"></span>
#  <span data-value="1.5558912E12" name="us"></span>
#  <span data-value="591202" name="nv"></span>
#  <span data-value="-2.5" name="ur"></span>
#  <a href="/title/tt4154796/"> <img alt="Avengers: Endgame" height="67" src="https://m.media-amazon.com/images/M/MV5BMTc5MDE2ODcwNV5BMl5BanBnXkFtZTgwMzI2NzQ2NzM@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt4154796/" title="Anthony Russo (dir.), Robert Downey Jr., Chris Evans">Avengers: Endgame</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">36
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  4)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.5 based on 591,202 user ratings">8.5</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt4154796 pending" data-titleid="tt4154796">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt4154796"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="74" name="rk"></span>
#  <span data-value="8.5" name="ir"></span>
#  <span data-value="6.783264E11" name="us"></span>
#  <span data-value="929988" name="nv"></span>
#  <span data-value="-2.5" name="ur"></span>
#  <a href="/title/tt0103064/"> <img alt="Terminator 2: Judgment Day" height="67" src="https://m.media-amazon.com/images/M/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt0103064/" title="James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton">Terminator 2: Judgment Day</a>
#  <span class="secondaryInfo">(1991)</span>
#  <div class="velocity">73
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  60)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.5 based on 929,988 user ratings">8.5</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt0103064 pending" data-titleid="tt0103064">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0103064"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="86" name="rk"></span>
#  <span data-value="8.5" name="ir"></span>
#  <span data-value="9.571392E11" name="us"></span>
#  <span data-value="1243233" name="nv"></span>
#  <span data-value="-2.5" name="ur"></span>
#  <a href="/title/tt0172495/"> <img alt="Gladiator" height="67" src="https://m.media-amazon.com/images/M/MV5BMDliMmNhNDEtODUyOS00MjNlLTgxODEtN2U3NzIxMGVkZTA1L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt0172495/" title="Ridley Scott (dir.), Russell Crowe, Joaquin Phoenix">Gladiator</a>
#  <span class="secondaryInfo">(2000)</span>
#  <div class="velocity">85
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  16)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.5 based on 1,243,233 user ratings">8.5</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt0172495 pending" data-titleid="tt0172495">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0172495"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="9" name="rk"></span>
#  <span data-value="8.4" name="ir"></span>
#  <span data-value="1.558224E12" name="us"></span>
#  <span data-value="7652" name="nv"></span>
#  <span data-value="-2.5999999999999996" name="ur"></span>
#  <a href="/title/tt7984734/"> <img alt="The Lighthouse" height="67" src="https://m.media-amazon.com/images/M/MV5BZmE0MGJhNmYtOWNjYi00Njc5LWE2YjEtMWMxZTVmODUwMmMxXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt7984734/" title="Robert Eggers (dir.), Willem Dafoe, Robert Pattinson">The Lighthouse</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">9
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  11)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.4 based on 7,652 user ratings">8.4</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt7984734 pending" data-titleid="tt7984734">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt7984734"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="43" name="rk"></span>
#  <span data-value="8.4" name="ir"></span>
#  <span data-value="3.27888E11" name="us"></span>
#  <span data-value="807229" name="nv"></span>
#  <span data-value="-2.5999999999999996" name="ur"></span>
#  <a href="/title/tt0081505/"> <img alt="The Shining" height="67" src="https://m.media-amazon.com/images/M/MV5BZWFlYmY2MGEtZjVkYS00YzU4LTg0YjQtYzY1ZGE3NTA5NGQxXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt0081505/" title="Stanley Kubrick (dir.), Jack Nicholson, Shelley Duvall">The Shining</a>
#  <span class="secondaryInfo">(1980)</span>
#  <div class="velocity">42
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  32)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.4 based on 807,229 user ratings">8.4</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt0081505 pending" data-titleid="tt0081505">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
#  </div>
#  </div>
#  </td>
#  <td class="watchlistColumn">
#  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0081505"></div>
#  </td>
#  </tr>
#  <tr>
#  <td class="posterColumn">
#  <span data-value="99" name="rk"></span>
#  <span data-value="8.4" name="ir"></span>
#  <span data-value="1.3423968E12" name="us"></span>
#  <span data-value="1417792" name="nv"></span>
#  <span data-value="-2.5999999999999996" name="ur"></span>
#  <a href="/title/tt1345836/"> <img alt="The Dark Knight Rises" height="67" src="https://m.media-amazon.com/images/M/MV5BMTk4ODQzNDY3Ml5BMl5BanBnXkFtZTcwODA0NTM4Nw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#  <a href="/title/tt1345836/" title="Christopher Nolan (dir.), Christian Bale, Tom Hardy">The Dark Knight Rises</a>
#  <span class="secondaryInfo">(2012)</span>
#  <div class="velocity">98
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  27)</span>
#  </div>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.4 based on 1,417,792 user ratings">8.4</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt1345836 pending" data-titleid="tt1345836">
#  <div class="boundary">
#  <div class="popover">
#  <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
#  </div>
#  <div class="inline">
#  <div class="pending"></div>
#  <div class="unseeable">NOT YET RELEASED</div>
#  <div class="unseen"> </div>
#  <div class="rating"></div>
#  <div class="seen">Seen</div>
# ...
#  <path d="M4.85,16.634 C3.379,16.634 2.202,16.215 1.321,15.376 C0.44,14.535 0,13.411 0,12.002 C0,10.488 0.538,9.281 1.616,8.379 C2.694,7.478 4.146,7.026 5.97,7.026 C7.131,7.026 8.436,7.202 9.887,7.556 L9.887,5.503 C9.887,4.384 9.633,3.597 9.126,3.14 C8.617,2.684 7.753,2.456 6.53,2.456 C5.099,2.456 3.7,2.664 2.332,3.078 C1.854,3.224 1.554,3.295 1.43,3.295 C1.181,3.295 1.057,3.109 1.057,2.736 L1.057,1.897 C1.057,1.627 1.098,1.43 1.181,1.305 C1.264,1.181 1.43,1.068 1.679,0.963 C2.321,0.674 3.135,0.44 4.119,0.264 C5.104,0.088 6.083,0 7.058,0 C9.028,0 10.479,0.409 11.411,1.228 C12.344,2.047 12

#  <td>
#  <div>
#  <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-in&amp;token=BCYqRbMUzFOs_rWAfxw9N42E6huGz0PXdQQk3z5lRbw_BpUdbqk2bIXVDao9tRgHDchSYU-sFZc0%0D%0Awu67gyzwWuhncpHXrqIaQjCExNGejQYFpbm70ibX3Wi67PJdGDZcdCf9EIWkWLnnLBpWL7VhnJVT%0D%0AgmUNXu6UfT7_B-tGX_oQrKk1jarI9m91h4BV2e0Xath_FBK1WtxSgFTLBkNnX0O4LRX5dLAxTOCc%0D%0AiDz2xztaXkEYIlv980lf6tilLTBPH6Cr%0D%0A">
#  <span class="amazon-affiliate-site-name">Amazon India</span><br/>
#  <span class="amazon-affiliate-site-desc">Buy Movie and<br/>TV Show DVDs</span>
#  </a>
#  </div>
#  </td>
#  <td>
#  <div>
#  <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-dpr&amp;token=BCYjr0JcM1Qhwv93NNXz9TR__AXq0tvWXq0HJOaLLBCCKmt9ooJOO8CLmZm9aGzByF9-sEo3n5Uw%0D%0A_4WS-DKrVNwSo7kJzW1edlGK1XhNvkra7V1XlZ3Ac9zACcsHri5cNnlEtSUl9wPCSk_MGBHIwSZ5%0D%0AYV078zIYAPJuVxh67bnCJDA%0D%0A">
#  <span class="amazon-affiliate-site-name">DPReview</span><br/>
#  <span class="amazon-affiliate-site-desc">Digital<br/>Photography</span>
#  </a>
#  </div>
#  </td>
#  <td>
#  <div>
#  <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-aud&amp;token=BCYuUCvq4n9ZOsDdLJMYkD6yqvhUU704sBjh6Njyxq1yRujEA-3f8Wstdr3ozXM_Wwn1jwcgSMtq%0D%0AIFN2ChmNpcrPdsG0hi-O-KZyu6amyTWwzH38DWC92-b-YFIC5xp5kbfMJ7M4xZjDIafADY5TSHgC%0D%0A5-KfVOS5UIIbcxrPtZ_veOY%0D%0A">
#  <span class="amazon-affiliate-site-name">Audible</span><br/>
#  <span class="amazon-affiliate-site-desc">Download<br/>Audio Books</span>
#  </a>
#  </div>
#  </td>
#  </tr>
#  </table>
#  </div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "desktopFooter", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "desktopFooter", {wb: 1});
#      }
#  </script>
#  <script type="text/javascript">
#          try {
#              window.lumierePlayer = window.lumierePlayer || {};
#              window.lumierePlayer.weblab = JSON.parse('{"IMDB_TV_REBRAND_212999":"T1","IMDB_VIDEO_PLAYER_162496":"C","IMDB_RELATED_VIDEOS_196868":"T1","IMDB_VIDEO_SINGLE_PAGE_REDIRECT_241512":"C"}');
#          } catch (error) {
#              if (window.ueLogError) {
#                  window.ueLogError(error, {
#                      logLevel: "WARN",
#                      attribution: "videoplayer",
#                      message: "Failed to parse weblabs for video player."
#                  });
#              }
#          }
#      </script>
#  </div>
#  </div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("bb", "LoadHeaderJS", {wb: 1});
#      }
#  </script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/common-991210058._CB436754830_.js" type="text/javascript"></script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/pagelayout-3281904452._CB448911442_.js" type="text/javascript"></script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/other-1526325458._CB450703648_.js" type="text/javascript"></script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/seenWidget-1675519461._CB449143927_.js" type="text/javascript"></script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/watchlistButton-1850442102._CB450746566_.js" type="text/javascript"></script>
#  <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/chart-share-widget-1048338655._CB461897629_.js" type="text/javascript"></script>
#  <script type="text/javascript">
#              function jQueryOnReady(remaining_count) {
#                  if (window.jQuery && typeof $.fn.watchlistRibbon !== 'undefined') {
#                      jQuery(
#                                          function() {
#                      window.imdb.CS.Chart.InitChart();
#                  }
#
#                      );
#                      jQuery(
#                          function() { $('#content-2-wide').watchlistRibbon('.ribbonize'); }
#                      );
#                  } else if (remaining_count > 0) {
#                      setTimeout(function() { jQueryOnReady(remaining_count-1) }, 100);
#                  }
#              }
#              jQueryOnReady(50);
#              </script>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be", "LoadFooterJS", {wb: 1});
#      }
#  </script>
#  <script>
#      if (typeof uex == 'function') {
#        uex("ld", "LoadFooterJS", {wb: 1});
#      }
#  </script>
#  <div id="servertime" time="153"></div>
#  <script>
#      if (typeof uet == 'function') {
#        uet("be");
#      }
#  </script>
#  </body>, '\n']

# %%
body = list(html.children)[3]

# %%
body
# Out:
# <body class="fixed" id="styleguide-v2">
# <script>
#     if (typeof uet == 'function') {
#       uet("bb");
#     }
# </script>
# <script>
#     if ('csm' in window) {
#       csm.measure('csm_body_delivery_started');
#     }
#   </script>
# <div id="wrapper">
# <div class="redesign" id="root">
# <div class="navbarSprite" id="nb20">
# <div id="supertab">
# <!-- no content received for slot: top_ad -->
# </div>
# <script>
#     if (typeof uet == 'function') {
#       uet("ns");
#     }
# </script>
# <div class="navbarSprite" id="navbar">
# <noscript>
# <style>
#         #pagecontent{margin-top:-17px}
#     </style>
# </noscript>
# <span id="home_img_holder">
# <a class="navbarSprite" href="/" id="home_img" title="Home"></a> <span class="alt_logo">
# <a href="/" title="Home">IMDb</a>
# </span>
# </span>
# <form action="/find" class="nav-searchbar-inner" id="navbar-form" method="get">
# <div id="nb_search">
# <noscript><div id="more_if_no_javascript"><a href="/search/">More</a></div></noscript>
# <button aria-label="Submit Search" class="primary btn" id="navbar-submit-button" type="submit"><div class="magnifyingglass navbarSprite"></div></button>
# <input name="ref_" type="hidden" value="nv_sr_fn"/>
# <input autocomplete="off" id="navbar-query" name="q" placeholder="Find Movies, TV shows, Celebrities and more..." type="text" value=""/>
# <div class="quicksearch_dropdown_wrapper">
# <select class="quicksearch_dropdown navbarSprite hidden" id="quicksearch" name="s">
# <option value="all">All</option>
# <option value="tt">Titles</option>
# <option value="ep">TV Episodes</option>
# <option value="nm">Names</option>
# <option value="co">Companies</option>
# <option value="kw">Keywords</option>
# </select>
# </div>
# <div cel_widget_id="SuggestionSearchWidget" class="celwidget" id="navbar-suggestionsearch"></div>
# </div>
# </form>
# <div id="megaMenu">
# <ul class="main_nav" id="consumer_main_nav">
# <li class="spacer"></li>
# <li class="css_nav_item freediveNavMenu" id="navFreediveMenu">
# <p class="navCategory">
# <a href="/tv/"> Watch Now For Free
# </a> </p>
# <span class="downArrow"></span>
# <div class="sub_nav freediveNavMenu__container" id="navMenu0">
# <h5>
# <span class="headerText">Featured</span>
# <span class="seeAll">
# <a href="/tv/">Browse more titles »</a>
# </span>
# </h5>
# <ul class="freediveNavMenu__list" id="freediveNavMenuList"></ul>
# </div>
# <script>
#                     if (!('imdb' in window)) { window.imdb = {}; }
#                     window.imdb.freediveTitleData = [
#                              {
#                                 imageUrl: "https://m.media-amazon.com/images/M/MV5BZDAwYTlhMDEtNTg0OS00NDY2LWJjOWItNWY3YTZkM2UxYzUzXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY209_CR4,0,140,209_AL_.jpg",
#                                 link: "https://www.imdb.com/tv/watch/tt0110413",
#                                 title: "Léon: The Professional"
#                              },
#                              {
#                                 imageUrl: "https://m.media-amazon.com/images/M/MV5BM2VlNTE1ZmMtOTAyNS00ODYwLWFmY2MtZWEzOTE2YjE1NDE2XkEyXkFqcGdeQXVyNDk3NzU2MTQ@._V1_SX140_AL_.jpg",
#                                 link: "https://www.imdb.com/tv/watch/tt0088930",
#                                 title: "Clue"
#                              },
#                              {
#                                 imageUrl: "https://m.media-amazon.com/images/M/MV5BMzUzNDM2NzM2MV5BMl5BanBnXkFtZTgwNTM3NTg4OTE@._V1_SY209_CR0,0,140,209_AL_.jpg",
#                                 link: "https://www.imdb.com/tv/watch/tt3783958",
#                                 title: "La La Land"
#                              },
#                     ];
#                 </script>
# </li>
# <li class="spacer"></li>
# <li class="css_nav_item" id="navTitleMenu">
# <p class="navCategory">
# <a href="/movies-in-theaters/">Movies</a>,
#                 <a href="/chart/toptv/">TV</a><br/>
#                 &amp; <a href="/showtimes/">Showtimes</a></p>
# <span class="downArrow"></span>
# <div class="sub_nav" id="navMenu1">
# <div id="titleMenuImage" style="background: url('https://ia.media-imdb.com/images/M/MV5BNTc0NTU3NDg4Ml5BMl5BanBnXkFtZTgwOTM0NzQ5MTE@._UY340_CR80,10,410,315_HC_BR10_.jpg')">
# <a class="fallback" href="/title/tt2582802/?ref_=nv_mv_dflt_1" title="                            Whiplash
# , #45 on IMDb Top Rated Movies">
# </a>
# <div class="overlay">
# <p>
# <a href="/title/tt2582802/?ref_=nv_mv_dflt_2" id="titleMenuImageClick">
# <strong>                            Whiplash
# </strong> (2014)
#                                 </a>
# <br/>
# <a href="/chart/top?ref_=nv_mv_dflt_3" id="titleMenuImageSecondaryClick">
#                                     #<strong>45</strong> on IMDb Top Rated Movies
#                                 </a> »
#                             </p>
# </div>
# </div>
# <div class="subNavListContainer">
# <h5>MOVIES</h5>
# <ul>
# <li><a href="/movies-in-theaters/">In Theaters</a></li>
# <li><a href="/showtimes/">Showtimes &amp; Tickets</a></li>
# <li><a href="/trailers/">Latest Trailers</a></li>
# <li><a href="/movies-coming-soon/">Coming Soon</a></li>
# <li><a href="/calendar/">Release Calendar</a></li>
# <li><a href="/chart/top">Top Rated Movies</a></li>
# <li><a href="/india/top-rated-indian-movies">Top Rated Indian Movies</a></li>
# <li><a href="/chart/moviemeter">Most Popular Movies</a></li>
# </ul>
# <h5>CHARTS &amp; TRENDS</h5>
# <ul>
# <li><a href="/chart/">Box Office</a></li>
# <li><a href="/search/title?count=100&amp;groups=oscar_best_picture_winners&amp;sort=year,desc">Oscar Winners</a></li>
# <li><a href="/genre/">Most Popular by Genre</a></li>
# </ul>
# </div>
# <div class="subNavListContainer">
# <h5>TV &amp; VIDEO</h5>
# <ul>
# <li><a href="/chart/toptv/">Top Rated TV Shows</a></li>
# <li><a href="/chart/tvmeter">Most Popular TV Shows</a></li>
# <li><a href="/sections/dvd/">DVD &amp; Blu-Ray</a></li>
# </ul>
# <h5>SPECIAL FEATURES</h5>
# <ul>
# <li><a href="/amazon-originals/">Amazon Originals</a></li>
# <li><a href="/streaming/">Streaming Now</a></li>
# <li><a href="/scary-good/">Horror Guide</a></li>
# <li><a href="/imdbpicks/">IMDb Picks</a></li>
# <li><a href="/originals/">IMDb Original Series</a></li>
# <li><a href="/family-entertainment-guide/">Family Movie/TV Guide</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class
# <span>29 October 2019</span>
# <span>|</span>
# <span>The Wrap</span>
# </small>
# </li>
# </ul>
# </div>
# </div>
# <div class="subNavListContainer">
# <h5>NEWS</h5>
# <ul>
# <li><a href="/news/top">Top News</a></li>
# <li><a href="/news/movie">Movie News</a></li>
# <li><a href="/news/tv">TV News</a></li>
# <li><a href="/news/celebrity">Celebrity News</a></li>
# <li><a href="/news/indie">Indie News</a></li>
# </ul>
# <h5>COMMUNITY</h5>
# <ul>
# <li><a href="/czone/">Contributor Zone</a></li>
# <li><a href="/poll/">Polls</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="spacer"></li>
# <li class="css_nav_item" id="navWatchlistMenu">
# <p class="navCategory singleLine watchlist">
# <a href="/list/watchlist">Watchlist</a>
# </p>
# <span class="downArrow"></span>
# <div class="sub_nav" id="navMenu4">
# <h5>
#             YOUR WATCHLIST
#     </h5>
# <ul id="navWatchlist">
# </ul>
# <script>
#     if (!('imdb' in window)) { window.imdb = {}; }
#     window.imdb.watchlistTeaserData = [
#                 {
#                         href : "/list/watchlist",
#                 src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot1_logged_out._CB484021159_.jpg"
#                 },
#                 {
#                     href : "/search/title?count=100&title_type=feature,tv_series",
#                 src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot2_popular._CB484021159_.jpg"
#                 },
#                 {
#                     href : "/chart/top",
#                 src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot3_top250._CB484021159_.jpg"
#                 }
#     ];
#     </script>
# </div>
# </li>
# <li class="spacer"></li>
# </ul>
# </div>
# <div id="nb_extra">
# <ul class="main_nav" id="nb_extra_nav">
# <li class="css_nav_item" id="navProMenu">
# <p class="navCategory">
# <a href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm"> <img alt="IMDbPro Menu" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_logo_nb._CB484021162_.png"/>
# </a> </p>
# <span class="downArrow"></span>
# <div class="imdb-pro-ad-shared imdb-pro-ad-redesign sub_nav" id="navMenuPro">
# <a class="imdb-pro-ad__link" href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm"> <div class="imdb-pro-ad__image" id="proAd">
# <img alt="Go to IMDbPro" height="145" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png" srcset="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png 1x, https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user_2x._CB484021157_.png 2x" width="127"/>
# </div>
# <section class="imdb-pro-ad__content">
# <div class="imdb-pro-ad__title">The essential resource for entertainment professionals</div>
# <p class="imdb-pro-ad__line">Find industry contacts &amp; talent representation</p>
# <p class="imdb-pro-ad__line">Access in-development titles not available on IMDb</p>
# <p class="imdb-pro-ad__line">Get the latest news from leading industry trades</p>
# <p class="imdb-pro-ad__line">Claim your page and control your brand across IMDb &amp; Amazon</p>
# <div class="imdb-pro-new__button">
# <svg height="30px" version="1.1" viewbox="0 0 172 29" width="175px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>TryIMDbProFree</title>
# <g fill="none" fill-rule="evenodd" id="tryIMDbProFree" stroke="none" stroke-width="1">
# <rect fill="#F1C241" height="28" id="tryIMDbProFreeButton" rx="3" stroke="#A88734" width="170" x="1" y="1"></rect>
# <text id="tryIMDbProFreeText">
# <tspan x="33" y="19">Try IMDbPro Free</tspan>
# </text>
# </g>
# </svg>
# </div>
# </section>
# </a></div>
# </li>
# <li class="spacer"><span class="ghost">|</span></li>
# <li>
# <a href="https://help.imdb.com/imdb">Help</a>
# </li>
# <li class="spacer"><span class="ghost">|</span></li>
# <li class="nb-social-links">
icon ipl-icon--inherit-color ipl-icon--inline" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M9.955 14.955v-5.91L15.182 12l-5.227 2.955zm11.627-7.769a2.505 2.505 0 0 0-1.768-1.768C18.254 5 12 5 12 5s-6.254 0-7.814.418c-.86.23-1.538.908-1.768 1.768C2 8.746 2 12 2 12s0 3.254.418 4.814c.23.86.908 1.538 1.768 1.768C5.746 19 12 19 12 19s6.254 0 7.814-.418a2.505 2.505 0 0 0 1.768-1.768C22 15.254 22 12 22 12s0-3.254-.418-4.814z"></path>
# <path d="M0 0h24v24H0z" fill="none"></path>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# <div id="nb_personal">
# <ul class="main_nav" id="consumer_user_nav">
# <li class="css_nav_menu no_arrow" id="navUserMenu">
# <p class="navCategory singleLine">
# <a class="signin-button" href="/registration/signin?u=https%3A//www.imdb.com/chart/moviemeter%3Fsort%3Dir,desc%26mode%3Dsimple%26page%3D1" id="imdb-signin-link"> <span class="signin-imdb-text">Sign in</span>
# </a> </p>
# </li>
# </ul>
# </div>
# </div>
# <script>
#     if (typeof uet == 'function') {
#       uet("ne");
#     }
# </script>
# <!-- no content received for slot: navstrip -->
# <!-- no content received for slot: injected_navstrip -->
# </div>
# <script>
#     if (typeof uet == 'function') {
#       uet("cf");
#     }
# </script>
# <div id="pagecontent">
# <div class="pagecontent">
# <!-- no content received for slot: injected_billboard -->
# </div>
# <div class="pagecontent" id="top-slot-wrapper">
# </div>
# <div class="pagecontent">
# <div id="content-2-wide">
# <div id="main">
# <script>
#     if (typeof uet == 'function') {
#       uet("af");
#     }
# </script>
# <a name="slot_center-1"></a>
# <div class="article">
# <script type="text/javascript">if(typeof uet === 'function'){uet('bb','ChartWidget',{wb:1});}</script>
# <span class="ab_widget">
# <input data-caller="chtmvm" id="seen-config" type="hidden"/><div class="seen-collection" data-collectionid="moviemeter">
# <div class="article">
# <h3>IMDb Charts</h3>
# <div class="chart-social-sharing-widget" id="social-sharing-widget"></div>
# <h1 class="header">Most Popular Movies</h1>
# <div class="byline">As determined by IMDb Users</div>
# <hr/>
# <div class="lister">
# <div>
# <div class="nav">
# <div class="controls float-right lister-activated">
# <label class="lister-sort-by-label" for="lister-sort-by-options">Sort by: </label>
# <select class="lister-sort-by" id="lister-sort-by-options" name="sort">
# <option value="rk:ascending">
#           Ranking
#         </option>
# <option selected="selected" value="ir:descending">
#           IMDb Rating
#         </option>
# <option value="us:descending">
#           Release Date
#         </option>
# <option value="nv:descending">
#           Number of Ratings
#         </option>
# <option value="ur:descending">
#           Your Rating
#         </option>
# </select>
# <span class="global-sprite lister-sort-reverse ascending" data-sort="ir:asc">
# </span>
# </div>
# <div class="desc">Showing <span>100</span> Titles</div>
# </div>
# </div>
# <br class="clear"/>
# <table class="chart full-width" data-caller-name="chart-moviemeter">
# <colgroup>
# <col class="chartTableColumnPoster"/>
# <col class="chartTableColumnTitle"/>
# <col class="chartTableColumnIMDbRating"/>
# <col class="chartTableColumnYourRating"/>
# <col class="chartTableColumnWatchlistRibbon"/>
# </colgroup>
# <thead>
# <tr>
# <th></th>
# <th>Rank &amp; Title</th>
# <th>IMDb Rating</th>
# <th>Your Rating</th>
# <th></th>
# </tr>
# </thead>
# <tbody class="lister-list">
# <tr>
# <td class="posterColumn">
# <span data-value="84" name="rk"></span>
# <span data-value="9.3" name="ir"></span>
# <span data-value="7.791552E11" name="us"></span>
# <span data-value="2153486" name="nv"></span>
# <span data-value="-1.6999999999999993" name="ur"></span>
# <a href="/title/tt0111161/"> <img alt="The Shawshank Redemption" height="67" src="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
# <span class="secondaryInfo">(1994)</span>
# <div class="velocity">83
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter down"></span>
# 28)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="9.3 based on 2,153,486 user ratings">9.3</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0111161 pending" data-titleid="tt0111161">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0111161"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="28" name="rk"></span>
# <span data-value="9.0" name="ir"></span>
# <span data-value="1.2159936E12" name="us"></span>
# <span data-value="2126122" name="nv"></span>
# <span data-value="-2.0" name="ur"></span>
# <a href="/title/tt0468569/"> <img alt="The Dark Knight" height="67" src="https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
# <span class="secondaryInfo">(2008)</span>
# <div class="velocity">28
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter down"></span>
# 15)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="9.0 based on 2,126,122 user ratings">9.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0468569 pending" data-titleid="tt0468569">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0468569"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="1" name="rk"></span>
# <span data-value="8.8" name="ir"></span>
# <span data-value="1.5672096E12" name="us"></span>
# <span data-value="401160" name="nv"></span>
# <span data-value="-2.1999999999999993" name="ur"></span>
# <a href="/title/tt7286456/"> <img alt="Joker" height="67" src="https://m.media-amazon.com/images/M/MV5BNGVjNWI4ZGUtNzE0MS00YTJmLWE0ZDctN2ZiYTk2YmI3NTYyXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt7286456/" title="Todd Phillips (dir.), Joaquin Phoenix, Robert De Niro">Joker</a>
# <span class="secondaryInfo">(2019)</span>
# <div class="velocity">1
# (no change)
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.8 based on 401,160 user ratings">8.8</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt7286456 pending" data-titleid="tt7286456">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt7286456"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="13" name="rk"></span>
# <span data-value="8.6" name="ir"></span>
# <span data-value="1.5695424E12" name="us"></span>
# <span data-value="3684" name="nv"></span>
# <span data-value="-2.4000000000000004" name="ur"></span>
# <a href="/title/tt1302006/"> <img alt="The Irishman" height="67" src="https://m.media-amazon.com/images/M/MV5BMGUyM2ZiZmUtMWY0OC00NTQ4LThkOGUtNjY2NjkzMDJiMWMwXkEyXkFqcGdeQXVyMzY0MTE3NzU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt1302006/" title="Martin Scorsese (dir.), Jesse Plemons, Robert De Niro">The Irishman</a>
# <span class="secondaryInfo">(2019)</span>
# <div class="velocity">13
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter down"></span>
# 4)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.6 based on 3,684 user ratings">8.6</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt1302006 pending" data-titleid="tt1302006">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1302006"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="15" name="rk"></span>
# <span data-value="8.5" name="ir"></span>
# <span data-value="1.5583968E12" name="us"></span>
# <span data-value="53185" name="nv"></span>
# <span data-value="-2.5" name="ur"></span>
# <a href="/title/tt6751668/"> <img alt="Parasite" height="67" src="https://m.media-amazon.com/images/M/MV5BOWVmODY4MjYtZGViYS00MzJjLWI3NmItMGFmMDRkMzI1OTU3XkEyXkFqcGdeQXVyNTQ0NTUxOTA@._V1_UY67_CR2,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt6751668/" title="Bong Joon Ho (dir.), Kang-ho Song, Yeo-jeong Jo">Parasite</a>
# <span class="secondaryInfo">(2019)</span>
# <div class="velocity">15
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter up"></span>
# 6)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.5 based on 53,185 user ratings">8.5</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt6751668 pending" data-titleid="tt6751668">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt6751668"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="36" name="rk"></span>
# <span data-value="8.5" name="ir"></span>
# <span data-value="1.5558912E12" name="us"></span>
# <span data-value="591202" name="nv"></span>
# <span data-value="-2.5" name="ur"></span>
# <a href="/title/tt4154796/"> <img alt="Avengers: Endgame" height="67" src="https://m.media-amazon.com/images/M/MV5BMTc5MDE2ODcwNV5BMl5BanBnXkFtZTgwMzI2NzQ2NzM@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt4154796/" title="Anthony Russo (dir.), Robert Downey Jr., Chris Evans">Avengers: Endgame</a>
# <span class="secondaryInfo">(2019)</span>
# <div class="velocity">36
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter down"></span>
# 4)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.5 based on 591,202 user ratings">8.5</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt4154796 pending" data-titleid="tt4154796">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt4154796"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="74" name="rk"></span>
# <span data-value="8.5" name="ir"></span>
# <span data-value="6.783264E11" name="us"></span>
# <span data-value="929988" name="nv"></span>
# <span data-value="-2.5" name="ur"></span>
# <a href="/title/tt0103064/"> <img alt="Terminator 2: Judgment Day" height="67" src="https://m.media-amazon.com/images/M/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt0103064/" title="James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton">Terminator 2: Judgment Day</a>
# <span class="secondaryInfo">(1991)</span>
# <div class="velocity">73
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter up"></span>
# 60)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.5 based on 929,988 user ratings">8.5</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0103064 pending" data-titleid="tt0103064">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0103064"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="86" name="rk"></span>
# <span data-value="8.5" name="ir"></span>
# <span data-value="9.571392E11" name="us"></span>
# <span data-value="1243233" name="nv"></span>
# <span data-value="-2.5" name="ur"></span>
# <a href="/title/tt0172495/"> <img alt="Gladiator" height="67" src="https://m.media-amazon.com/images/M/MV5BMDliMmNhNDEtODUyOS00MjNlLTgxODEtN2U3NzIxMGVkZTA1L2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt0172495/" title="Ridley Scott (dir.), Russell Crowe, Joaquin Phoenix">Gladiator</a>
# <span class="secondaryInfo">(2000)</span>
# <div class="velocity">85
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter down"></span>
# 16)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.5 based on 1,243,233 user ratings">8.5</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0172495 pending" data-titleid="tt0172495">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0172495"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="9" name="rk"></span>
# <span data-value="8.4" name="ir"></span>
# <span data-value="1.558224E12" name="us"></span>
# <span data-value="7652" name="nv"></span>
# <span data-value="-2.5999999999999996" name="ur"></span>
# <a href="/title/tt7984734/"> <img alt="The Lighthouse" height="67" src="https://m.media-amazon.com/images/M/MV5BZmE0MGJhNmYtOWNjYi00Njc5LWE2YjEtMWMxZTVmODUwMmMxXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt7984734/" title="Robert Eggers (dir.), Willem Dafoe, Robert Pattinson">The Lighthouse</a>
# <span class="secondaryInfo">(2019)</span>
# <div class="velocity">9
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter up"></span>
# 11)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.4 based on 7,652 user ratings">8.4</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt7984734 pending" data-titleid="tt7984734">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt7984734"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="43" name="rk"></span>
# <span data-value="8.4" name="ir"></span>
# <span data-value="3.27888E11" name="us"></span>
# <span data-value="807229" name="nv"></span>
# <span data-value="-2.5999999999999996" name="ur"></span>
# <a href="/title/tt0081505/"> <img alt="The Shining" height="67" src="https://m.media-amazon.com/images/M/MV5BZWFlYmY2MGEtZjVkYS00YzU4LTg0YjQtYzY1ZGE3NTA5NGQxXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt0081505/" title="Stanley Kubrick (dir.), Jack Nicholson, Shelley Duvall">The Shining</a>
# <span class="secondaryInfo">(1980)</span>
# <div class="velocity">42
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter up"></span>
# 32)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.4 based on 807,229 user ratings">8.4</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0081505 pending" data-titleid="tt0081505">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0081505"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="99" name="rk"></span>
# <span data-value="8.4" name="ir"></span>
# <span data-value="1.3423968E12" name="us"></span>
# <span data-value="1417792" name="nv"></span>
# <span data-value="-2.5999999999999996" name="ur"></span>
# <a href="/title/tt1345836/"> <img alt="The Dark Knight Rises" height="67" src="https://m.media-amazon.com/images/M/MV5BMTk4ODQzNDY3Ml5BMl5BanBnXkFtZTcwODA0NTM4Nw@@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt1345836/" title="Christopher Nolan (dir.), Christian Bale, Tom Hardy">The Dark Knight Rises</a>
# <span class="secondaryInfo">(2012)</span>
# <div class="velocity">98
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter down"></span>
# 27)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.4 based on 1,417,792 user ratings">8.4</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt1345836 pending" data-titleid="tt1345836">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1345836"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="94" name="rk"></span>
# <span data-value="8.3" name="ir"></span>
# <span data-value="1.925856E11" name="us"></span>
# <span data-value="658508" name="nv"></span>
# <span data-value="-2.6999999999999993" name="ur"></span>
# <a href="/title/tt0075314/"> <img alt="Taxi Driver" height="67" src="https://m.media-amazon.com/images/M/MV5BM2M1MmVhNDgtNmI0YS00ZDNmLTkyNjctNTJiYTQ2N2NmYzc2XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt0075314/" title="Martin Scorsese (dir.), Robert De Niro, Jodie Foster">Taxi Driver</a>
# <span class="secondaryInfo">(1976)</span>
# <div class="velocity">93
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter down"></span>
# 35)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.3 based on 658,508 user ratings">8.3</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0075314 pending" data-titleid="tt0075314">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0075314"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="20" name="rk"></span>
# <span data-value="8.0" name="ir"></span>
# <span data-value="1.5723936E12" name="us"></span>
# <span data-value="102" name="nv"></span>
# <span data-value="-3.0" name="ur"></span>
# <a href="/title/tt5606664/"> <img alt="Doctor Sleep" height="67" src="https://m.media-amazon.com/images/M/MV5BYmY3NGJlYTItYmQ4OS00ZTEwLWIzODItMjMzNWU2MDE0NjZhXkEyXkFqcGdeQXVyMzQzMDA3MTI@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt5606664/" title="Mike Flanagan (dir.), Rebecca Ferguson, Ewan McGregor">Doctor Sleep</a>
# <span class="secondaryInfo">(2019)</span>
# <div class="velocity">20
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter up"></span>
# 15)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 102 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt5606664 pending" data-titleid="tt5606664">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt5606664"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="24" name="rk"></span>
# <span data-value="8.0" name="ir"></span>
# <span data-value="1.5583968E12" name="us"></span>
# <span data-value="221114" name="nv"></span>
# <span data-value="-3.0" name="ur"></span>
# <a href="/title/tt7131622/"> <img alt="Once Upon a Time in Hollywood" height="67" src="https://m.media-amazon.com/images/M/MV5BOTg4ZTNkZmUtMzNlZi00YmFjLTk1MmUtNWQwNTM0YjcyNTNkXkEyXkFqcGdeQXVyNjg2NjQwMDQ@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt7131622/" title="Quentin Tarantino (dir.), Leonardo DiCaprio, Brad Pitt">Once Upon a Time in Hollywood</a>
# <span class="secondaryInfo">(2019)</span>
# <div class="velocity">24
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter up"></span>
# 1)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 221,114 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt7131622 pending" data-titleid="tt7131622">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt7131622"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="33" name="rk"></span>
# <span data-value="8.0" name="ir"></span>
# <span data-value="1.5602112E12" name="us"></span>
# <span data-value="122557" name="nv"></span>
# <span data-value="-3.0" name="ur"></span>
# <a href="/title/tt1979376/"> <img alt="Toy Story 4" height="67" src="https://m.media-amazon.com/images/M/MV5BMTYzMDM4NzkxOV5BMl5BanBnXkFtZTgwNzM1Mzg2NzM@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt1979376/" title="Josh Cooley (dir.), Tom Hanks, Tim Allen">Toy Story 4</a>
# <span class="secondaryInfo">(2019)</span>
# <div class="velocity">33
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter down"></span>
# 14)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 122,557 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt1979376 pending" data-titleid="tt1979376">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt1979376"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="80" name="rk"></span>
# <span data-value="8.0" name="ir"></span>
# <span data-value="4.675968E11" name="us"></span>
# <span data-value="746758" name="nv"></span>
# <span data-value="-3.0" name="ur"></span>
# <a href="/title/tt0088247/"> <img alt="The Terminator" height="67" src="https://m.media-amazon.com/images/M/MV5BYTViNzMxZjEtZGEwNy00MDNiLWIzNGQtZDY2MjQ1OWViZjFmXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
# <a href="/title/tt0088247/" title="James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton">The Terminator</a>
# <span class="secondaryInfo">(1984)</span>
# <div class="velocity">79
# <span class="secondaryInfo">(
# <span class="global-sprite titlemeter up"></span>
# 46)</span>
# </div>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="8.0 based on 746,758 user ratings">8.0</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0088247 pending" data-titleid="tt0088247">
# <div class="boundary">
# <div class="popover">
# <span class="delete"> </span><ol><li>1<li>2<li>3<li>4<li>5<li>6<li>7<li>8<li>9<li>10</li></li></li></li></li></li></li></li></li></li></ol> </div>
# </div>
# <div class="inline">
# <div class="pending"></div>
# <div class="unseeable">NOT YET RELEASED</div>
# <div class="unseen"> </div>
# <div class="rating"></div>
# <div class="seen">Seen</div>
# </div>
# </div>
# </td>
# <td class="watchlistColumn">
# <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0088247"></div>
# </td>
# </tr>
# <tr>
# <td class="posterColumn">
# <span data-value="95" name="rk"></span>
# <span data-value="8.0" name="ir"></span>
# <span data-value="1.381536E12" name="us"></span>
# <span data-value="485243" name="nv"></span>
# <span data-value="-3.0" name="ur"></span>
# <a href="/title/tt1798709/"> <img alt="Her" height="67" src="https://m.media-amazon.com/images/M/MV5BMjA1Nzk0OTM2OF5BMl5BanBnXkFtZTgwNjU2NjEwMDE@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
span><br/>
# <span class="amazon-affiliate-site-desc">Buy Movies on<br/>DVD &amp; Blu-ray</span>
# </a>
# </div>
# </td>
# <td>
# <div>
# <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-fr&amp;token=BCYqdUTG--CCvgusHg2qCghiG2BKWeilFyeKBKfyNii_1CruqJBzqTMhSsOu1xH_UNhTE6e86SPJ%0D%0AnNRoYpFCegq2RYAZtfn3PNCbPCfrnplmAJCfgbErQCKhKAhfcbJ8xizfrCuIdc_crUThyAUeiQRi%0D%0ASQxb27KDf-vbTpyvGYxf0t054DnACuNflLi2Wfh_Ux-uduHJsneH3eYd4LTdWYgEDNtIkc9oa_64%0D%0AnPWPvi4FcoI%0D%0A">
# <span class="amazon-affiliate-site-name">Amazon France</span><br/>
# <span class="amazon-affiliate-site-desc">Buy Movies on<br/>DVD &amp; Blu-ray</span>
# </a>
# </div>
# </td>
# <td>
# <div>
# <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-in&amp;token=BCYqRbMUzFOs_rWAfxw9N42E6huGz0PXdQQk3z5lRbw_BpUdbqk2bIXVDao9tRgHDchSYU-sFZc0%0D%0Awu67gyzwWuhncpHXrqIaQjCExNGejQYFpbm70ibX3Wi67PJdGDZcdCf9EIWkWLnnLBpWL7VhnJVT%0D%0AgmUNXu6UfT7_B-tGX_oQrKk1jarI9m91h4BV2e0Xath_FBK1WtxSgFTLBkNnX0O4LRX5dLAxTOCc%0D%0AiDz2xztaXkEYIlv980lf6tilLTBPH6Cr%0D%0A">
# <span class="amazon-affiliate-site-name">Amazon India</span><br/>
# <span class="amazon-affiliate-site-desc">Buy Movie and<br/>TV Show DVDs</span>
# </a>
# </div>
# </td>
# <td>
# <div>
# <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-dpr&amp;token=BCYjr0JcM1Qhwv93NNXz9TR__AXq0tvWXq0HJOaLLBCCKmt9ooJOO8CLmZm9aGzByF9-sEo3n5Uw%0D%0A_4WS-DKrVNwSo7kJzW1edlGK1XhNvkra7V1XlZ3Ac9zACcsHri5cNnlEtSUl9wPCSk_MGBHIwSZ5%0D%0AYV078zIYAPJuVxh67bnCJDA%0D%0A">
# <span class="amazon-affiliate-site-name">DPReview</span><br/>
# <span class="amazon-affiliate-site-desc">Digital<br/>Photography</span>
# </a>
# </div>
# </td>
# <td>
# <div>
# <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-aud&amp;token=BCYuUCvq4n9ZOsDdLJMYkD6yqvhUU704sBjh6Njyxq1yRujEA-3f8Wstdr3ozXM_Wwn1jwcgSMtq%0D%0AIFN2ChmNpcrPdsG0hi-O-KZyu6amyTWwzH38DWC92-b-YFIC5xp5kbfMJ7M4xZjDIafADY5TSHgC%0D%0A5-KfVOS5UIIbcxrPtZ_veOY%0D%0A">
# <span class="amazon-affiliate-site-name">Audible</span><br/>
# <span class="amazon-affiliate-site-desc">Download<br/>Audio Books</span>
# </a>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "desktopFooter", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "desktopFooter", {wb: 1});
#     }
# </script>
# <script type="text/javascript">
#         try {
#             window.lumierePlayer = window.lumierePlayer || {};
#             window.lumierePlayer.weblab = JSON.parse('{"IMDB_TV_REBRAND_212999":"T1","IMDB_VIDEO_PLAYER_162496":"C","IMDB_RELATED_VIDEOS_196868":"T1","IMDB_VIDEO_SINGLE_PAGE_REDIRECT_241512":"C"}');
#         } catch (error) {
#             if (window.ueLogError) {
#                 window.ueLogError(error, {
#                     logLevel: "WARN",
#                     attribution: "videoplayer",
#                     message: "Failed to parse weblabs for video player."
#                 });
#             }
#         }
#     </script>
# </div>
# </div>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadHeaderJS", {wb: 1});
#     }
# </script>
# <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/common-991210058._CB436754830_.js" type="text/javascript"></script>
# <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/pagelayout-3281904452._CB448911442_.js" type="text/javascript"></script>
# <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/other-1526325458._CB450703648_.js" type="text/javascript"></script>
# <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/seenWidget-1675519461._CB449143927_.js" type="text/javascript"></script>
# <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/watchlistButton-1850442102._CB450746566_.js" type="text/javascript"></script>
# <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/chart-share-widget-1048338655._CB461897629_.js" type="text/javascript"></script>
# <script type="text/javascript">
#             function jQueryOnReady(remaining_count) {
#                 if (window.jQuery && typeof $.fn.watchlistRibbon !== 'undefined') {
#                     jQuery(
#                                         function() {
#                     window.imdb.CS.Chart.InitChart();
#                 }
#
#                     );
#                     jQuery(
#                         function() { $('#content-2-wide').watchlistRibbon('.ribbonize'); }
#                     );
#                 } else if (remaining_count > 0) {
#                     setTimeout(function() { jQueryOnReady(remaining_count-1) }, 100);
#                 }
#             }
#             jQueryOnReady(50);
#             </script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadFooterJS", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadFooterJS", {wb: 1});
#     }
# </script>
# <div id="servertime" time="153"></div>
# <script>
#     if (typeof uet == 'function') {
#       uet("be");
#     }
# </script>
# </body>

# %%
#flitering for the location of 'titleColumn' AND naming it movie_infos (movie's information is under this class)
soup.find_all( class_='titleColumn')

movie_infos = soup.find_all( class_='titleColumn')

# %%
movie_infos
# Out:
# [<td class="titleColumn">
#  <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
#  <span class="secondaryInfo">(1994)</span>
#  <div class="velocity">83
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  28)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
#  <span class="secondaryInfo">(2008)</span>
#  <div class="velocity">28
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  15)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt7286456/" title="Todd Phillips (dir.), Joaquin Phoenix, Robert De Niro">Joker</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">1
#  (no change)
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt1302006/" title="Martin Scorsese (dir.), Jesse Plemons, Robert De Niro">The Irishman</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">13
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  4)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt6751668/" title="Bong Joon Ho (dir.), Kang-ho Song, Yeo-jeong Jo">Parasite</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">15
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  6)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt4154796/" title="Anthony Russo (dir.), Robert Downey Jr., Chris Evans">Avengers: Endgame</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">36
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  4)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt0103064/" title="James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton">Terminator 2: Judgment Day</a>
#  <span class="secondaryInfo">(1991)</span>
#  <div class="velocity">73
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  60)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt0172495/" title="Ridley Scott (dir.), Russell Crowe, Joaquin Phoenix">Gladiator</a>
#  <span class="secondaryInfo">(2000)</span>
#  <div class="velocity">85
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  16)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt7984734/" title="Robert Eggers (dir.), Willem Dafoe, Robert Pattinson">The Lighthouse</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">9
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  11)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt0081505/" title="Stanley Kubrick (dir.), Jack Nicholson, Shelley Duvall">The Shining</a>
#  <span class="secondaryInfo">(1980)</span>
#  <div class="velocity">42
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  32)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt1345836/" title="Christopher Nolan (dir.), Christian Bale, Tom Hardy">The Dark Knight Rises</a>
#  <span class="secondaryInfo">(2012)</span>
#  <div class="velocity">98
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  27)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt0075314/" title="Martin Scorsese (dir.), Robert De Niro, Jodie Foster">Taxi Driver</a>
#  <span class="secondaryInfo">(1976)</span>
#  <div class="velocity">93
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  35)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt5606664/" title="Mike Flanagan (dir.), Rebecca Ferguson, Ewan McGregor">Doctor Sleep</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">20
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  15)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt7131622/" title="Quentin Tarantino (dir.), Leonardo DiCaprio, Brad Pitt">Once Upon a Time in Hollywood</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">24
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  1)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt1979376/" title="Josh Cooley (dir.), Tom Hanks, Tim Allen">Toy Story 4</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">33
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  14)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt0088247/" title="James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton">The Terminator</a>
#  <span class="secondaryInfo">(1984)</span>
#  <div class="velocity">79
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  46)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt1798709/" title="Spike Jonze (dir.), Joaquin Phoenix, Amy Adams">Her</a>
#  <span class="secondaryInfo">(2013)</span>
#  <div class="velocity">94
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  32)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt10915286/" title="Ed Perkins (dir.), Andrew Caley, Alex Lewis">Tell Me Who I Am</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">65
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  787)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt0077651/" title="John Carpenter (dir.), Donald Pleasence, Jamie Lee Curtis">Halloween</a>
#  <span class="secondaryInfo">(1978)</span>
#  <div class="velocity">84
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  35)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt6398184/" title="Michael Engler (dir.), Matthew Goode, Tuppence Middleton">Downton Abbey</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity
</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt7713068/" title="Cathy Yan (dir.), Margot Robbie, Mary Elizabeth Winstead">Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn</a>
#  <span class="secondaryInfo">(2020)</span>
#  <div class="velocity">59
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  25)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt4520988/" title="Chris Buck (dir.), Kristen Bell, Jason Ritter">Frozen II</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">60
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  20)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt8623904/" title="Paul Feig (dir.), Emilia Clarke, Henry Golding">Last Christmas</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">62
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  29)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt10665338/" title="David Gordon Green (dir.), Jamie Lee Curtis, Judy Greer">Halloween Kills</a>
#  <span class="secondaryInfo">(2020)</span>
#  <div class="velocity">64
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter up"></span>
#  43)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt3480822/" title="Cate Shortland (dir.), Scarlett Johansson, Florence Pugh">Black Widow</a>
#  <span class="secondaryInfo">(2020)</span>
#  <div class="velocity">74
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  7)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt2382320/" title="Cary Joji Fukunaga (dir.), Ana de Armas, Naomie Harris">No Time to Die</a>
#  <span class="secondaryInfo">(2020)</span>
#  <div class="velocity">75
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  5)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt10362466/" title="Roger Kumble (dir.), Hero Fiennes Tiffin, Josephine Langford">After We Collided</a>
#  <div class="velocity">81
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  31)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt6394270/" title="Jay Roach (dir.), Margot Robbie, Charlize Theron">Bombshell</a>
#  <span class="secondaryInfo">(2019)</span>
#  <div class="velocity">82
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  43)</span>
#  </div>
#  </td>, <td class="titleColumn">
#  <a href="/title/tt6673612/" title="Stephen Gaghan (dir.), Tom Holland, Robert Downey Jr.">Dolittle</a>
#  <span class="secondaryInfo">(2020)</span>
#  <div class="velocity">90
#  <span class="secondaryInfo">(
#  <span class="global-sprite titlemeter down"></span>
#  78)</span>
#  </div>
#  </td>]

# %%
#Separate each <a> and calls the first value [0] that has <a> (((Joker)))
movie_info = movie_infos[0].find('a')

#
movie_info
# Out:
# <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>

# %%
#Selecting the value of href which has the movie id
movie_info['href']
# Out:
# '/title/tt0111161/'

# %%
#need to spilt to remove the '/'
movie_id = movie_info['href'].split('/')
movie_id
# Out:
# ['', 'title', 'tt0111161', '']

# %%
#only calling the 2nd  part of the split list (eg. movie id's location)

movie_id = movie_info['href'].split('/')[2]
movie_id
# Out:
# 'tt0111161'

# %%
#get the total number of movies in a set

movie_detail= len(movie_infos)
movie_detail
# Out:
# 100

# %%
# loop for all of the movie_ids

list_of_ids=[]

#for loop for the id
for i in range(movie_detail):
    id_string = movie_infos[i].find('a')
    id_int = id_string['href'].split('/')[2]
    list_of_ids.append(id_int)

list_of_ids
# Out:
# ['tt0111161',
#  'tt0468569',
#  'tt7286456',
#  'tt1302006',
#  'tt6751668',
#  'tt4154796',
#  'tt0103064',
#  'tt0172495',
#  'tt7984734',
#  'tt0081505',
#  'tt1345836',
#  'tt0075314',
#  'tt5606664',
#  'tt7131622',
#  'tt1979376',
#  'tt0088247',
#  'tt1798709',
#  'tt10915286',
#  'tt0077651',
#  'tt6398184',
#  'tt5052448',
#  'tt2584384',
#  'tt0409459',
#  'tt1156398',
#  'tt6320628',
#  'tt6146586',
#  'tt9243946',
#  'tt8526872',
#  'tt6521876',
#  'tt0094721',
#  'tt0385887',
#  'tt2066051',
#  'tt1560220',
#  'tt8772262',
#  'tt1950186',
#  'tt1396484',
#  'tt7784604',
#  'tt7549996',
#  'tt6139732',
#  'tt2527336',
#  'tt7798634',
#  'tt4777008',
#  'tt6105098',
#  'tt7984766',
#  'tt1587310',
#  'tt2935510',
#  'tt1477834',
#  'tt8079248',
#  'tt8946378',
#  'tt0101272',
#  'tt0107120',
#  'tt7349950',
#  'tt7430722',
#  'tt4263482',
#  'tt6924650',
#  'tt6823368',
#  'tt1270797',
#  'tt1206885',
#  'tt5503686',
#  'tt6806448',
#  'tt1502407',
#  'tt6450804',
#  'tt2140507',
#  'tt1340138',
#  'tt5865326',
#  'tt4332232',
#  'tt3387520',
#  'tt8110640',
#  'tt8364368',
#  'tt7734218',
#  'tt9398640',
#  'tt1386697',
#  'tt1620981',
#  'tt5294518',
#  'tt6565702',
#  'tt1025100',
#  'tt8134742',
#  'tt2283336',
#  'tt4687108',
#  'tt10039344',
#  'tt4126476',
#  'tt7390646',
#  'tt5822564',
#  'tt9257484',
#  'tt5913798',
#  'tt7721946',
#  'tt2527338',
#  'tt1634106',
#  'tt7740510',
#  'tt5033998',
#  'tt1877830',
#  'tt7713068',
#  'tt4520988',
#  'tt8623904',
#  'tt10665338',
#  'tt3480822',
#  'tt2382320',
#  'tt10362466',
#  'tt6394270',
#  'tt6673612']

# %%
# intergrating the movie_ids with the main_url and apikey for GET
urls=[]
main_url = 'http://www.omdbapi.com/?i='  


for i in list_of_ids:
    urls.append(main_url + i + '&apikey=6d18c241')

            
#all of the URL's

urls
# Out:
# ['http://www.omdbapi.com/?i=tt0111161&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0468569&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7286456&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1302006&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6751668&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt4154796&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0103064&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0172495&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7984734&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0081505&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1345836&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0075314&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt5606664&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7131622&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1979376&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0088247&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1798709&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt10915286&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0077651&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6398184&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt5052448&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt2584384&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0409459&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1156398&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6320628&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6146586&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt9243946&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt8526872&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6521876&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0094721&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0385887&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt2066051&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1560220&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt8772262&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1950186&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1396484&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7784604&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7549996&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6139732&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt2527336&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7798634&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt4777008&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6105098&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7984766&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1587310&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt2935510&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1477834&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt8079248&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt8946378&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0101272&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt0107120&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7349950&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7430722&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt4263482&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6924650&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6823368&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1270797&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1206885&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt5503686&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6806448&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1502407&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6450804&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt2140507&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1340138&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt5865326&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt4332232&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt3387520&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt8110640&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt8364368&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7734218&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt9398640&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1386697&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1620981&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt5294518&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6565702&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1025100&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt8134742&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt2283336&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt4687108&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt10039344&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt4126476&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7390646&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt5822564&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt9257484&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt5913798&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7721946&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt2527338&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1634106&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7740510&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt5033998&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt1877830&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt7713068&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt4520988&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt8623904&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt10665338&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt3480822&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt2382320&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt10362466&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6394270&apikey=6d18c241',
#  'http://www.omdbapi.com/?i=tt6673612&apikey=6d18c241']

# %%
# Just another way to intergrate the movie ids and the url for GET ***Mehmet showed me this one***

# sites=[]
# for i in list_of_ids:
#     sites.append('http://www.omdbapi.com/?i={}&apikey=6d18c241'.format(i))
# sites

# %%
test = requests.get('http://www.omdbapi.com/?i=tt0103064&apikey=6d18c241')
test.content
# Out:
# b'{"Title":"Terminator 2: Judgment Day","Year":"1991","Rated":"R","Released":"03 Jul 1991","Runtime":"137 min","Genre":"Action, Sci-Fi","Director":"James Cameron","Writer":"James Cameron, William Wisher","Actors":"Arnold Schwarzenegger, Linda Hamilton, Edward Furlong, Robert Patrick","Plot":"A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her teenage son, John Connor, from a more advanced and powerful cyborg.","Language":"English, Spanish","Country":"USA","Awards":"Won 4 Oscars. Another 27 wins & 27 nominations.","Poster":"https://m.media-amazon.com/images/M/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg","Ratings":[{"Source":"Internet Movie Database","Value":"8.5/10"},{"Source":"Rotten Tomatoes","Value":"93%"},{"Source":"Metacritic","Value":"75/100"}],"Metascore":"75","imdbRating":"8.5","imdbVotes":"926,991","imdbID":"tt0103064","Type":"movie","DVD":"31 Mar 1998","BoxOffice":"$198,116,802","Production":"TriStar Pictures","Website":"N/A","Response":"True"}'

# %%
###  TESTING ####
"""imdb_db = []
page1 = requests.get('http://www.omdbapi.com/?i=tt0103064&apikey=6d18c241')
data = page1.json()
keys = ['imdbID', 'Title','imdbRating','imdbVotes', 'Metascore', 'Director', 'Genre', 'BoxOffice']
parsed_results = {key: (data[key] if key in data else 'Null') for key in keys}

#Showing the last parsed result only(just checking)
parsed_results"""
# Out:
# "imdb_db = []\npage1 = requests.get('http://www.omdbapi.com/?i=tt0103064&apikey=6d18c241')\ndata = page1.json()\nkeys = ['imdbID', 'Title', 'Released' ,'imdbRating','imdbVotes', 'Metascore', 'Director', 'Genre', 'BoxOffice']\nparsed_results = {key: (data[key] if key in data else 'Null') for key in keys}\n\n#Showing the last parsed result only(just checking)\nparsed_results"

# %%
# Loop to Get response for all the urls & Parsing results with the keys I need

imdb_db = []

for x in urls:

    
        page1 = requests.get(x)
        data = page1.json()
        keys = ['imdbID', 'Title','imdbRating','imdbVotes', 'Metascore', 'Director', 'Genre', 'BoxOffice']
        parsed_results = {key: (data[key] if key in data else 'Null') for key in keys}
        imdb_db.append(parsed_results)
        time.sleep(0.25)

# %%
#calling to check if IMDB database is correct
imdb_db
# Out:
# [{'imdbID': 'tt0111161',
#   'Title': 'The Shawshank Redemption',
#   'imdbRating': '9.3',
#   'imdbVotes': '2,139,341',
#   'Metascore': '80',
#   'Director': 'Frank Darabont',
#   'Genre': 'Drama',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt0468569',
#   'Title': 'The Dark Knight',
#   'imdbRating': '9.0',
#   'imdbVotes': '2,124,722',
#   'Metascore': '84',
#   'Director': 'Christopher Nolan',
#   'Genre': 'Action, Crime, Drama, Thriller',
#   'BoxOffice': '$533,316,061'},
#  {'imdbID': 'tt7286456',
#   'Title': 'Joker',
#   'imdbRating': '8.9',
#   'imdbVotes': '360,218',
#   'Metascore': '59',
#   'Director': 'Todd Phillips',
#   'Genre': 'Crime, Drama, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1302006',
#   'Title': 'The Irishman',
#   'imdbRating': '8.6',
#   'imdbVotes': '2,745',
#   'Metascore': '94',
#   'Director': 'Martin Scorsese',
#   'Genre': 'Biography, Crime, Drama, History, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6751668',
#   'Title': 'Parasite',
#   'imdbRating': '8.5',
#   'imdbVotes': '34,961',
#   'Metascore': '92',
#   'Director': 'Joon-ho Bong',
#   'Genre': 'Comedy, Drama, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt4154796',
#   'Title': 'Avengers: Endgame',
#   'imdbRating': '8.5',
#   'imdbVotes': '589,503',
#   'Metascore': '78',
#   'Director': 'Anthony Russo, Joe Russo',
#   'Genre': 'Action, Adventure, Drama, Sci-Fi',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt0103064',
#   'Title': 'Terminator 2: Judgment Day',
#   'imdbRating': '8.5',
#   'imdbVotes': '926,991',
#   'Metascore': '75',
#   'Director': 'James Cameron',
#   'Genre': 'Action, Sci-Fi',
#   'BoxOffice': '$198,116,802'},
#  {'imdbID': 'tt0172495',
#   'Title': 'Gladiator',
#   'imdbRating': '8.5',
#   'imdbVotes': '1,234,768',
#   'Metascore': '67',
#   'Director': 'Ridley Scott',
#   'Genre': 'Action, Adventure, Drama',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt7984734',
#   'Title': 'The Lighthouse',
#   'imdbRating': '8.1',
#   'imdbVotes': '1,994',
#   'Metascore': '83',
#   'Director': 'Robert Eggers',
#   'Genre': 'Drama, Fantasy, Horror, Mystery',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt0081505',
#   'Title': 'The Shining',
#   'imdbRating': '8.4',
#   'imdbVotes': '799,875',
#   'Metascore': '66',
#   'Director': 'Stanley Kubrick',
#   'Genre': 'Drama, Horror',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1345836',
#   'Title': 'The Dark Knight Rises',
#   'imdbRating': '8.4',
#   'imdbVotes': '1,408,657',
#   'Metascore': '78',
#   'Director': 'Christopher Nolan',
#   'Genre': 'Action, Thriller',
#   'BoxOffice': '$448,130,642'},
#  {'imdbID': 'tt0075314',
#   'Title': 'Taxi Driver',
#   'imdbRating': '8.3',
#   'imdbVotes': '651,817',
#   'Metascore': '94',
#   'Director': 'Martin Scorsese',
#   'Genre': 'Crime, Drama',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt5606664',
#   'Title': 'Doctor Sleep',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Mike Flanagan',
#   'Genre': 'Horror',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt7131622',
#   'Title': 'Once Upon a Time... in Hollywood',
#   'imdbRating': '8.0',
#   'imdbVotes': '200,902',
#   'Metascore': '83',
#   'Director': 'Quentin Tarantino',
#   'Genre': 'Comedy, Drama',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1979376',
#   'Title': 'Toy Story 4',
#   'imdbRating': '8.0',
#   'imdbVotes': '121,373',
#   'Metascore': '84',
#   'Director': 'Josh Cooley',
#   'Genre': 'Animation, Adventure, Comedy, Family, Fantasy',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt0088247',
#   'Title': 'The Terminator',
#   'imdbRating': '8.0',
#   'imdbVotes': '742,341',
#   'Metascore': '84',
#   'Director': 'James Cameron',
#   'Genre': 'Action, Sci-Fi',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1798709',
#   'Title': 'Her',
#   'imdbRating': '8.0',
#   'imdbVotes': '479,220',
#   'Metascore': '90',
#   'Director': 'Spike Jonze',
#   'Genre': 'Drama, Romance, Sci-Fi',
#   'BoxOffice': '$17,901,029'},
#  {'imdbID': 'tt10915286',
#   'Title': 'Tell Me Who I Am',
#   'imdbRating': '6.6',
#   'imdbVotes': '9',
#   'Metascore': 'N/A',
#   'Director': 'Ed Perkins',
#   'Genre': 'Documentary, Drama, Mystery',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt0077651',
#   'Title': 'Halloween',
#   'imdbRating': '7.8',
#   'imdbVotes': '210,029',
#   'Metascore': '81',
#   'Director': 'John Carpenter',
#   'Genre': 'Horror, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6398184',
#   'Title': 'Downton Abbey',
#   'imdbRating': '7.7',
#   'imdbVotes': '14,748',
#   'Metascore': '64',
#   'Director': 'Michael Engler',
#   'Genre': 'Drama, Romance',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt5052448',
#   'Title': 'Get Out',
#   'imdbRating': '7.7',
#   'imdbVotes': '421,587',
#   'Metascore': '84',
#   'Director': 'Jordan Peele',
#   'Genre': 'Horror, Mystery, Thriller',
#   'BoxOffice': '$175,428,355'},
#  {'imdbID': 'tt2584384',
#   'Title': 'Jojo Rabbit',
#   'imdbRating': '7.1',
#   'imdbVotes': '1,150',
#   'Metascore': '52',
#   'Director': 'Taika Waititi',
#   'Genre': 'Comedy, Drama, War',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt0409459',
#   'Title': 'Watchmen',
#   'imdbRating': '7.6',
#   'imdbVotes': '461,098',
#   'Metascore': '56',
#   'Director': 'Zack Snyder',
#   'Genre': 'Action, Drama, Mystery, Sci-Fi',
#   'BoxOffice': '$107,453,620'},
#  {'imdbID': 'tt1156398',
#   'Title': 'Zombieland',
#   'imdbRating': '7.6',
#   'imdbVotes': '469,668',
#   'Metascore': '73',
#   'Director': 'Ruben Fleischer',
#   'Genre': 'Adventure, Comedy, Horror, Sci-Fi',
#   'BoxOffice': '$75,590,286'},
#  {'imdbID': 'tt6320628',
#   'Title': 'Spider-Man: Far from Home',
#   'imdbRating': '7.6',
#   'imdbVotes': '221,516',
#   'Metascore': '69',
#   'Director': 'Jon Watts',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6146586',
#   'Title': 'John Wick: Chapter 3 - Parabellum',
#   'imdbRating': '7.6',
#   'imdbVotes': '186,360',
#   'Metascore': '73',
#   'Director': 'Chad Stahelski',
#   'Genre': 'Action, Crime, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt9243946',
#   'Title': 'El Camino: A Breaking Bad Movie',
#   'imdbRating': '7.7',
#   'imdbVotes': '81,896',
#   'Metascore': '72',
#   'Director': 'Vince Gilligan',
#   'Genre': 'Action, Drama',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt8526872',
#   'Title': 'Dolemite Is My Name',
#   'imdbRating': '6.5',
#   'imdbVotes': '297',
#   'Metascore': '74',
#   'Director': 'Craig Brewer',
#   'Genre': 'Biography, Comedy, Drama',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6521876',
#   'Title': 'Jay and Silent Bob Reboot',
#   'imdbRating': '8.0',
#   'imdbVotes': '265',
#   'Metascore': 'N/A',
#   'Director': 'Kevin Smith',
#   'Genre': 'Comedy',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt0094721',
#   'Title': 'Beetlejuice',
#   'imdbRating': '7.5',
#   'imdbVotes': '236,167',
#   'Metascore': '70',
#   'Director': 'Tim Burton',
#   'Genre': 'Comedy, Fantasy',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt0385887',
#   'Title': 'Motherless Brooklyn',
#   'imdbRating': '7.9',
#   'imdbVotes': '982',
#   'Metascore': '62',
#   'Director': 'Edward Norton',
#   'Genre': 'Crime, Drama',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt2066051',
#   'Title': 'Rocketman',
#   'imdbRating': '7.4',
#   'imdbVotes': '68,866',
#   'Metascore': '69',
#   'Director': 'Dexter Fletcher',
#   'Genre': 'Biography, Drama, Music, Musical',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1560220',
#   'Title': 'Zombieland: Double Tap',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Ruben Fleischer',
#   'Genre': 'Action, Comedy, Horror',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt8772262',
#   'Title': 'Midsommar',
#   'imdbRating': '7.4',
#   'imdbVotes': '50,296',
#   'Metascore': '72',
#   'Director': 'Ari Aster',
#   'Genre': 'Drama, Horror, Mystery, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1950186',
#   'Title': 'Ford v Ferrari',
#   'imdbRating': '7.4',
#   'imdbVotes': '963',
#   'Metascore': '70',
#   'Director': 'James Mangold',
#   'Genre': 'Action, Biography, Drama, Sport',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1396484',
#   'Title': 'It',
#   'imdbRating': '7.4',
#   'imdbVotes': '392,735',
#   'Metascore': '69',
#   'Director': 'Andy Muschietti',
#   'Genre': 'Horror',
#   'BoxOffice': '$326,898,358'},
#  {'imdbID': 'tt7784604',
#   'Title': 'Hereditary',
#   'imdbRating': '7.3',
#   'imdbVotes': '172,886',
#   'Metascore': '87',
#   'Director': 'Ari Aster',
#   'Genre': 'Drama, Horror, Mystery, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt7549996',
#   'Title': 'Judy',
#   'imdbRating': '7.2',
#   'imdbVotes': '3,790',
#   'Metascore': '66',
#   'Director': 'Rupert Goold',
#   'Genre': 'Biography, Drama, History, Romance',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6139732',
#   'Title': 'Aladdin',
#   'imdbRating': '7.1',
#   'imdbVotes': '151,546',
#   'Metascore': '53',
#   'Director': 'Guy Ritchie',
#   'Genre': 'Adventure, Family, Fantasy, Musical, Romance',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt2527336',
#   'Title': 'Star Wars: The Last Jedi',
#   'imdbRating': '7.1',
#   'imdbVotes': '476,677',
#   'Metascore': '85',
#   'Director': 'Rian Johnson',
#   'Genre': 'Action, Adventure, Fantasy, Sci-Fi',
#   'BoxOffice': '$619,117,636'},
#  {'imdbID': 'tt7798634',
#   'Title': 'Ready or Not',
#   'imdbRating': '7.1',
#   'imdbVotes': '18,012',
#   'Metascore': '64',
#   'Director': 'Matt Bettinelli-Olpin, Tyler Gillett',
#   'Genre': 'Comedy, Horror, Mystery, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt4777008',
#   'Title': 'Maleficent: Mistress of Evil',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Joachim Rønning',
#   'Genre': 'Adventure, Family, Fantasy',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6105098',
#   'Title': 'The Lion King',
#   'imdbRating': '7.1',
#   'imdbVotes': '102,621',
#   'Metascore': '55',
#   'Director': 'Jon Favreau',
#   'Genre': 'Animation, Adventure, Drama, Family, Musical',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt7984766',
#   'Title': 'The King',
#   'imdbRating': '6.5',
#   'imdbVotes': '400',
#   'Metascore': '67',
#   'Director': 'David Michôd',
#   'Genre': 'Biography, Drama, History, Romance, War',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1587310',
#   'Title': 'Maleficent',
#   'imdbRating': '7.0',
#   'imdbVotes': '311,641',
#   'Metascore': '56',
#   'Director': 'Robert Stromberg',
#   'Genre': 'Action, Adventure, Family, Fantasy, Romance',
#   'BoxOffice': '$190,871,149'},
#  {'imdbID': 'tt2935510',
#   'Title': 'Ad Astra',
#   'imdbRating': '7.0',
#   'imdbVotes': '52,852',
#   'Metascore': '80',
#   'Director': 'James Gray',
#   'Genre': 'Adventure, Drama, Mystery, Sci-Fi, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1477834',
#   'Title': 'Aquaman',
#   'imdbRating': '7.0',
#   'imdbVotes': '299,582',
#   'Metascore': '55',
#   'Director': 'James Wan',
#   'Genre': 'Action, Adventure, Fantasy, Sci-Fi',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt8079248',
#   'Title': 'Yesterday',
#   'imdbRating': '7.0',
#   'imdbVotes': '44,927',
#   'Metascore': '56',
#   'Director': 'Danny Boyle',
#   'Genre': 'Comedy, Fantasy, Music, Musical, Romance',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt8946378',
#   'Title': 'Knives Out',
#   'imdbRating': '7.6',
#   'imdbVotes': '397',
#   'Metascore': '84',
#   'Director': 'Rian Johnson',
#   'Genre': 'Comedy, Crime, Drama, Mystery, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt0101272',
#   'Title': 'The Addams Family',
#   'imdbRating': '6.9',
#   'imdbVotes': '117,124',
#   'Metascore': '57',
#   'Director': 'Barry Sonnenfeld',
#   'Genre': 'Comedy, Fantasy',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt0107120',
#   'Title': 'Hocus Pocus',
#   'imdbRating': '6.8',
#   'imdbVotes': '82,953',
#   'Metascore': 'N/A',
#   'Director': 'Kenny Ortega',
#   'Genre': 'Comedy, Family, Fantasy',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt7349950',
#   'Title': 'It: Chapter Two',
#   'imdbRating': '7.0',
#   'imdbVotes': '79,586',
#   'Metascore': '58',
#   'Director': 'Andy Muschietti',
#   'Genre': 'Drama, Fantasy, Horror',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt7430722',
#   'Title': 'War',
#   'imdbRating': '7.2',
#   'imdbVotes': '5,355',
#   'Metascore': 'N/A',
#   'Director': 'Siddharth Anand',
#   'Genre': 'Action, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt4263482',
#   'Title': 'The Witch',
#   'imdbRating': '6.8',
#   'imdbVotes': '164,697',
#   'Metascore': '83',
#   'Director': 'Robert Eggers',
#   'Genre': 'Horror, Mystery',
#   'BoxOffice': '$19,239,494'},
#  {'imdbID': 'tt6924650',
#   'Title': 'Midway',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Roland Emmerich',
#   'Genre': 'Action, Drama, History, War',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6823368',
#   'Title': 'Glass',
#   'imdbRating': '6.7',
#   'imdbVotes': '159,195',
#   'Metascore': '43',
#   'Director': 'M. Night Shyamalan',
#   'Genre': 'Drama, Sci-Fi, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1270797',
#   'Title': 'Venom',
#   'imdbRating': '6.7',
#   'imdbVotes': '304,804',
#   'Metascore': '35',
#   'Director': 'Ruben Fleischer',
#   'Genre': 'Action, Sci-Fi, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1206885',
#   'Title': 'Rambo: Last Blood',
#   'imdbRating': '6.8',
#   'imdbVotes': '17,078',
#   'Metascore': '26',
#   'Director': 'Adrian Grunberg',
#   'Genre': 'Action, Adventure, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt5503686',
#   'Title': 'Hustlers',
#   'imdbRating': '6.7',
#   'imdbVotes': '12,312',
#   'Metascore': '79',
#   'Director': 'Lorene Scafaria',
#   'Genre': 'Comedy, Crime, Drama, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6806448',
#   'Title': 'Fast & Furious Presents: Hobbs & Shaw',
#   'imdbRating': '6.7',
#   'imdbVotes': '74,896',
#   'Metascore': '60',
#   'Director': 'David Leitch',
#   'Genre': 'Action, Adventure',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1502407',
#   'Title': 'Halloween',
#   'imdbRating': '6.6',
#   'imdbVotes': '96,977',
#   'Metascore': '67',
#   'Director': 'David Gordon Green',
#   'Genre': 'Horror, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6450804',
#   'Title': 'Terminator: Dark Fate',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Tim Miller',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt2140507',
#   'Title': "The Current War: Director's Cut",
#   'imdbRating': '6.3',
#   'imdbVotes': '3,630',
#   'Metascore': '43',
#   'Director': 'Alfonso Gomez-Rejon',
#   'Genre': 'Biography, Drama, History',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1340138',
#   'Title': 'Terminator Genisys',
#   'imdbRating': '6.4',
#   'imdbVotes': '238,578',
#   'Metascore': '38',
#   'Director': 'Alan Taylor',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'BoxOffice': '$75,614,989'},
#  {'imdbID': 'tt5865326',
#   'Title': 'The Laundromat',
#   'imdbRating': '6.2',
#   'imdbVotes': '459',
#   'Metascore': '57',
#   'Director': 'Steven Soderbergh',
#   'Genre': 'Drama',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt4332232',
#   'Title': 'Fractured',
#   'imdbRating': '6.2',
#   'imdbVotes': '79',
#   'Metascore': 'N/A',
#   'Director': 'Brad Anderson',
#   'Genre': 'Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt3387520',
#   'Title': 'Scary Stories to Tell in the Dark',
#   'imdbRating': '6.4',
#   'imdbVotes': '18,402',
#   'Metascore': '61',
#   'Director': 'André Øvredal',
#   'Genre': 'Horror, Mystery, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt8110640',
#   'Title': 'In the Shadow of the Moon',
#   'imdbRating': '6.2',
#   'imdbVotes': '5,469',
#   'Metascore': '48',
#   'Director': 'Jim Mickle',
#   'Genre': 'Crime, Mystery, Sci-Fi, Thriller',
#   'BoxOffice': '$941,775'},
#  {'imdbID': 'tt8364368',
#   'Title': 'Crawl',
#   'imdbRating': '6.3',
#   'imdbVotes': '23,610',
#   'Metascore': '60',
#   'Director': 'Alexandre Aja',
#   'Genre': 'Action, Drama, Horror, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt7734218',
#   'Title': 'Stuber',
#   'imdbRating': '6.2',
#   'imdbVotes': '9,714',
#   'Metascore': '42',
#   'Director': 'Michael Dowse',
#   'Genre': 'Action, Comedy, Crime, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt9398640',
#   'Title': 'Between Two Ferns: The Movie',
#   'imdbRating': '6.1',
#   'imdbVotes': '15,906',
#   'Metascore': '59',
#   'Director': 'Scott Aukerman',
#   'Genre': 'Comedy',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1386697',
#   'Title': 'Suicide Squad',
#   'imdbRating': '6.0',
#   'imdbVotes': '547,371',
#   'Metascore': '40',
#   'Director': 'David Ayer',
#   'Genre': 'Action, Adventure, Fantasy, Sci-Fi',
#   'BoxOffice': '$325,021,779'},
#  {'imdbID': 'tt1620981',
#   'Title': 'The Addams Family',
#   'imdbRating': '5.8',
#   'imdbVotes': '1,513',
#   'Metascore': '45',
#   'Director': 'Greg Tiernan, Conrad Vernon',
#   'Genre': 'Animation, Comedy, Family, Fantasy, Horror',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt5294518',
#   'Title': 'Eli',
#   'imdbRating': '5.9',
#   'imdbVotes': '4,660',
#   'Metascore': 'N/A',
#   'Director': 'Ciarán Foy',
#   'Genre': 'Horror',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6565702',
#   'Title': 'Dark Phoenix',
#   'imdbRating': '5.8',
#   'imdbVotes': '94,363',
#   'Metascore': '43',
#   'Director': 'Simon Kinberg',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1025100',
#   'Title': 'Gemini Man',
#   'imdbRating': '4.9',
#   'imdbVotes': '294',
#   'Metascore': '33',
#   'Director': 'Ang Lee',
#   'Genre': 'Action, Drama, Sci-Fi, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt8134742',
#   'Title': '3 from Hell',
#   'imdbRating': '6.0',
#   'imdbVotes': '2,020',
#   'Metascore': '50',
#   'Director': 'Rob Zombie',
#   'Genre': 'Horror',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt2283336',
#   'Title': 'Men in Black: International',
#   'imdbRating': '5.6',
#   'imdbVotes': '70,333',
#   'Metascore': '38',
#   'Director': 'F. Gary Gray',
#   'Genre': 'Action, Adventure, Comedy, Sci-Fi',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt4687108',
#   'Title': 'In the Tall Grass',
#   'imdbRating': '5.7',
#   'imdbVotes': '3,418',
#   'Metascore': '46',
#   'Director': 'Vincenzo Natali',
#   'Genre': 'Drama, Horror, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt10039344',
#   'Title': 'Countdown',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Justin Dec',
#   'Genre': 'Horror, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt4126476',
#   'Title': 'After',
#   'imdbRating': '5.4',
#   'imdbVotes': '18,349',
#   'Metascore': '30',
#   'Director': 'Jenny Gage',
#   'Genre': 'Drama, Romance',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt7390646',
#   'Title': 'Black and Blue',
#   'imdbRating': '5.7',
#   'imdbVotes': '29',
#   'Metascore': 'N/A',
#   'Director': 'Deon Taylor',
#   'Genre': 'Action, Crime, Drama, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt5822564',
#   'Title': 'The Kitchen',
#   'imdbRating': '5.2',
#   'imdbVotes': '3,320',
#   'Metascore': '35',
#   'Director': 'Andrea Berloff',
#   'Genre': 'Action, Crime, Drama',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt9257484',
#   'Title': 'Rattlesnake',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Zak Hilditch',
#   'Genre': 'Drama, Horror, Mystery, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt5913798',
#   'Title': 'Wounds',
#   'imdbRating': '4.5',
#   'imdbVotes': '766',
#   'Metascore': '50',
#   'Director': 'Babak Anvari',
#   'Genre': 'Drama, Horror, Mystery, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt7721946',
#   'Title': 'Housefull 4',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Farhad Samji',
#   'Genre': 'Action, Comedy, Fantasy',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt2527338',
#   'Title': 'Star Wars: The Rise of Skywalker',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'J.J. Abrams',
#   'Genre': 'Action, Adventure, Fantasy, Sci-Fi',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1634106',
#   'Title': 'Bloodshot',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Dave Wilson',
#   'Genre': 'Action, Drama, Fantasy, Sci-Fi',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt7740510',
#   'Title': 'Antlers',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Scott Cooper',
#   'Genre': 'Horror',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt5033998',
#   'Title': "Charlie's Angels",
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Elizabeth Banks',
#   'Genre': 'Action, Adventure, Comedy',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt1877830',
#   'Title': 'The Batman',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Matt Reeves',
#   'Genre': 'Action, Crime, Drama, Sci-Fi',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt7713068',
#   'Title': 'Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Cathy Yan',
#   'Genre': 'Action, Adventure, Crime',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt4520988',
#   'Title': 'Frozen II',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Chris Buck, Jennifer Lee',
#   'Genre': 'Animation, Adventure, Comedy, Family, Fantasy, Musical',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt8623904',
#   'Title': 'Last Christmas',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Paul Feig',
#   'Genre': 'Comedy, Drama, Romance',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt10665338',
#   'Title': 'Halloween Kills',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'David Gordon Green',
#   'Genre': 'Horror, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt3480822',
#   'Title': 'Black Widow',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Cate Shortland',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt2382320',
#   'Title': 'No Time to Die',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Cary Joji Fukunaga',
#   'Genre': 'Action, Adventure, Thriller',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt10362466',
#   'Title': 'After We Collided',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Roger Kumble',
#   'Genre': 'Drama, Romance',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6394270',
#   'Title': 'Bombshell',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Jay Roach',
#   'Genre': 'Biography, Drama',
#   'BoxOffice': 'N/A'},
#  {'imdbID': 'tt6673612',
#   'Title': 'The Voyage of Doctor Dolittle',
#   'imdbRating': 'N/A',
#   'imdbVotes': 'N/A',
#   'Metascore': 'N/A',
#   'Director': 'Stephen Gaghan',
#   'Genre': 'Comedy, Family, Fantasy',
#   'BoxOffice': 'N/A'}]

# %%
db_name = 'Movies'

def create_database(cursor, database):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)
        
    #above is python code that is going to connect to SQL queries w/ cursor.execute
    #cursor knows to take SQL query and send it to server to run code
    #try & except is error handling within python
    #format takes in database and tries to run it
    #if failed, except will tell you error and why it failed
    #above is a function to create a database

    try:
        cursor.execute("USE {}".format(db_name))
    except mysql.connector.Error as err:
        print("Database {} does not exists.".format(db_name))
        if err.errno == errorcode.ER_BAD_DB_ERROR:
            create_database(cursor, db_name)
            print("Database {} created successfully.".format(db_name))
            cnx.database = db_name
        else:
            print(err)
            exit(1)

# %%
db_name
# Out:
# 'Movies'

# %%
cursor = cnx.cursor()
TABLES = {} #use dictionary to save diff create statements for each table
TABLES['IMDb_Top_100'] = (
    "  CREATE TABLE IMDb_Top_100 ("
    "  movie_id varchar(11) NOT NULL primary key,"
    "  movie_name varchar(200) not null,"
    "  imdb_rating float(2) not null,"
    "  imdb_total_votes float(7) not null,"
    "  metascore int(3) not null,"
    "  director varchar(100) not null,"
    "  genre varchar(255) not null,"
    "  box_office int(20) not null"

     
") ENGINE=InnoDB")

for table_name in TABLES:
    table_description = TABLES[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")
# Out:
# Creating table IMDb_Top_100: OK

# %%
# Making tuple list

movies_lists = []
for movie in imdb_db:
    movies_tuples = (movie['imdbID'], movie['Title'], movie['imdbRating'], movie['imdbVotes'], movie['Metascore'], movie['Director'], movie['Genre'], movie['BoxOffice'])
    movies_lists.append(movies_tuples)

    insert_stmt = "INSERT INTO IMDb_Top_100 (movie_id, movie_name, imdb_rating, imdb_total_votes, metascore, director, genre, box_office) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
    cursor.execute(insert_stmt, movies_tuples)
    cnx.commit()
    time.sleep(1)

# %%
movies_lists

# %%
movies_lists[2]

# %%
insert_stmt = "INSERT INTO IMDb_Top_100 (movie_id, movie_name, imdb_rating, imdb_total_votes, metascore, director, genre, box_office) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
cursor.execute(insert_stmt, movies_tuples)
cnx.commit()
time.sleep(1)
