# %% [markdown]
# # Imports

# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns     ###didnt really use, can remove
import json
import time
import mysql.connector 
from mysql.connector import errorcode
import config_project1

# %% [markdown]
# # Connecting to MySQL

# %%
cnx = mysql.connector .connect(
    host = config_project1.host,
    user = config_project1.user,
    passwd = config_project1.password,
    database = 'Movies'
)
cursor = cnx.cursor()

# %% [markdown]
# # Web Scrapping for Top 250 and Lowest 100 movies

# %%
# Top 250 rated movies
URL1 = "https://www.imdb.com/chart/top?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=4da9d9a5-d299-43f2-9c53-f0efa18182cd&pf_rd_r=BYZ5JEW58AJEXDTT58SP&pf_rd_s=right-4&pf_rd_t=15506&pf_rd_i=topenglish&ref_=chttentp_ql_3"
r = requests.get(URL1)

# Bottom 100 rated movies
URL2 = "https://www.imdb.com/chart/bottom?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=4da9d9a5-d299-43f2-9c53-f0efa18182cd&pf_rd_r=GNJSYA49KTF016PSH5AD&pf_rd_s=right-4&pf_rd_t=15506&pf_rd_i=topenglish&ref_=chttentp_ql_8"
r2 = requests.get(URL2) 

# Combining both urls into one 'soup'
soup = BeautifulSoup(r.content + r2.content, 'html.parser')

#printing in sytlized text to read easier
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
#   <style>
#    body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#   </style>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    IMDb Top 250 - IMDb
#   </title>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <link href="https://www.imdb.com/chart/top" rel="canonical"/>
#   <meta content="http://www.imdb.com/chart/top" property="og:url">
#    <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadIcons", {wb: 1});
#     }
#    </script>
#    <script>
#     (function(t){ (t.events = t.events || {})["csm_head_pre_icon"] = new Date().getTime(); })(IMDbTimer);
#    </script>
#    <link href="https://m.media-amazon.com/images/G/01/imdb/images/safari-favicon-517611381._CB483525257_.svg" mask="" rel="icon" sizes="any"/>
#    <link href="https://m.media-amazon.com/images/G/01/imdb/images/favicon-2165806970._CB470047330_.ico" rel="icon" type="image/ico">
#     <meta content="#000000" name="theme-color">
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/desktop-favicon-2165806970._CB484110913_.ico" rel="shortcut icon" type="image/x-icon"/>
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-4151659188._CB483525313_.png" rel="apple-touch-icon"/>
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-76x76-53536248._CB484146059_.png" rel="apple-touch-icon" sizes="76x76"/>
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-120x120-2442878471._CB483525250_.png" rel="apple-touch-icon" sizes="120x120"/>
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/mobile/apple-touch-icon-web-152x152-1475823641._CB470042035_.png" rel="apple-touch-icon" sizes="152x152"/>
#      <link href="https://m.media-amazon.com/images/G/01/imdb/images/imdbsearch-3349468880._CB470047351_.xml" rel="search" title="IMDb" type="application/opensearchdescription+xml">
#       <script>
#        (function(t){ (t.events = t.events || {})["csm_head_post_icon"] = new Date().getTime(); })(IMDbTimer);
#       </script>
#       <script>
#        if (typeof uet == 'function') {
#       uet("be", "LoadIcons", {wb: 1});
#     }
#       </script>
#       <script>
#        if (typeof uex == 'function') {
#       uex("ld", "LoadIcons", {wb: 1});
#     }
#       </script>
#       <title>
#        IMDb Top Rated Movies
#       </title>
#       <meta content="Check out the top 250 movies as rated by IMDb users" name="description">
#        <meta content="index,follow" name="robots"/>
#        <meta content="Check out the top 250 movies as rated by IMDb users" itemprop="description"/>
#        <meta content="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg" itemprop="image"/>
#        <meta content="IMDb Top Rated Movies" itemprop="name"/>
#        <meta content="chart" property="pageType"/>
#        <meta content="top250movie" property="subpageType"/>
#        <meta content="MTA9QJQE1G2PHWJ44775" name="requestId"/>
#        <meta content="115109575169727" property="fb:app_id"/>
#        <meta content="website" property="og:type"/>
#        <meta content="Check out the top 250 movies as rated by IMDb users" property="og:description"/>
#        <meta content="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg" property="og:image"/>
#        <meta content="IMDb" property="og:site_name"/>
#        <meta content="IMDb Top Rated Movies" property="og:title"/>
#        <meta content="Check out the top 250 movies as rated by IMDb users" name="twitter:description"/>
#        <meta content="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_.jpg" name="twitter:image">
#         <meta content="summary_large_image" name="twitter:card"/>
#         <meta content="@IMDb" name="twitter:site"/>
#         <meta content="IMDb Top Rated Movies" name="twitter:title">
#          <script>
#           if (typeof uet == 'function') {
#       uet("bb", "LoadCSS", {wb: 1});
#     }
#          </script>
#          <script>
#           (function(t){ (t.events = t.events || {})["csm_head_pre_css"] = new Date().getTime(); })(IMDbTimer);
#          </script>
#          <!-- h=ics-c52xl-4-1e-523f8717.us-east-1 -->
#          <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/consumer-2-column-2498110331._CB449764127_.css" rel="stylesheet" type="text/css">
#           <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/other-3053529766._CB440616809_.css" rel="stylesheet" type="text/css">
#            <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/seenWidget-1193206528._CB461844790_.css" rel="stylesheet" type="text/css">
#             <link href="https://m.media-amazon.com/images/G/01/imdb/css/collections/watchlistButton-197279306._CB482060654_.css" rel="stylesheet" type="text/css"/>
#             <noscript>
#              <link href="https://m.media-amazon.com/images/G/01/imdb/css/wheel/nojs-2827156349._CB470041026_.css" rel="stylesheet" type="text/css"/>
#             </noscript>
#             <script>
#              (function(t){ (t.events = t.events || {})["csm_head_post_css"] = new Date().getTime(); })(IMDbTimer);
#             </script>
#             <script>
#              if (typeof uet == 'function') {
#       uet("be", "LoadCSS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uex == 'function') {
#       uex("ld", "LoadCSS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uet == 'function') {
#       uet("bb", "LoadJS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uet == 'function') {
#       uet("bb", "LoadHeaderJS", {wb: 1});
#     }
#             </script>
#             <script>
#              (function(t){ (t.events = t.events || {})["csm_head_pre_ads"] = new Date().getTime(); })(IMDbTimer);
#             </script>
#             <script type="text/javascript">
#              // ensures js doesn't die if ads service fails.
#             // Note that we need to define the js here, since ad js is being rendered inline after this.
#             (function(f) {
#                 // Fallback javascript, when the ad Service call fails.
#
#                 if((window.csm == null || window.generic == null || window.consoleLog == null)) {
#                     if (window.console && console.log) {
#                         console.log("one or more of window.csm, window.generic or window.consoleLog has been stubbed...");
#                     }
#                 }
#
#                 window.csm = window.csm || { measure:f, record:f, duration:f, listen:f, metrics:{} };
#                 window.generic = window.generic || { monitoring: { start_timing: f, stop_timing: f } };
#                 window.consoleLog = window.consoleLog || f;
#             })(function() {});
#             </script>
#             <script type="text/javascript">
#              if (!window.RadWidget) {
#         window.RadWidget = {
#             registerReactWidgetInstance: function(input) {
#                 window.RadWidget[input.widgetName] = window.RadWidget[input.widgetName] || [];
#                 window.RadWidget[input.widgetName].push({
#                     id: input.instanceId,
#                     props: JSON.stringify(input.model)
#                 })
#             },
#             getReactWidgetInstances: function(widgetName) {
#                 return window.RadWidget[widgetName] || []
#             }
#         };
#     }
#             </script>
#             <script>
#              if ('csm' in window) {
#       csm.measure('csm_head_delivery_finished');
#     }
#             </script>
#             <script>
#              if (typeof uet == 'function') {
#       uet("be", "LoadHeaderJS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uex == 'function') {
#       uex("ld", "LoadHeaderJS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uet == 'function') {
#       uet("be", "LoadJS", {wb: 1});
#     }
#             </script>
#             <script>
#              if (typeof uex == 'function') {
#       uex("ld", "LoadJS", {wb: 1});
#     }
#             </script>
#            </link>
#           </link>
#          </link>
#         </meta>
#        </meta>
#       </meta>
#      </link>
#     </meta>
#    </link>
#   </meta>
#  </head>
#  <body class="fixed" id="styleguide-v2">
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb");
#     }
#   </script>
#   <script>
#    if ('csm' in window) {
#       csm.measure('csm_body_delivery_started');
#     }
#   </script>
#   <div id="wrapper">
#    <div class="redesign" id="root">
#     <div class="navbarSprite" id="nb20">
#      <div id="supertab">
#       <!-- no content received for slot: top_ad -->
#      </div>
#      <script>
#       if (typeof uet == 'function') {
#       uet("ns");
#     }
#      </script>
#      <div class="navbarSprite" id="navbar">
#       <noscript>
#        <style>
#         #pagecontent{margin-top:-17px}
#        </style>
#       </noscript>
#       <span id="home_img_holder">
#        <a class="navbarSprite" href="/" id="home_img" title="Home">
#        </a>
#        <span class="alt_logo">
#         <a href="/" title="Home">
#          IMDb
#         </a>
#        </span>
#       </span>
#       <form action="/find" class="nav-searchbar-inner" id="navbar-form" method="get">
#        <div id="nb_search">
#         <noscript>
#          <div id="more_if_no_javascript">
#           <a href="/search/">
#            More
#           </a>
#          </div>
#         </noscript>
#         <button aria-label="Submit Search" class="primary btn" id="navbar-submit-button" type="submit">
#          <div class="magnifyingglass navbarSprite">
#          </div>
#         </button>
#         <input name="ref_" type="hidden" value="nv_sr_fn"/>
#         <input autocomplete="off" id="navbar-query" name="q" placeholder="Find Movies, TV shows, Celebrities and more..." type="text" value=""/>
#         <div class="quicksearch_dropdown_wrapper">
#          <select class="quicksearch_dropdown navbarSprite hidden" id="quicksearch" name="s">
#           <option value="all">
#            All
#           </option>
#           <option value="tt">
#            Titles
#           </option>
#           <option value="ep">
#            TV Episodes
#           </option>
#           <option value="nm">
#            Names
#           </option>
#           <option value="co">
#            Companies
#           </option>
#           <option value="kw">
#            Keywords
#           </option>
#          </select>
#         </div>
#         <div cel_widget_id="SuggestionSearchWidget" class="celwidget" id="navbar-suggestionsearch">
#         </div>
#        </div>
#       </form>
#       <div id="megaMenu">
#        <ul class="main_nav" id="consumer_main_nav">
#         <li class="spacer">
#         </li>
#         <li class="css_nav_item freediveNavMenu" id="navFreediveMenu">
#          <p class="navCategory">
#           <a href="/tv/">
#            Watch Now For Free
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="sub_nav freediveNavMenu__container" id="navMenu0">
#           <h5>
#            <span class="headerText">
#             Featured
#            </span>
#            <span class="seeAll">
#             <a href="/tv/">
#              Browse more titles »
#             </a>
#            </span>
#           </h5>
#           <ul class="freediveNavMenu__list" id="freediveNavMenuList">
#           </ul>
#          </div>
#          <script>
#           if (!('imdb' in window)) { window.imdb = {}; }
#                     window.imdb.freediveTitleData = [
#                              {
#                                 imageUrl: "https://m.media-amazon.com/images/M/MV5BZDAwYTlhMDEtNTg0OS00NDY2LWJjOWItNWY3YTZkM2UxYzUzXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY209_CR4,0,140,209_AL_.jpg",
#                                 link: "https://www.imdb.com/tv/watch/tt0110413",
#                                 title: "Léon: The Professional"
#                              },
#                              {
#                                 imageUrl: "https://m.media-amazon.com/images/M/MV5BMzUzNDM2NzM2MV5BMl5BanBnXkFtZTgwNTM3NTg4OTE@._V1_SY209_CR0,0,140,209_AL_.jpg",
#                                 link: "https://www.imdb.com/tv/watch/tt3783958",
#                                 title: "La La Land"
#                              },
#                              {
#                                 imageUrl: "https://m.media-amazon.com/images/M/MV5BNzk1MjU3MDQyMl5BMl5BanBnXkFtZTcwNjc1OTM2MQ@@._V1_SX140_AL_.jpg",
#                                 link: "https://www.imdb.com/tv/watch/tt0114388",
#                                 title: "Sense and Sensibility"
#                              },
#                     ];
#          </script>
#         </li>
#         <li class="spacer">
#         </li>
#         <li class="css_nav_item" id="navTitleMenu">
#          <p class="navCategory">
#           <a href="/movies-in-theaters/">
#            Movies
#           </a>
#           ,
#           <a href="/chart/toptv/">
#            TV
#           </a>
#           <br/>
#           &amp;
#           <a href="/showtimes/">
#            Showtimes
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="sub_nav" id="navMenu1">
#           <div id="titleMenuImage" style="background: url('https://ia.media-imdb.com/images/M/MV5BMTY2MTM0Nzk0N15BMl5BanBnXkFtZTgwMzMzODgwNzE@._UY330_CR90,10,410,315_.jpg')">
#            <a class="fallback" href="/title/tt3170832/?ref_=nv_mv_dflt_1" title="                            Room
# , #157 on IMDb Top Rated Movies">
#            </a>
#            <div class="overlay">
#             <p>
#              <a href="/title/tt3170832/?ref_=nv_mv_dflt_2" id="titleMenuImageClick">
#               <strong>
#                Room
#               </strong>
#               (2015)
#              </a>
#              <br/>
#              <a href="/chart/top?ref_=nv_mv_dflt_3" id="titleMenuImageSecondaryClick">
#               #
#               <strong>
#                157
#               </strong>
#               on IMDb Top Rated Movies
#              </a>
#              »
#             </p>
#            </div>
#           </div>
#           <div class="subNavListContainer">
#            <h5>
#             MOVIES
#            </h5>
#            <ul>
#             <li>
#              <a href="/movies-in-theaters/">
#               In Theaters
#              </a>
#             </li>
#             <li>
#              <a href="/showtimes/">
#               Showtimes &amp; Tickets
#              </a>
#             </li>
#             <li>
#              <a href="/trailers/">
#               Latest Trailers
#              </a>
#             </li>
#             <li>
#              <a href="/movies-coming-soon/">
#               Coming Soon
#              </a>
#             </li>
#             <li>
#              <a href="/calendar/">
#               Release Calendar
#              </a>
#             </li>
#             <li>
#              <a href="/chart/top">
#               Top Rated Movies
#              </a>
#             </li>
#             <li>
#              <a href="/india/top-rated-indian-movies">
#               Top Rated Indian Movies
#              </a>
#             </li>
#             <li>
#              <a href="/chart/moviemeter">
#               Most Popular Movies
#              </a>
#             </li>
#            </ul>
#            <h5>
#             CHARTS &amp; TRENDS
#            </h5>
#            <ul>
#             <li>
#              <a href="/chart/">
#               Box Office
#              </a>
#             </li>
#             <li>
#              <a href="/search/title?count=100&amp;groups=oscar_best_picture_winners&amp;sort=year,desc">
#               Oscar Winners
#              </a>
#             </li>
#             <li>
#              <a href="/genre/">
#               Most Popular by Genre
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="subNavListContainer">
#            <h5>
#             TV &amp; VIDEO
#            </h5>
#            <ul>
#             <li>
#              <a href="/chart/toptv/">
#               Top Rated TV Shows
#              </a>
#             </li>
#             <li>
#              <a href="/chart/tvmeter">
#               Most Popular TV Shows
#              </a>
#             </li>
#             <li>
#              <a href="/sections/dvd/">
#               DVD &amp; Blu-Ray
#              </a>
#             </li>
#            </ul>
#            <h5>
#             SPECIAL FEATURES
#            </h5>
#            <ul>
#             <li>
#              <a href="/amazon-originals/">
#               Amazon Originals
#              </a>
#             </li>
#             <li>
#              <a href="/streaming/">
#               Streaming Now
#              </a>
#             </li>
#             <li>
#              <a href="/scary-good/">
#               Horror Guide
#              </a>
#             </li>
#             <li>
#              <a href="/imdbpicks/">
#               IMDb Picks
#              </a>
#             </li>
#             <li>
#              <a href="/originals/">
#               IMDb Original Series
#              </a>
#             </li>
#             <li>
#              <a href="/family-entertainment-guide/">
#               Family Movie/TV Guide
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#         <li class="spacer">
#         </li>
#         <li class="css_nav_item" id="navNameMenu">
#          <p class="navCategory">
#           <a href="/search/name?gender=male,female">
#            Celebs
#           </a>
#           ,
#           <a href="/awards-central/">
#            Events
#           </a>
#           <br/>
#           &amp;
#           <a href="/gallery/rg1859820288">
#            Photos
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="sub_nav" id="navMenu2">
#           <div id="nameMenuImage" style="background: url('https://ia.media-imdb.com/images/M/MV5BMjMwMTc1NDQ0N15BMl5BanBnXkFtZTcwNjkzMzMzOQ@@._V1._SX430_CR100,10,250,315_.jpg')">
#            <a class="fallback" href="/name/nm0000129/?ref_=nv_cel_dflt_1" title="Tom Cruise, #92 on STARmeter">
#            </a>
#            <div class="overlay">
#             <p>
#              <a href="/name/nm0000129/?ref_=nv_cel_dflt_2" id="nameAdClick">
#               <strong>
#                Tom Cruise
#               </strong>
#              </a>
#              »
#              <br/>
#              #
#              <strong>
#               92
#              </strong>
#              on STARmeter
#             </p>
#            </div>
#           </div>
#           <div class="subNavListContainer">
#            <h5>
#             CELEBS
#            </h5>
#            <ul>
#             <li>
#              <a href="/search/name?birth_monthday=11-05&amp;refine=birth_monthday">
#               Born Today
#              </a>
#             </li>
#             <li>
#              <a href="/news/celebrity">
#               Celebrity News
#              </a>
#             </li>
#             <li>
#              <a href="/search/name?gender=male,female">
#               Most Popular Celebs
#              </a>
#             </li>
#            </ul>
#            <h5>
#             PHOTOS
#            </h5>
#            <ul>
#             <li>
#              <a href="/gallery/rg1859820288">
#               Latest Stills
#              </a>
#             </li>
#             <li>
#              <a href="/gallery/rg1624939264">
#               Latest Posters
#              </a>
#             </li>
#             <li>
#              <a href="/gallery/rg1641716480">
#               Photos We Love
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="subNavListContainer">
#            <h5>
#             EVENTS
#            </h5>
#            <ul>
#             <li>
#              <a href="/awards-central/">
#               Awards Central
#              </a>
#             </li>
#             <li>
#              <a href="/festival-central/">
#               Festival Central
#              </a>
#             </li>
#             <li>
#              <a href="/oscars/">
#               Oscars
#              </a>
#             </li>
#             <li>
#              <a href="/golden-globes/">
#               Golden Globes
#              </a>
#             </li>
#             <li>
#              <a href="/sundance/">
#               Sundance
#              </a>
#             </li>
#             <li>
#              <a href="/cannes/">
#               Cannes
#              </a>
#             </li>
#             <li>
#              <a href="/nycc/">
#               New York Comic Con
#              </a>
#             </li>
#             <li>
#              <a href="/comic-con/">
#               San Diego Comic-Con
#              </a>
#             </li>
#             <li>
#              <a href="/emmys/">
#               Emmy Awards
#              </a>
#             </li>
#             <li>
#              <a href="/venice/">
#               Venice Film Festival
#              </a>
#             </li>
#             <li>
#              <a href="/toronto/">
#               Toronto Film Festival
#              </a>
#             </li>
#             <li>
#              <a href="/festival-central/tribeca">
#               Tribeca
#              </a>
#             </li>
#             <li>
#              <a href="/event/all/">
#               All Events
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#         <li class="spacer">
#         </li>
#         <li class="css_nav_item" id="navNewsMenu">
#          <p class="navCategory">
#           <a href="/news/top">
#            News
#           </a>
#           &amp;
#           <br/>
#           <a href="/czone/">
#            Community
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="sub_nav" id="navMenu3">
#           <div id="latestHeadlines">
#            <div class="subNavListContainer">
#             <h5>
#              LATEST HEADLINES
#             </h5>
#             <ul class="ipl-simple-list">
#              <li class="news_item">
#               <a href="/news/ni62676041">
#                ‘Billions’: Julianna Margulies &amp; Carey Stoll Join Season 5 Cast Of Showtime Drama
#               </a>
#               <br/>
#               <small>
#                <span>
#                 05 November 2019
#                </span>
#                <span>
#                 |
#                </span>
#                <span>
#                 Deadline
#                </span>
#               </small>
#              </li>
#              <li class="news_item">
#               <a href="/news/ni62676040">
#                Amazon Orders 2 Seasons Of Adult Animated Series ‘Critical Role: The Legend Of Vox Machina’ As Part Of First-Look Deal
#               </a>
#               <br/>
#               <small>
#                <span>
#                 05 November 2019
#                </span>
#                <span>
#                 |
#                </span>
#                <span>
#                 Deadline
#                </span>
#               </small>
#              </li>
#              <li class="news_item">
#               <a href="/news/ni62675013">
#                ‘Fantastic Beasts 3’ Finally Moves Forward With Filming
#               </a>
#               <br/>
#               <small>
#                <span>
#                 04 November 2019
#                </span>
#                <span>
#                 |
#                </span>
#                <span>
#                 Variety - Film News
#                </span>
#               </small>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="subNavListContainer">
#            <h5>
#             NEWS
#            </h5>
#            <ul>
#             <li>
#              <a href="/news/top">
#               Top News
#              </a>
#             </li>
#             <li>
#              <a href="/news/movie">
#               Movie News
#              </a>
#             </li>
#             <li>
#              <a href="/news/tv">
#               TV News
#              </a>
#             </li>
#             <li>
#              <a href="/news/celebrity">
#               Celebrity News
#              </a>
#             </li>
#             <li>
#              <a href="/news/indie">
#               Indie News
#              </a>
#             </li>
#            </ul>
#            <h5>
#             COMMUNITY
#            </h5>
#            <ul>
#             <li>
#              <a href="/czone/">
#               Contributor Zone
#              </a>
#             </li>
#             <li>
#              <a href="/poll/">
#               Polls
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#         <li class="spacer">
#         </li>
#         <li class="css_nav_item" id="navWatchlistMenu">
#          <p class="navCategory singleLine watchlist">
#           <a href="/list/watchlist">
#            Watchlist
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="sub_nav" id="navMenu4">
#           <h5>
#            YOUR WATCHLIST
#           </h5>
#           <ul id="navWatchlist">
#           </ul>
#           <script>
#            if (!('imdb' in window)) { window.imdb = {}; }
#     window.imdb.watchlistTeaserData = [
#                 {
#                         href : "/list/watchlist",
#                 src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot1_logged_out._CB484021159_.jpg"
#                 },
#                 {
#                     href : "/search/title?count=100&title_type=feature,tv_series",
#                 src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot2_popular._CB484021159_.jpg"
#                 },
#                 {
#                     href : "/chart/top",
#                 src : "https://m.media-amazon.com/images/G/01/wprs/images/navbar/watchlist_slot3_top250._CB484021159_.jpg"
#                 }
#     ];
#           </script>
#          </div>
#         </li>
#         <li class="spacer">
#         </li>
#        </ul>
#       </div>
#       <div id="nb_extra">
#        <ul class="main_nav" id="nb_extra_nav">
#         <li class="css_nav_item" id="navProMenu">
#          <p class="navCategory">
#           <a href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm">
#            <img alt="IMDbPro Menu" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_logo_nb._CB484021162_.png"/>
#           </a>
#          </p>
#          <span class="downArrow">
#          </span>
#          <div class="imdb-pro-ad-shared imdb-pro-ad-redesign sub_nav" id="navMenuPro">
#           <a class="imdb-pro-ad__link" href="https://pro.imdb.com/login/ap?u=/login/lwa&amp;imdbPageAction=signUp&amp;rf=cons_nb_hm">
#            <div class="imdb-pro-ad__image" id="proAd">
#             <img alt="Go to IMDbPro" height="145" src="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png" srcset="https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user._CB484021156_.png 1x, https://m.media-amazon.com/images/G/01/wprs/images/navbar/imdbpro_navbar_menu_user_2x._CB484021157_.png 2x" width="127"/>
#            </div>
#            <section class="imdb-pro-ad__content">
#             <div class="imdb-pro-ad__title">
#              The essential resource for entertainment professionals
#             </div>
#             <p class="imdb-pro-ad__line">
#              Find industry contacts &amp; talent representation
#             </p>
#             <p class="imdb-pro-ad__line">
#              Access in-development titles not available on IMDb
#             </p>
#             <p class="imdb-pro-ad__line">
#              Get the latest news from leading industry trades
#             </p>
#             <p class="imdb-pro-ad__line">
#              Claim your page and control your brand across IMDb &amp; Amazon
#             </p>
#             <div class="imdb-pro-new__button">
#              <svg height="30px" version="1.1" viewbox="0 0 172 29" width="175px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#               <title>
#                TryIMDbProFree
#               </title>
#               <g fill="none" fill-rule="evenodd" id="tryIMDbProFree" stroke="none" stroke-width="1">
#                <rect fill="#F1C241" height="28" id="tryIMDbProFreeButton" rx="3" stroke="#A88734" width="170" x="1" y="1">
#                </rect>
#                <text id="tryIMDbProFreeText">
#                 <tspan x="33" y="19">
#                  Try IMDbPro Free
#                 </tspan>
#                </text>
#               </g>
#              </svg>
#             </div>
#            </section>
#           </a>
#          </div>
#         </li>
#         <li class="spacer">
#          <span class="ghost">
#           |
#          </span>
#         </li>
#         <li>
#          <a href="https://help.imdb.com/imdb">
#           Help
#          </a>
#         </li>
#         <li class="spacer">
#          <span class="ghost">
#           |
#          </span>
#         </li>
#         <li class="nb-social-links">
#          <a class="nb-social-links__link" href="/offsite/?page-action=fol_fb&amp;token=BCYtO1HKp_53BBdbAXbnbfJTyWuHQfBCxjHLQFQ4VspOSvSmZjNXYFzKycHqQog2hj0xIkTOQhmb%0D%0AaEh3xvn4GFRetGERdYW7j7kucziPkhcf-VvQ7eb03srFBWuudl4psSOKUJwOgXMrDovKlbyTLIpn%0D%0AcObNDyzsrNaR0KFYXql7F322DcBIUNygk07_jHCCjieS6KfIWb1G0NnxFzlhncKnsQ%0D%0A" target="_blank" title="Follow IMDb on Facebook">
#           <svg class="ipl-icon ipl-facebook-icon ipl-icon--inherit-color ipl-icon--inline" fill="#000000" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path d="
#            <path d="M0 0h24v24H0z" fill="none">
#            </path>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div id="nb_personal">
#        <ul class="main_nav" id="consumer_user_nav">
#         <li class="css_nav_menu no_arrow" id="navUserMenu">
#          <p class="navCategory singleLine">
#           <a class="signin-button" href="/registration/signin?u=https%3A//www.imdb.com/chart/top%3Fpf_rd_m%3DA2FGELUUNOQJNL%26pf_rd_p%3D4da9d9a5-d299-43f2-9c53-f0efa18182cd%26pf_rd_r%3DBYZ5JEW58AJEXDTT58SP%26pf_rd_s%3Dright-4%26pf_rd_t%3D15506%26pf_rd_i%3Dtopenglish%26ref_%3Dchttentp_ql_3" id="imdb-signin-link">
#            <span class="signin-imdb-text">
#             Sign in
#            </span>
#           </a>
#          </p>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <script>
#       if (typeof uet == 'function') {
#       uet("ne");
#     }
#      </script>
#      <!-- no content received for slot: navstrip -->
#      <!-- no content received for slot: injected_navstrip -->
#     </div>
#     <script>
#      if (typeof uet == 'function') {
#       uet("cf");
#     }
#     </script>
#     <div id="pagecontent">
#      <div class="pagecontent">
#       <!-- no content received for slot: injected_billboard -->
#      </div>
#      <div class="pagecontent" id="top-slot-wrapper">
#      </div>
#      <div class="pagecontent">
#       <div id="content-2-wide">
#        <div id="main">
#         <script>
#          if (typeof uet == 'function') {
#       uet("af");
#     }
#         </script>
#         <a name="slot_center-1">
#         </a>
#         <div class="article">
#          <script type="text/javascript">
#           if(typeof uet === 'function'){uet('bb','ChartWidget',{wb:1});}
#          </script>
#          <span class="ab_widget">
#           <input data-caller="chttp" id="seen-config" type="hidden"/>
#           <div class="seen-collection" data-collectionid="top-250">
#            <div class="article">
#             <h3>
#              IMDb Charts
#             </h3>
#             <div class="chart-social-sharing-widget" id="social-sharing-widget">
#             </div>
#             <h1 class="header">
#              Top Rated Movies
#             </h1>
#             <div class="byline">
#              Top 250 as rated by IMDb Users
#             </div>
#             <hr/>
#             <div class="lister">
#              <div>
#               <div class="nav">
#                <div class="controls float-right lister-activated">
#                 <label class="lister-sort-by-label" for="lister-sort-by-options">
#                  Sort by:
#                 </label>
#                 <select class="lister-sort-by" id="lister-sort-by-options" name="sort">
#                  <option selected="selected" value="rk:ascending">
#                   Ranking
#                  </option>
#                  <option value="ir:descending">
#                   IMDb Rating
#                  </option>
#                  <option value="us:descending">
#                   Release Date
#                  </option>
#                  <option value="nv:descending">
#                   Number of Ratings
#                  </option>
#                  <option value="ur:descending">
#                   Your Rating
#                  </option>
#                 </select>
#                 <span class="global-sprite lister-sort-reverse descending" data-sort="rk:desc">
#                 </span>
#                </div>
#                <div class="desc">
#                 Showing
#                 <span>
#                  250
#                 </span>
#                 Titles
#                </div>
#               </div>
#              </div>
#              <br class="clear"/>
#              <table class="chart full-width" data-caller-name="chart-top250movie">
#               <colgroup>
#                <col class="chartTableColumnPoster"/>
#                <col class="chartTableColumnTitle"/>
#                <col class="chartTableColumnIMDbRating"/>
#                <col class="chartTableColumnYourRating"/>
#                <col class="chartTableColumnWatchlistRibbon"/>
#               </colgroup>
#               <thead>
#                <tr>
#                 <th>
#                 </th>
#                 <th>
#                  Rank &amp; Title
#                 </th>
#                 <th>
#                  IMDb Rating
#                 </th>
#                 <th>
#                  Your Rating
#                 </th>
#                 <th>
#                 </th>
#                </tr>
#               </thead>
#               <tbody class="lister-list">
#                <tr>
#                 <td class="posterColumn">
#                  <span data-value="1" name="rk">
#                  </span>
#                  <span data-value="9.222213744856937" name="ir">
#                  </span>
#                  <span data-value="7.791552E11" name="us">
#                  </span>
#                  <span data-value="2155658" name="nv">
#                  </span>
#                  <span data-value="-1.777786255143063" name="ur">
#                  </span>
#                  <a href="/title/tt0111161/">
#                   <img alt="The Shawshank Redemption" height="67" src="https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UY67_CR0,0,45,67_AL_.jpg" width="45"/>
#                  </a>
#                 </td>
#                 <td class="titleColumn">
#                  1.
#                  <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">
#                   The Shawshank Redemption
#                  </a>
#                  <span class="secondaryInfo">
#                   (1994)
#                  </span>
#                 </td>
#                 <td class="ratingColumn imdbRating">
#                  <strong title="9.2 based on 2,155,658 user ratings">
#                   9.2
#                  </strong>
#                 </td>
#                 <td class="ratingColumn">
#                  <div class="seen-widget seen-widget-tt0111161 pending" data-titleid="tt0111161">
#                   <div class="boundary">
#                    <div class="popover">
#                     <span class="delete">
#                     </span>
#                     <ol>
#                      <li>
#                       1
#                       <li>
#                        2
#                        <li>
#                         3
#                         <li>
#                          4
#                          <li>
#                           5
#                           <li>
#                            6
#                            <li>
#                             7
#                             <li>
#                              8
#                              <li>
#                               9
#                               <li>
#                                10
#                               </li>
#                              </li>
#                             </li>
#                            </li>
#                           </li>
#                          </li>
#                         </li>
#                        </li>
#                       </li>
#                      </li>
#                     </ol>
#                    </div>
#                   </div>
#                   <div class="inline">
#                    <div class="pending">
#                    </div>
#                    <div class="unseeable">
#                     NOT YET RELEASED
#                    </div>
#                    <div class="unseen">
#                    </div>
#                    <div class="rating">
#                    </div>
#                    <div class="seen">
#                     Seen
#                    </div>
#                   </div>
#                  </div>
#                 </td>
#                 <td class="watchlistColumn">
#                  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0111161">
#                  </div>
#                 </td>
#                </tr>
#                <tr>
#                 <td class="posterColumn">
#                  <span data-value="2" name="rk">
#                  </span>
#                  <span data-value="9.148933084118038" name="ir">
#                  </span>
#                  <span data-value="6.93792E10" name="us">
#                  </span>
#                  <span data-value="1479253" name="nv">
#                  </span>
#                  <span data-value="-1.8510669158819617" name="ur">
#                  </span>
#                  <a href="/title/tt0068646/">
#                   <img alt="The Godfather" height="67" src="https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
#                  </a>
#                 </td>
#                 <td class="titleColumn">
#                  2.
#                  <a href="/title/tt0068646/" title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">
#                   The Godfather
#                  </a>
#                  <span class="secondaryInfo">
#                   (1972)
#                  </span>
#                 </td>
#                 <td class="ratingColumn imdbRating">
#                  <strong title="9.1 based on 1,479,253 user ratings">
#                   9.1
#                  </strong>
#                 </td>
#                 <td class="ratingColumn">
#                  <div class="seen-widget seen-widget-tt0068646 pending" data-titleid="tt0068646">
#                   <div class="boundary">
#                    <div class="popover">
#                     <span class="delete">
#                     </span>
#                     <ol>
#                      <li>
#                       1
#                       <li>
#                        2
#                        <li>
#                         3
#                         <li>
#                          4
#                          <li>
#                           5
#                           <li>
#                            6
#                            <li>
#                             7
#                             <li>
#                              8
#                              <li>
#                               9
#                               <li>
#                                10
#                               </li>
#                              </li>
#                             </li>
#                            </li>
#                           </li>
#                          </li>
#                         </li>
#                        </li>
#                       </li>
#                      </li>
#                     </ol>
#                    </div>
#                   </div>
#                   <div class="inline">
#                    <div class="pending">
#                    </div>
#                    <div class="unseeable">
#                     NOT YET RELEASED
#                    </div>
#                    <div class="unseen">
#                    </div>
#                    <div class="rating">
#                    </div>
#                    <div class="seen">
#                     Seen
#                    </div>
#                   </div>
#                  </div>
#                 </td>
#                 <td class="watchlistColumn">
#                  <div class="wlb_ribbon" data-recordmetrics="true" data-tconst="tt0068646">
#                  </div>
#                 </td>
#                </tr>
#                <tr>
#                 <td class="posterColumn">
#                  <span data-value="3" name="rk">
#                  </span>
#                  <span data-value="8.981301034320696" name="ir">
#                  </span>
#                  <span data-value="1.560384E11" name="us">
#                  </span>
#                  <span data-value="1029777" name="nv">
# ...
#           </path>
#           <path d="M18.003,16.231 C17.588,16.231 17.381,16.023 17.381,15.608 L17.381,1.088 C17.381,0.673 17.588,0.466 18.003,0.466 L19.37,0.466 C19.578,0.466 19.738,0.508 19.852,0.59 C19.966,0.673 20.044,0.829 20.086,1.057 L20.273,2.207 C22.241,0.735 24.315,0 26.491,0 C28.004,0 29.155,0.398 29.942,1.196 C30.73,1.995 31.124,3.151 31.124,4.664 L31.124,15.608 C31.124,16.023 30.917,16.231 30.503,16.231 L28.668,16.231 C28.253,16.231 28.046,16.023 28.046,15.608 L28.046,5.69 C28.046,4.592 27.823,3.782 27.377,3.265 C26.931,2.746 26.232,2.486 25.279,2.486 C23.641,2.486 22.034,3.016 20.459,4.073 L20.459,15.608 C20.459,16.023 20.251,16.231 19.837,16.231 L18.003,16.231" fill="#232F3E">
#           </path>
#           <path d="M148.483,16.572 C146.037,16.572 144.166,15.872 142.871,14.474 C141.575,13.074 140.927,11.048 140.927,8.395 C140.927,5.763 141.595,3.726 142.932,2.285 C144.27,0.845 146.161,0.124 148.607,0.124 C149.726,0.124 150.825,0.32 151.903,0.715 C152.131,0.798 152.292,0.901 152.385,1.025 C152.478,1.149 152.525,1.357 152.525,1.648 L152.525,2.486 C152.525,2.902 152.389,3.108 152.12,3.108 C152.016,3.108 151.851,3.078 151.624,3.016 C150.773,2.767 149.913,2.643 149.043,2.643 C147.302,2.643 146.047,3.083 145.28,3.964 C144.512,4.845 144.13,6.249 144.13,8.178 L144.13,8.581 C144.13,10.468 144.518,11.852 145.296,12.732 C146.073,13.613 147.302,14.054 148.98,14.054 C149.851,14.054 150.784,13.909 151.779,13.618 C152.007,13.557 152.162,13.525 152.245,13.525 C152.514,13.525 152.649,13.732 152.649,14.148 L152.649,14.986 C152.649,15.256 152.608,15.453 152.525,15.577 C152.442,15.701 152.276,15.815 152.027,15.92 C151.011,16.355 149.83,16.572 148.483,16.572" fill="#232F3E">
#           </span>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div>
#          <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-fr&amp;token=BCYqKRp2JXVVbNIVbSFdHD6YFSZVUVR4rXN4pVXcy9f3GC-rinOqTUi5ocivU-s7aH0fBS5e8wLc%0D%0AUT4EGamH97Qr5FRKfM2rVcwHCk0LNkEd3KpqBL0PpVwNnHUxqSNLHm03gMXXV6aaMU7PDeBPMafj%0D%0ANInlISiQ57zpSrutW6NzWzC48NVhnzJtujugKkyJiEpOQrVQ1DceL4q77ky5ToHpkEblryvapjnM%0D%0AtyMYA1qyHJQ%0D%0A">
#           <span class="amazon-affiliate-site-name">
#            Amazon France
#           </span>
#           <br/>
#           <span class="amazon-affiliate-site-desc">
#            Buy Movies on
#            <br/>
#            DVD &amp; Blu-ray
#           </span>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div>
#          <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-in&amp;token=BCYrY-Co5Ogu3yZTDPgWv_x5lWhSrAEF1OJTOP2IK-xJCqEPJ5bGhyNKVwvIsCHid47fFaDjpihm%0D%0AkxCjaNL8GJYonKSyzgMHN85VqL75bVzY1j-SyA7yMWz3TDwRIhs8g7QVz2W21rx7I0xZm8RJcvg_%0D%0ANUX9XqVL9_Xy6_5HBJWd-gHnr8wSuDDzNw38qZhnwY6aCDnGZhZslrc_5jbEzp1P9Cmdep6ckH4u%0D%0AzxvZaR8WEdtffxyrn4RjuDG4129OJwno%0D%0A">
#           <span class="amazon-affiliate-site-name">
#            Amazon India
#           </span>
#           <br/>
#           <span class="amazon-affiliate-site-desc">
#            Buy Movie and
#            <br/>
#            TV Show DVDs
#           </span>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div>
#          <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-dpr&amp;token=BCYrH8jz9Y6J1IFUZWrNRxCjW2JHqdJQypu8HO_QqmzxvunEkTeWUZqpzhReyEfKA2pgDYTxhChx%0D%0AykQoqN6qaq88g7lAXjPTF_M3pf9kvKakQyIe2TjuPaI_M50050mEvHHY_hJe_MhI4u4QzcGgiH9d%0D%0ANDyLdnEiWRTPqQXD_iJ9cmo%0D%0A">
#           <span class="amazon-affiliate-site-name">
#            DPReview
#           </span>
#           <br/>
#           <span class="amazon-affiliate-site-desc">
#            Digital
#            <br/>
#            Photography
#           </span>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div>
#          <a class="amazon-affiliate-site-link" href="/offsite/?page-action=ft-amzn-aud&amp;token=BCYqWL6fz5KB7qujVvvAeUXEjBruBbZvKP5g2ZuJ9lhipgTKMKtNJrEksBf2GDEZySBuSbUGA0h3%0D%0AM8UT1CS2ogn1mQneSUWmV3q8W-3ynawXu6UvGX1UujNUC4KYU5QQCzhitGZl8xweBkwDJVoSkrWp%0D%0AEJxTkgtZ5QxBeZOudv9EkWk%0D%0A">
#           <span class="amazon-affiliate-site-name">
#            Audible
#           </span>
#           <br/>
#           <span class="amazon-affiliate-site-desc">
#            Download
#            <br/>
#            Audio Books
#           </span>
#          </a>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <script>
#      if (typeof uet == 'function') {
#       uet("be", "desktopFooter", {wb: 1});
#     }
#     </script>
#     <script>
#      if (typeof uex == 'function') {
#       uex("ld", "desktopFooter", {wb: 1});
#     }
#     </script>
#     <script type="text/javascript">
#      try {
#             window.lumierePlayer = window.lumierePlayer || {};
#             window.lumierePlayer.weblab = JSON.parse('{"IMDB_TV_REBRAND_212999":"T1","IMDB_VIDEO_PLAYER_162496":"C","IMDB_RELATED_VIDEOS_196868":"T1","IMDB_VIDEO_SINGLE_PAGE_REDIRECT_241512":"C"}');
#         } catch (error) {
#             if (window.ueLogError) {
#                 window.ueLogError(error, {
#                     logLevel: "WARN",
#                     attribution: "videoplayer",
#                     message: "Failed to parse weblabs for video player."
#                 });
#             }
#         }
#     </script>
#    </div>
#   </div>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadHeaderJS", {wb: 1});
#     }
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/common-858210017._CB450536990_.js" type="text/javascript">
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/pagelayout-1396940656._CB447911047_.js" type="text/javascript">
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/other-1018173565._CB449480046_.js" type="text/javascript">
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/seenWidget-1675519461._CB449143927_.js" type="text/javascript">
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/watchlistButton-1817690010._CB448978296_.js" type="text/javascript">
#   </script>
#   <script src="https://m.media-amazon.com/images/G/01/imdb/js/collections/chart-share-widget-1048338655._CB461897629_.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function jQueryOnReady(remaining_count) {
#                 if (window.jQuery && typeof $.fn.watchlistRibbon !== 'undefined') {
#                     jQuery(
#                                         function() {
#                     window.imdb.CS.Chart.InitChart();
#                 }
#
#                     );
#                     jQuery(
#                         function() { $('#content-2-wide').watchlistRibbon('.ribbonize'); }
#                     );
#                 } else if (remaining_count > 0) {
#                     setTimeout(function() { jQueryOnReady(remaining_count-1) }, 100);
#                 }
#             }
#             jQueryOnReady(50);
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be", "LoadFooterJS", {wb: 1});
#     }
#   </script>
#   <script>
#    if (typeof uex == 'function') {
#       uex("ld", "LoadFooterJS", {wb: 1});
#     }
#   </script>
#   <div id="servertime" time="187">
#   </div>
#   <script>
#    if (typeof uet == 'function') {
#       uet("be");
#     }
#   </script>
#  </body>
# </html>

# %%
#flitering for the location of 'titleColumn' AND naming it movie_infos (movie's information is under this class)
soup.find_all( class_='titleColumn')

movie_infos = soup.find_all( class_='titleColumn')

# %%
# loop for all of the movie_ids

list_of_ids=[]

#for loop for the id
for i in range(len(movie_infos)):
    id_string = movie_infos[i].find('a')
    id_int = id_string['href'].split('/')[2]
    list_of_ids.append(id_int)

list_of_ids
# Out:
# ['tt0111161',
#  'tt0068646',
#  'tt0071562',
#  'tt0468569',
#  'tt0050083',
#  'tt0108052',
#  'tt0167260',
#  'tt0110912',
#  'tt0060196',
#  'tt0137523',
#  'tt0120737',
#  'tt0109830',
#  'tt1375666',
#  'tt0080684',
#  'tt7286456',
#  'tt0167261',
#  'tt0133093',
#  'tt0073486',
#  'tt0099685',
#  'tt0047478',
#  'tt0114369',
#  'tt0317248',
#  'tt0118799',
#  'tt0102926',
#  'tt0038650',
#  'tt0076759',
#  'tt0120815',
#  'tt0245429',
#  'tt0120689',
#  'tt0110413',
#  'tt0816692',
#  'tt0056058',
#  'tt0114814',
#  'tt0110357',
#  'tt0120586',
#  'tt0088763',
#  'tt0253474',
#  'tt0027977',
#  'tt0103064',
#  'tt0054215',
#  'tt1675434',
#  'tt0172495',
#  'tt0021749',
#  'tt0407887',
#  'tt2582802',
#  'tt0064116',
#  'tt0482571',
#  'tt0034583',
#  'tt0095327',
#  'tt4154796',
#  'tt0047396',
#  'tt6751668',
#  'tt0095765',
#  'tt0078748',
#  'tt0082971',
#  'tt0209144',
#  'tt0078788',
#  'tt0032553',
#  'tt0405094',
#  'tt1853728',
#  'tt4154756',
#  'tt0081505',
#  'tt4633694',
#  'tt0050825',
#  'tt0910970',
#  'tt0119698',
#  'tt0043014',
#  'tt0057012',
#  'tt0364569',
#  'tt0051201',
#  'tt1345836',
#  'tt0087843',
#  'tt0090605',
#  'tt0169547',
#  'tt5311514',
#  'tt2380307',
#  'tt0112573',
#  'tt0082096',
#  'tt1187043',
#  'tt0986264',
#  'tt0086190',
#  'tt0114709',
#  'tt0105236',
#  'tt0086879',
#  'tt5074352',
#  'tt0361748',
#  'tt0119217',
#  'tt0022100',
#  'tt0180093',
#  'tt0062622',
#  'tt0052357',
#  'tt0338013',
#  'tt0033467',
#  'tt2106476',
#  'tt0093058',
#  'tt0053125',
#  'tt0066921',
#  'tt0208092',
#  'tt0012349',
#  'tt0211915',
#  'tt0040522',
#  'tt0086250',
#  'tt0045152',
#  'tt0056172',
#  'tt0075314',
#  'tt0435761',
#  'tt0070735',
#  'tt0017136',
#  'tt0059578',
#  'tt0044741',
#  'tt1832382',
#  'tt0036775',
#  'tt0056592',
#  'tt8267604',
#  'tt0097576',
#  'tt0053604',
#  'tt1049413',
#  'tt0119488',
#  'tt0071853',
#  'tt1255953',
#  'tt0113277',
#  'tt0042876',
#  'tt0055630',
#  'tt0372784',
#  'tt0095016',
#  'tt0105695',
#  'tt6966692',
#  'tt0363163',
#  'tt0118849',
#  'tt0053291',
#  'tt0347149',
#  'tt0057115',
#  'tt0096283',
#  'tt0089881',
#  'tt0268978',
#  'tt0042192',
#  'tt0457430',
#  'tt0091251',
#  'tt0112641',
#  'tt1305806',
#  'tt0081398',
#  'tt0120735',
#  'tt3417422',
#  'tt0040897',
#  'tt0993846',
#  'tt0476735',
#  'tt0055031',
#  'tt5027774',
#  'tt0071315',
#  'tt0015864',
#  'tt0046912',
#  'tt0469494',
#  'tt2096673',
#  'tt0434409',
#  'tt0050976',
#  'tt1291584',
#  'tt3170832',
#  'tt0477348',
#  'tt0117951',
#  'tt0080678',
#  'tt0167404',
#  'tt1130884',
#  'tt8108198',
#  'tt0084787',
#  'tt0031381',
#  'tt0050212',
#  'tt0083658',
#  'tt0041959',
#  'tt0047296',
#  'tt0107290',
#  'tt0050986',
#  'tt0266543',
#  'tt0116231',
#  'tt1205489',
#  'tt0116282',
#  'tt0266697',
#  'tt0077416',
#  'tt0079944',
#  'tt0120382',
#  'tt0118715',
#  'tt0046438',
#  'tt3011894',
#  'tt0978762',
#  'tt0107207',
#  'tt2267998',
#  'tt2119532',
#  'tt0017925',
#  'tt0015324',
#  'tt0892769',
#  'tt0031679',
#  'tt0353969',
#  'tt2278388',
#  'tt0060827',
#  'tt0112471',
#  'tt0264464',
#  'tt0758758',
#  'tt0061512',
#  'tt0046268',
#  'tt2024544',
#  'tt1392214',
#  'tt0074958',
#  'tt0040725',
#  'tt0079470',
#  'tt0092005',
#  'tt1392190',
#  'tt0019254',
#  'tt0405508',
#  'tt0091763',
#  'tt0060107',
#  'tt0405159',
#  'tt1979320',
#  'tt1028532',
#  'tt3315342',
#  'tt0072684',
#  'tt0052618',
#  'tt0087544',
#  'tt0395169',
#  'tt0245712',
#  'tt1201607',
#  'tt0053198',
#  'tt1895587',
#  'tt0097165',
#  'tt0042041',
#  'tt0043338',
#  'tt0032976',
#  'tt0075148',
#  'tt0198781',
#  'tt0025316',
#  'tt0113247',
#  'tt4016934',
#  'tt1954470',
#  'tt0169102',
#  'tt0093779',
#  'tt2338151',
#  'tt0374887',
#  'tt0064115',
#  'tt0381681',
#  'tt1454029',
#  'tt0094625',
#  'tt0088247',
#  'tt0118694',
#  'tt0367110',
#  'tt0087884',
#  'tt0103639',
#  'tt2015381',
#  'tt0338564',
#  'tt0058946',
#  'tt0092067',
#  'tt0120731',
#  'tt0050613']

# %%
# intergrating the movie_ids with the main_url and apikey for GET
urls=[]
main_url = 'http://www.omdbapi.com/?i='  


for i in list_of_ids:
    urls.append(main_url + i + '&apikey=6d18c241')

            


# urls

# %%
# Checking reponse for information
test = requests.get('http://www.omdbapi.com/?i=tt0103064&apikey=6d18c241')
test.content
# Out:
# b'{"Title":"Terminator 2: Judgment Day","Year":"1991","Rated":"R","Released":"03 Jul 1991","Runtime":"137 min","Genre":"Action, Sci-Fi","Director":"James Cameron","Writer":"James Cameron, William Wisher","Actors":"Arnold Schwarzenegger, Linda Hamilton, Edward Furlong, Robert Patrick","Plot":"A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her teenage son, John Connor, from a more advanced and powerful cyborg.","Language":"English, Spanish","Country":"USA","Awards":"Won 4 Oscars. Another 27 wins & 27 nominations.","Poster":"https://m.media-amazon.com/images/M/MV5BMGU2NzRmZjUtOGUxYS00ZjdjLWEwZWItY2NlM2JhNjkxNTFmXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SX300.jpg","Ratings":[{"Source":"Internet Movie Database","Value":"8.5/10"},{"Source":"Rotten Tomatoes","Value":"93%"},{"Source":"Metacritic","Value":"75/100"}],"Metascore":"75","imdbRating":"8.5","imdbVotes":"926,991","imdbID":"tt0103064","Type":"movie","DVD":"31 Mar 1998","BoxOffice":"$198,116,802","Production":"TriStar Pictures","Website":"N/A","Response":"True"}'

# %% [markdown]
# # Making of the tables:

# %%
cursor = cnx.cursor()
TABLES = {} #use dictionary to save diff create statements for each table

#Creating Table 'OMDb_Top_250_and_Low_100'

TABLES['OMDb_Top_250_and_Low_100'] = (
    "  CREATE TABLE OMDb_Top_250_and_Low_100 ("
    "  movie_id varchar(11) NOT NULL primary key,"
    "  movie_name varchar(200) not null,"
    "  rated varchar(20) not null,"
    "  imdb_rating float(2) not null,"
    "  imdb_total_votes int(7) not null,"
    "  metascore int(3) not null,"
    "  release_year int(5) not null,"
    "  runtime varchar(30) not null"
    
") ENGINE=InnoDB")


#Creating Table 'OMDb_Actors'


TABLES['OMDb_Actors'] = (
    "  CREATE TABLE OMDb_Actors ("
    "  movie_id varchar(11) NOT NULL,"
    "  movie_name varchar(200) NOT NULL,"
    "  actors varchar(255) not null"
") ENGINE=InnoDB")
    


#Creating Table 'OMDb_Directors'    
    
TABLES['OMDb_Directors'] = (
    "  CREATE TABLE OMDb_Directors ("
    "  movie_id varchar(11) NOT NULL,"
    "  movie_name varchar(200) NOT NULL,"
    "  director varchar(100) not null"
") ENGINE=InnoDB")
    

    
# Code for making each of the tables; if table exist will not make a new table    
    
for table_name in TABLES:
    table_description = TABLES[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")
# Out:
# Creating table OMDb_Top_250_and_Low_100: already exists.
# Creating table OMDb_Actors: already exists.
# Creating table OMDb_Directors: already exists.

# %% [markdown]
# # Populating the Main Table

# %%
# Loop to .Get response for all the urls & Parsing results with the keys I need for the main table, and assigned to imdb list

imdb_db = []

for x in urls:

    
        page1 = requests.get(x)
        data = page1.json()
        keys = ['imdbID', 'Title', 'Rated','imdbRating','imdbVotes', 'Metascore', 'Year', 'Runtime']
        parsed_results = {key: (data[key] if key in data else 'Null') for key in keys}
        imdb_db.append(parsed_results)
        time.sleep(0.1)

# %%
# made a copy to not work with main list
imdb_db = imdb_db.copy()

# %%
# Making tuple list for Main Table      #### added 'IGNORE INTO' to skips duplicate responses to avoid error message

movies_lists = []
for movie in imdb_db:
    movies_tuples = (movie['imdbID'], movie['Title'], movie['Rated'], movie['imdbRating'], movie['imdbVotes'], movie['Metascore'], movie['Year'], movie['Runtime'])
    movies_lists.append(movies_tuples)
    
# Inserting into Main table
    
    insert_stmt = "INSERT IGNORE INTO OMDb_Top_250_and_Low_100 ( movie_id, movie_name, rated, imdb_rating, imdb_total_votes, metascore, release_year, runtime) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
    cursor.execute(insert_stmt, movies_tuples)
    cnx.commit()
    time.sleep(0.1)

# %% [markdown]
# # Populating Table Actors

# %%
# Loop to Get response for all the urls & Parsing results with the keys I need for the Actors table, and assigned to imdb_actorss list

imdb_actorss = []

for x in urls:

    
        page1 = requests.get(x)
        data = page1.json()
        keys = ['imdbID', 'Title', 'Actors']
        parsed_results = {key: (data[key] if key in data else 'Null') for key in keys}
        imdb_actorss.append(parsed_results)
        time.sleep(0.1)

# %%
# made a copy to not work with main list

imdb_actors = imdb_actorss.copy()

# %%
# spliting the actors that are in a list of list into separate actor names

for movie in imdb_actors:
    movie['Actors'] = movie['Actors'].split(',')
    movie['Actors'] = [i.strip() for i in movie['Actors']]

# %%
imdb_actors
# Out:
# [{'imdbID': 'tt0111161',
#   'Title': 'The Shawshank Redemption',
#   'Actors': ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton', 'William Sadler']},
#  {'imdbID': 'tt0068646',
#   'Title': 'The Godfather',
#   'Actors': ['Marlon Brando',
#    'Al Pacino',
#    'James Caan',
#    'Richard S. Castellano']},
#  {'imdbID': 'tt0071562',
#   'Title': 'The Godfather: Part II',
#   'Actors': ['Al Pacino', 'Robert Duvall', 'Diane Keaton', 'Robert De Niro']},
#  {'imdbID': 'tt0468569',
#   'Title': 'The Dark Knight',
#   'Actors': ['Christian Bale',
#    'Heath Ledger',
#    'Aaron Eckhart',
#    'Michael Caine']},
#  {'imdbID': 'tt0050083',
#   'Title': '12 Angry Men',
#   'Actors': ['Martin Balsam', 'John Fiedler', 'Lee J. Cobb', 'E.G. Marshall']},
#  {'imdbID': 'tt0108052',
#   'Title': "Schindler's List",
#   'Actors': ['Liam Neeson',
#    'Ben Kingsley',
#    'Ralph Fiennes',
#    'Caroline Goodall']},
#  {'imdbID': 'tt0167260',
#   'Title': 'The Lord of the Rings: The Return of the King',
#   'Actors': ['Noel Appleby', 'Ali Astin', 'Sean Astin', 'David Aston']},
#  {'imdbID': 'tt0110912',
#   'Title': 'Pulp Fiction',
#   'Actors': ['Tim Roth', 'Amanda Plummer', 'Laura Lovelace', 'John Travolta']},
#  {'imdbID': 'tt0060196',
#   'Title': 'The Good, the Bad and the Ugly',
#   'Actors': ['Eli Wallach',
#    'Clint Eastwood',
#    'Lee Van Cleef',
#    'Aldo Giuffrè']},
#  {'imdbID': 'tt0137523',
#   'Title': 'Fight Club',
#   'Actors': ['Edward Norton', 'Brad Pitt', 'Meat Loaf', 'Zach Grenier']},
#  {'imdbID': 'tt0120737',
#   'Title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'Actors': ['Alan Howard', 'Noel Appleby', 'Sean Astin', 'Sala Baker']},
#  {'imdbID': 'tt0109830',
#   'Title': 'Forrest Gump',
#   'Actors': ['Tom Hanks',
#    'Rebecca Williams',
#    'Sally Field',
#    'Michael Conner Humphreys']},
#  {'imdbID': 'tt1375666',
#   'Title': 'Inception',
#   'Actors': ['Leonardo DiCaprio',
#    'Joseph Gordon-Levitt',
#    'Ellen Page',
#    'Tom Hardy']},
#  {'imdbID': 'tt0080684',
#   'Title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'Actors': ['Mark Hamill',
#    'Harrison Ford',
#    'Carrie Fisher',
#    'Billy Dee Williams']},
#  {'imdbID': 'tt7286456',
#   'Title': 'Joker',
#   'Actors': ['Joaquin Phoenix',
#    'Robert De Niro',
#    'Zazie Beetz',
#    'Frances Conroy']},
#  {'imdbID': 'tt0167261',
#   'Title': 'The Lord of the Rings: The Two Towers',
#   'Actors': ['Bruce Allpress', 'Sean Astin', 'John Bach', 'Sala Baker']},
#  {'imdbID': 'tt0133093',
#   'Title': 'The Matrix',
#   'Actors': ['Keanu Reeves',
#    'Laurence Fishburne',
#    'Carrie-Anne Moss',
#    'Hugo Weaving']},
#  {'imdbID': 'tt0073486',
#   'Title': "One Flew Over the Cuckoo's Nest",
#   'Actors': ['Jack Nicholson',
#    'Louise Fletcher',
#    'Will Sampson',
#    'Michael Berryman']},
#  {'imdbID': 'tt0099685',
#   'Title': 'Goodfellas',
#   'Actors': ['Robert De Niro', 'Ray Liotta', 'Joe Pesci', 'Lorraine Bracco']},
#  {'imdbID': 'tt0047478',
#   'Title': 'Seven Samurai',
#   'Actors': ['Toshirô Mifune',
#    'Takashi Shimura',
#    'Keiko Tsushima',
#    'Yukiko Shimazaki']},
#  {'imdbID': 'tt0114369',
#   'Title': 'Se7en',
#   'Actors': ['Morgan Freeman',
#    'Andrew Kevin Walker',
#    'Daniel Zacapa',
#    'Brad Pitt']},
#  {'imdbID': 'tt0317248',
#   'Title': 'City of God',
#   'Actors': ['Alexandre Rodrigues',
#    'Leandro Firmino',
#    'Phellipe Haagensen',
#    'Douglas Silva']},
#  {'imdbID': 'tt0118799',
#   'Title': 'Life Is Beautiful',
#   'Actors': ['Roberto Benigni',
#    'Nicoletta Braschi',
#    'Giorgio Cantarini',
#    'Giustino Durano']},
#  {'imdbID': 'tt0102926',
#   'Title': 'The Silence of the Lambs',
#   'Actors': ['Jodie Foster',
#    'Lawrence A. Bonney',
#    'Kasi Lemmons',
#    'Lawrence T. Wrentz']},
#  {'imdbID': 'tt0038650',
#   'Title': "It's a Wonderful Life",
#   'Actors': ['James Stewart',
#    'Donna Reed',
#    'Lionel Barrymore',
#    'Thomas Mitchell']},
#  {'imdbID': 'tt0076759',
#   'Title': 'Star Wars: Episode IV - A New Hope',
#   'Actors': ['Mark Hamill',
#    'Harrison Ford',
#    'Carrie Fisher',
#    'Peter Cushing']},
#  {'imdbID': 'tt0120815',
#   'Title': 'Saving Private Ryan',
#   'Actors': ['Tom Hanks', 'Tom Sizemore', 'Edward Burns', 'Barry Pepper']},
#  {'imdbID': 'tt0245429',
#   'Title': 'Spirited Away',
#   'Actors': ['Rumi Hiiragi', 'Miyu Irino', 'Mari Natsuki', 'Takashi Naitô']},
#  {'imdbID': 'tt0120689',
#   'Title': 'The Green Mile',
#   'Actors': ['Tom Hanks',
#    'David Morse',
#    'Bonnie Hunt',
#    'Michael Clarke Duncan']},
#  {'imdbID': 'tt0110413',
#   'Title': 'Léon: The Professional',
#   'Actors': ['Jean Reno', 'Gary Oldman', 'Natalie Portman', 'Danny Aiello']},
#  {'imdbID': 'tt0816692',
#   'Title': 'Interstellar',
#   'Actors': ['Ellen Burstyn',
#    'Matthew McConaughey',
#    'Mackenzie Foy',
#    'John Lithgow']},
#  {'imdbID': 'tt0056058',
#   'Title': 'Harakiri',
#   'Actors': ['Tatsuya Nakadai',
#    'Akira Ishihama',
#    'Shima Iwashita',
#    'Tetsurô Tanba']},
#  {'imdbID': 'tt0114814',
#   'Title': 'The Usual Suspects',
#   'Actors': ['Stephen Baldwin',
#    'Gabriel Byrne',
#    'Benicio Del Toro',
#    'Kevin Pollak']},
#  {'imdbID': 'tt0110357',
#   'Title': 'The Lion King',
#   'Actors': ['Rowan Atkinson',
#    'Matthew Broderick',
#    'Niketa Calame-Harris',
#    'Jim Cummings']},
#  {'imdbID': 'tt0120586',
#   'Title': 'American History X',
#   'Actors': ['Edward Norton',
#    'Edward Furlong',
#    "Beverly D'Angelo",
#    'Jennifer Lien']},
#  {'imdbID': 'tt0088763',
#   'Title': 'Back to the Future',
#   'Actors': ['Michael J. Fox',
#    'Christopher Lloyd',
#    'Lea Thompson',
#    'Crispin Glover']},
#  {'imdbID': 'tt0253474',
#   'Title': 'The Pianist',
#   'Actors': ['Adrien Brody', 'Emilia Fox', 'Michal Zebrowski', 'Ed Stoppard']},
#  {'imdbID': 'tt0027977',
#   'Title': 'Modern Times',
#   'Actors': ['Charles Chaplin',
#    'Paulette Goddard',
#    'Henry Bergman',
#    'Tiny Sandford']},
#  {'imdbID': 'tt0103064',
#   'Title': 'Terminator 2: Judgment Day',
#   'Actors': ['Arnold Schwarzenegger',
#    'Linda Hamilton',
#    'Edward Furlong',
#    'Robert Patrick']},
#  {'imdbID': 'tt0054215',
#   'Title': 'Psycho',
#   'Actors': ['Anthony Perkins', 'Vera Miles', 'John Gavin', 'Janet Leigh']},
#  {'imdbID': 'tt1675434',
#   'Title': 'The Intouchables',
#   'Actors': ['François Cluzet', 'Omar Sy', 'Anne Le Ny', 'Audrey Fleurot']},
#  {'imdbID': 'tt0172495',
#   'Title': 'Gladiator',
#   'Actors': ['Russell Crowe',
#    'Joaquin Phoenix',
#    'Connie Nielsen',
#    'Oliver Reed']},
#  {'imdbID': 'tt0021749',
#   'Title': 'City Lights',
#   'Actors': ['Virginia Cherrill',
#    'Florence Lee',
#    'Harry Myers',
#    'Al Ernest Garcia']},
#  {'imdbID': 'tt0407887',
#   'Title': 'The Departed',
#   'Actors': ['Leonardo DiCaprio',
#    'Matt Damon',
#    'Jack Nicholson',
#    'Mark Wahlberg']},
#  {'imdbID': 'tt2582802',
#   'Title': 'Whiplash',
#   'Actors': ['Miles Teller',
#    'J.K. Simmons',
#    'Paul Reiser',
#    'Melissa Benoist']},
#  {'imdbID': 'tt0064116',
#   'Title': 'Once Upon a Time in the West',
#   'Actors': ['Claudia Cardinale',
#    'Henry Fonda',
#    'Jason Robards',
#    'Charles Bronson']},
#  {'imdbID': 'tt0482571',
#   'Title': 'The Prestige',
#   'Actors': ['Hugh Jackman',
#    'Christian Bale',
#    'Michael Caine',
#    'Piper Perabo']},
#  {'imdbID': 'tt0034583',
#   'Title': 'Casablanca',
#   'Actors': ['Humphrey Bogart',
#    'Ingrid Bergman',
#    'Paul Henreid',
#    'Claude Rains']},
#  {'imdbID': 'tt0095327',
#   'Title': 'Grave of the Fireflies',
#   'Actors': ['Tsutomu Tatsumi',
#    'Ayano Shiraishi',
#    'Yoshiko Shinohara',
#    'Akemi Yamaguchi']},
#  {'imdbID': 'tt4154796',
#   'Title': 'Avengers: Endgame',
#   'Actors': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth']},
#  {'imdbID': 'tt0047396',
#   'Title': 'Rear Window',
#   'Actors': ['James Stewart',
#    'Grace Kelly',
#    'Wendell Corey',
#    'Thelma Ritter']},
#  {'imdbID': 'tt6751668',
#   'Title': 'Parasite',
#   'Actors': ['Kang-ho Song', 'Yeo-jeong Jo', 'So-dam Park', 'Woo-sik Choi']},
#  {'imdbID': 'tt0095765',
#   'Title': 'Cinema Paradiso',
#   'Actors': ['Antonella Attili',
#    'Enzo Cannavale',
#    'Isa Danieli',
#    'Leo Gullotta']},
#  {'imdbID': 'tt0078748',
#   'Title': 'Alien',
#   'Actors': ['Tom Skerritt',
#    'Sigourney Weaver',
#    'Veronica Cartwright',
#    'Harry Dean Stanton']},
#  {'imdbID': 'tt0082971',
#   'Title': 'Raiders of the Lost Ark',
#   'Actors': ['Harrison Ford', 'Karen Allen', 'Paul Freeman', 'Ronald Lacey']},
#  {'imdbID': 'tt0209144',
#   'Title': 'Memento',
#   'Actors': ['Guy Pearce',
#    'Carrie-Anne Moss',
#    'Joe Pantoliano',
#    'Mark Boone Junior']},
#  {'imdbID': 'tt0078788',
#   'Title': 'Apocalypse Now',
#   'Actors': ['Marlon Brando',
#    'Martin Sheen',
#    'Robert Duvall',
#    'Frederic Forrest']},
#  {'imdbID': 'tt0032553',
#   'Title': 'The Great Dictator',
#   'Actors': ['Charles Chaplin',
#    'Jack Oakie',
#    'Reginald Gardiner',
#    'Henry Daniell']},
#  {'imdbID': 'tt0405094',
#   'Title': 'The Lives of Others',
#   'Actors': ['Martina Gedeck',
#    'Ulrich Mühe',
#    'Sebastian Koch',
#    'Ulrich Tukur']},
#  {'imdbID': 'tt1853728',
#   'Title': 'Django Unchained',
#   'Actors': ['Jamie Foxx',
#    'Christoph Waltz',
#    'Leonardo DiCaprio',
#    'Kerry Washington']},
#  {'imdbID': 'tt4154756',
#   'Title': 'Avengers: Infinity War',
#   'Actors': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans']},
#  {'imdbID': 'tt0081505',
#   'Title': 'The Shining',
#   'Actors': ['Jack Nicholson',
#    'Shelley Duvall',
#    'Danny Lloyd',
#    'Scatman Crothers']},
#  {'imdbID': 'tt4633694',
#   'Title': 'Spider-Man: Into the Spider-Verse',
#   'Actors': ['Shameik Moore',
#    'Jake Johnson',
#    'Hailee Steinfeld',
#    'Mahershala Ali']},
#  {'imdbID': 'tt0050825',
#   'Title': 'Paths of Glory',
#   'Actors': ['Kirk Douglas',
#    'Ralph Meeker',
#    'Adolphe Menjou',
#    'George Macready']},
#  {'imdbID': 'tt0910970',
#   'Title': 'WALL·E',
#   'Actors': ['Ben Burtt', 'Elissa Knight', 'Jeff Garlin', 'Fred Willard']},
#  {'imdbID': 'tt0119698',
#   'Title': 'Princess Mononoke',
#   'Actors': ['Billy Crudup',
#    'Billy Bob Thornton',
#    'Minnie Driver',
#    'John DiMaggio']},
#  {'imdbID': 'tt0043014',
#   'Title': 'Sunset Blvd.',
#   'Actors': ['William Holden',
#    'Gloria Swanson',
#    'Erich von Stroheim',
#    'Nancy Olson']},
#  {'imdbID': 'tt0057012',
#   'Title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'Actors': ['Peter Sellers',
#    'George C. Scott',
#    'Sterling Hayden',
#    'Keenan Wynn']},
#  {'imdbID': 'tt0364569',
#   'Title': 'Oldboy',
#   'Actors': ['Min-sik Choi', 'Ji-tae Yu', 'Hye-jeong Kang', 'Dae-han Ji']},
#  {'imdbID': 'tt0051201',
#   'Title': 'Witness for the Prosecution',
#   'Actors': ['Tyrone Power',
#    'Marlene Dietrich',
#    'Charles Laughton',
#    'Elsa Lanchester']},
#  {'imdbID': 'tt1345836',
#   'Title': 'The Dark Knight Rises',
#   'Actors': ['Christian Bale',
#    'Gary Oldman',
#    'Tom Hardy',
#    'Joseph Gordon-Levitt']},
#  {'imdbID': 'tt0087843',
#   'Title': 'Once Upon a Time in America',
#   'Actors': ['Robert De Niro',
#    'James Woods',
#    'Elizabeth McGovern',
#    'Treat Williams']},
#  {'imdbID': 'tt0090605',
#   'Title': 'Aliens',
#   'Actors': ['Sigourney Weaver',
#    'Carrie Henn',
#    'Michael Biehn',
#    'Paul Reiser']},
#  {'imdbID': 'tt0169547',
#   'Title': 'American Beauty',
#   'Actors': ['Kevin Spacey', 'Annette Bening', 'Thora Birch', 'Wes Bentley']},
#  {'imdbID': 'tt5311514',
#   'Title': 'Your Name.',
#   'Actors': ['Ryûnosuke Kamiki',
#    'Mone Kamishiraishi',
#    'Ryô Narita',
#    'Aoi Yûki']},
#  {'imdbID': 'tt2380307',
#   'Title': 'Coco',
#   'Actors': ['Anthony Gonzalez',
#    'Gael García Bernal',
#    'Benjamin Bratt',
#    'Alanna Ubach']},
#  {'imdbID': 'tt0112573',
#   'Title': 'Braveheart',
#   'Actors': ['James Robinson', 'Sean Lawlor', 'Sandy Nelson', 'James Cosmo']},
#  {'imdbID': 'tt0082096',
#   'Title': 'Das Boot',
#   'Actors': ['Jürgen Prochnow',
#    'Herbert Grönemeyer',
#    'Klaus Wennemann',
#    'Hubertus Bengsch']},
#  {'imdbID': 'tt1187043',
#   'Title': '3 Idiots',
#   'Actors': ['Aamir Khan', 'Madhavan', 'Sharman Joshi', 'Kareena Kapoor']},
#  {'imdbID': 'tt0986264',
#   'Title': 'Like Stars on Earth',
#   'Actors': ['Darsheel Safary', 'Aamir Khan', 'Tisca Chopra', 'Vipin Sharma']},
#  {'imdbID': 'tt0086190',
#   'Title': 'Star Wars: Episode VI - Return of the Jedi',
#   'Actors': ['Mark Hamill',
#    'Harrison Ford',
#    'Carrie Fisher',
#    'Billy Dee Williams']},
#  {'imdbID': 'tt0114709',
#   'Title': 'Toy Story',
#   'Actors': ['Tom Hanks', 'Tim Allen', 'Don Rickles', 'Jim Varney']},
#  {'imdbID': 'tt0105236',
#   'Title': 'Reservoir Dogs',
#   'Actors': ['Harvey Keitel', 'Tim Roth', 'Michael Madsen', 'Chris Penn']},
#  {'imdbID': 'tt0086879',
#   'Title': 'Amadeus',
#   'Actors': ['F. Murray Abraham',
#    'Tom Hulce',
#    'Elizabeth Berridge',
#    'Roy Dotrice']},
#  {'imdbID': 'tt5074352',
#   'Title': 'Dangal',
#   'Actors': ['Aamir Khan',
#    'Fatima Sana Shaikh',
#    'Sanya Malhotra',
#    'Sakshi Tanwar']},
#  {'imdbID': 'tt0361748',
#   'Title': 'Inglourious Basterds',
#   'Actors': ['Brad Pitt', 'Mélanie Laurent', 'Christoph Waltz', 'Eli Roth']},
#  {'imdbID': 'tt0119217',
#   'Title': 'Good Will Hunting',
#   'Actors': ['Matt Damon',
#    'Ben Affleck',
#    'Stellan Skarsgård',
#    'John Mighton']},
#  {'imdbID': 'tt0022100',
#   'Title': 'M',
#   'Actors': ['Peter Lorre', 'Ellen Widmann', 'Inge Landgut', 'Otto Wernicke']},
#  {'imdbID': 'tt0180093',
#   'Title': 'Requiem for a Dream',
#   'Actors': ['Ellen Burstyn',
#    'Jared Leto',
#    'Jennifer Connelly',
#    'Marlon Wayans']},
#  {'imdbID': 'tt0062622',
#   'Title': '2001: A Space Odyssey',
#   'Actors': ['Keir Dullea',
#    'Gary Lockwood',
#    'William Sylvester',
#    'Daniel Richter']},
#  {'imdbID': 'tt0052357',
#   'Title': 'Vertigo',
#   'Actors': ['James Stewart',
#    'Kim Novak',
#    'Barbara Bel Geddes',
#    'Tom Helmore']},
#  {'imdbID': 'tt0338013',
#   'Title': 'Eternal Sunshine of the Spotless Mind',
#   'Actors': ['Jim Carrey',
#    'Kate Winslet',
#    'Gerry Robert Byrne',
#    'Elijah Wood']},
#  {'imdbID': 'tt0033467',
#   'Title': 'Citizen Kane',
#   'Actors': ['Joseph Cotten',
#    'Dorothy Comingore',
#    'Agnes Moorehead',
#    'Ruth Warrick']},
#  {'imdbID': 'tt2106476',
#   'Title': 'The Hunt',
#   'Actors': ['Mads Mikkelsen',
#    'Thomas Bo Larsen',
#    'Annika Wedderkopp',
#    'Lasse Fogelstrøm']},
#  {'imdbID': 'tt0093058',
#   'Title': 'Full Metal Jacket',
#   'Actors': ['Matthew Modine',
#    'Adam Baldwin',
#    "Vincent D'Onofrio",
#    'R. Lee Ermey']},
#  {'imdbID': 'tt0053125',
#   'Title': 'North by Northwest',
#   'Actors': ['Cary Grant',
#    'Eva Marie Saint',
#    'James Mason',
#    'Jessie Royce Landis']},
#  {'imdbID': 'tt0066921',
#   'Title': 'A Clockwork Orange',
#   'Actors': ['Malcolm McDowell',
#    'Patrick Magee',
#    'Michael Bates',
#    'Warren Clarke']},
#  {'imdbID': 'tt0208092',
#   'Title': 'Snatch',
#   'Actors': ['Benicio Del Toro',
#    'Dennis Farina',
#    'Vinnie Jones',
#    'Brad Pitt']},
#  {'imdbID': 'tt0012349',
#   'Title': 'The Kid',
#   'Actors': ['Carl Miller',
#    'Edna Purviance',
#    'Jackie Coogan',
#    'Charles Chaplin']},
#  {'imdbID': 'tt0211915',
#   'Title': 'Amélie',
#   'Actors': ['Audrey Tautou',
#    'Mathieu Kassovitz',
#    'Rufus',
#    'Lorella Cravotta']},
#  {'imdbID': 'tt0040522',
#   'Title': 'Bicycle Thieves',
#   'Actors': ['Lamberto Maggiorani',
#    'Enzo Staiola',
#    'Lianella Carell',
#    'Elena Altieri']},
#  {'imdbID': 'tt0086250',
#   'Title': 'Scarface',
#   'Actors': ['Al Pacino',
#    'Steven Bauer',
#    'Michelle Pfeiffer',
#    'Mary Elizabeth Mastrantonio']},
#  {'imdbID': 'tt0045152',
#   'Title': "Singin' in the Rain",
#   'Actors': ['Gene Kelly',
#    "Donald O'Connor",
#    'Debbie Reynolds',
#    'Jean Hagen']},
#  {'imdbID': 'tt0056172',
#   'Title': 'Lawrence of Arabia',
#   'Actors': ["Peter O'Toole",
#    'Alec Guinness',
#    'Anthony Quinn',
#    'Jack Hawkins']},
#  {'imdbID': 'tt0075314',
#   'Title': 'Taxi Driver',
#   'Actors': ['Diahnne Abbott',
#    'Robinson Frank Adu',
#    'Victor Argo',
#    'Gino Ardito']},
#  {'imdbID': 'tt0435761',
#   'Title': 'Toy Story 3',
#   'Actors': ['Tom Hanks', 'Tim Allen', 'Joan Cusack', 'Ned Beatty']},
#  {'imdbID': 'tt0070735',
#   'Title': 'The Sting',
#   'Actors': ['Paul Newman',
#    'Robert Redford',
#    'Robert Shaw',
#    'Charles Durning']},
#  {'imdbID': 'tt0017136',
#   'Title': 'Metropolis',
#   'Actors': ['Alfred Abel',
#    'Gustav Fröhlich',
#    'Rudolf Klein-Rogge',
#    'Fritz Rasp']},
#  {'imdbID': 'tt0059578',
#   'Title': 'For a Few Dollars More',
#   'Actors': ['Clint Eastwood',
#    'Lee Van Cleef',
#    'Gian Maria Volontè',
#    'Mario Brega']},
#  {'imdbID': 'tt0044741',
#   'Title': 'Ikiru',
#   'Actors': ['Takashi Shimura',
#    "Shin'ichi Himori",
#    'Haruo Tanaka',
#    'Minoru Chiaki']},
#  {'imdbID': 'tt1832382',
#   'Title': 'A Separation',
#   'Actors': ['Payman Maadi',
#    'Leila Hatami',
#    'Sareh Bayat',
#    'Shahab Hosseini']},
#  {'imdbID': 'tt0036775',
#   'Title': 'Double Indemnity',
#   'Actors': ['Fred MacMurray',
#    'Barbara Stanwyck',
#    'Edward G. Robinson',
#    'Porter Hall']},
#  {'imdbID': 'tt0056592',
#   'Title': 'To Kill a Mockingbird',
#   'Actors': ['Gregory Peck',
#    'John Megna',
#    'Frank Overton',
#    'Rosemary Murphy']},
#  {'imdbID': 'tt8267604',
#   'Title': 'Capernaum',
#   'Actors': ['Zain Al Rafeea',
#    'Yordanos Shiferaw',
#    'Boluwatife Treasure Bankole',
#    'Kawsar Al Haddad']},
#  {'imdbID': 'tt0097576',
#   'Title': 'Indiana Jones and the Last Crusade',
#   'Actors': ['Harrison Ford',
#    'Sean Connery',
#    'Denholm Elliott',
#    'Alison Doody']},
#  {'imdbID': 'tt0053604',
#   'Title': 'The Apartment',
#   'Actors': ['Jack Lemmon',
#    'Shirley MacLaine',
#    'Fred MacMurray',
#    'Ray Walston']},
#  {'imdbID': 'tt1049413',
#   'Title': 'Up',
#   'Actors': ['Edward Asner',
#    'Christopher Plummer',
#    'Jordan Nagai',
#    'Bob Peterson']},
#  {'imdbID': 'tt0119488',
#   'Title': 'L.A. Confidential',
#   'Actors': ['Kevin Spacey', 'Russell Crowe', 'Guy Pearce', 'James Cromwell']},
#  {'imdbID': 'tt0071853',
#   'Title': 'Monty Python and the Holy Grail',
#   'Actors': ['Graham Chapman', 'John Cleese', 'Eric Idle', 'Terry Gilliam']},
#  {'imdbID': 'tt1255953',
#   'Title': 'Incendies',
#   'Actors': ['Mustafa Kamel',
#    'Hussein Sami',
#    'Rémy Girard',
#    'Mélissa Désormeaux-Poulin']},
#  {'imdbID': 'tt0113277',
#   'Title': 'Heat',
#   'Actors': ['Al Pacino', 'Robert De Niro', 'Val Kilmer', 'Jon Voight']},
#  {'imdbID': 'tt0042876',
#   'Title': 'Rashomon',
#   'Actors': ['Toshirô Mifune',
#    'Machiko Kyô',
#    'Masayuki Mori',
#    'Takashi Shimura']},
#  {'imdbID': 'tt0055630',
#   'Title': 'Yojimbo',
#   'Actors': ['Toshirô Mifune',
#    'Tatsuya Nakadai',
#    'Yôko Tsukasa',
#    'Isuzu Yamada']},
#  {'imdbID': 'tt0372784',
#   'Title': 'Batman Begins',
#   'Actors': ['Christian Bale',
#    'Michael Caine',
#    'Liam Neeson',
#    'Katie Holmes']},
#  {'imdbID': 'tt0095016',
#   'Title': 'Die Hard',
#   'Actors': ['Bruce Willis',
#    'Bonnie Bedelia',
#    'Reginald VelJohnson',
#    'Paul Gleason']},
#  {'imdbID': 'tt0105695',
#   'Title': 'Unforgiven',
#   'Actors': ['Clint Eastwood',
#    'Gene Hackman',
#    'Morgan Freeman',
#    'Richard Harris']},
#  {'imdbID': 'tt6966692',
#   'Title': 'Green Book',
#   'Actors': ['Viggo Mortensen',
#    'Mahershala Ali',
#    'Linda Cardellini',
#    'Sebastian Maniscalco']},
#  {'imdbID': 'tt0363163',
#   'Title': 'Downfall',
#   'Actors': ['Bruno Ganz',
#    'Alexandra Maria Lara',
#    'Corinna Harfouch',
#    'Ulrich Matthes']},
#  {'imdbID': 'tt0118849',
#   'Title': 'Children of Heaven',
#   'Actors': ['Mohammad Amir Naji',
#    'Amir Farrokh Hashemian',
#    'Bahare Seddiqi',
#    'Nafise Jafar-Mohammadi']},
#  {'imdbID': 'tt0053291',
#   'Title': 'Some Like It Hot',
#   'Actors': ['Marilyn Monroe', 'Tony Curtis', 'Jack Lemmon', 'George Raft']},
#  {'imdbID': 'tt0347149',
#   'Title': "Howl's Moving Castle",
#   'Actors': ['Chieko Baishô',
#    'Takuya Kimura',
#    'Akihiro Miwa',
#    'Tatsuya Gashûin']},
#  {'imdbID': 'tt0057115',
#   'Title': 'The Great Escape',
#   'Actors': ['Steve McQueen',
#    'James Garner',
#    'Richard Attenborough',
#    'James Donald']},
#  {'imdbID': 'tt0096283',
#   'Title': 'My Neighbor Totoro',
#   'Actors': ['Noriko Hidaka',
#    'Chika Sakamoto',
#    'Shigesato Itoi',
#    'Sumi Shimamoto']},
#  {'imdbID': 'tt0089881',
#   'Title': 'Ran',
#   'Actors': ['Tatsuya Nakadai',
#    'Akira Terao',
#    'Jinpachi Nezu',
#    'Daisuke Ryû']},
#  {'imdbID': 'tt0268978',
#   'Title': 'A Beautiful Mind',
#   'Actors': ['Russell Crowe',
#    'Ed Harris',
#    'Jennifer Connelly',
#    'Christopher Plummer']},
#  {'imdbID': 'tt0042192',
#   'Title': 'All About Eve',
#   'Actors': ['Bette Davis', 'Anne Baxter', 'George Sanders', 'Celeste Holm']},
#  {'imdbID': 'tt0457430',
#   'Title': "Pan's Labyrinth",
#   'Actors': ['Ivana Baquero', 'Sergi López', 'Maribel Verdú', 'Doug Jones']},
#  {'imdbID': 'tt0091251',
#   'Title': 'Come and See',
#   'Actors': ['Aleksey Kravchenko',
#    'Olga Mironova',
#    'Liubomiras Laucevicius',
#    'Vladas Bagdonas']},
#  {'imdbID': 'tt0112641',
#   'Title': 'Casino',
#   'Actors': ['Robert De Niro', 'Sharon Stone', 'Joe Pesci', 'James Woods']},
#  {'imdbID': 'tt1305806',
#   'Title': 'The Secret in Their Eyes',
#   'Actors': ['Soledad Villamil',
#    'Ricardo Darín',
#    'Carla Quevedo',
#    'Pablo Rago']},
#  {'imdbID': 'tt0081398',
#   'Title': 'Raging Bull',
#   'Actors': ['Robert De Niro',
#    'Cathy Moriarty',
#    'Joe Pesci',
#    'Frank Vincent']},
#  {'imdbID': 'tt0120735',
#   'Title': 'Lock, Stock and Two Smoking Barrels',
#   'Actors': ['Jason Flemyng',
#    'Dexter Fletcher',
#    'Nick Moran',
#    'Jason Statham']},
#  {'imdbID': 'tt3417422',
#   'Title': 'Drishyam',
#   'Actors': ['Mohanlal', 'Kalabhavan Rahman', 'Balaji Sarma', 'Sreekumar']},
#  {'imdbID': 'tt0040897',
#   'Title': 'The Treasure of the Sierra Madre',
#   'Actors': ['Humphrey Bogart', 'Walter Huston', 'Tim Holt', 'Bruce Bennett']},
#  {'imdbID': 'tt0993846',
#   'Title': 'The Wolf of Wall Street',
#   'Actors': ['Leonardo DiCaprio',
#    'Jonah Hill',
#    'Margot Robbie',
#    'Matthew McConaughey']},
#  {'imdbID': 'tt0476735',
#   'Title': 'My Father and My Son',
#   'Actors': ['Çetin Tekindor', 'Fikret Kuskan', 'Hümeyra', 'Ege Tanman']},
#  {'imdbID': 'tt0055031',
#   'Title': 'Judgment at Nuremberg',
#   'Actors': ['Spencer Tracy',
#    'Burt Lancaster',
#    'Richard Widmark',
#    'Marlene Dietrich']},
#  {'imdbID': 'tt5027774',
#   'Title': 'Three Billboards Outside Ebbing, Missouri',
#   'Actors': ['Frances McDormand',
#    'Caleb Landry Jones',
#    'Kerry Condon',
#    'Sam Rockwell']},
#  {'imdbID': 'tt0071315',
#   'Title': 'Chinatown',
#   'Actors': ['Jack Nicholson', 'Faye Dunaway', 'John Huston', 'Perry Lopez']},
#  {'imdbID': 'tt0015864',
#   'Title': 'The Gold Rush',
#   'Actors': ['Charles Chaplin', 'Mack Swain', 'Tom Murray', 'Henry Bergman']},
#  {'imdbID': 'tt0046912',
#   'Title': 'Dial M for Murder',
#   'Actors': ['Ray Milland',
#    'Grace Kelly',
#    'Robert Cummings',
#    'John Williams']},
#  {'imdbID': 'tt0469494',
#   'Title': 'There Will Be Blood',
#   'Actors': ['Daniel Day-Lewis',
#    'Martin Stringer',
#    'Matthew Braden Stringer',
#    'Jacob Stringer']},
#  {'imdbID': 'tt2096673',
#   'Title': 'Inside Out',
#   'Actors': ['Amy Poehler', 'Phyllis Smith', 'Richard Kind', 'Bill Hader']},
#  {'imdbID': 'tt0434409',
#   'Title': 'V for Vendetta',
#   'Actors': ['Natalie Portman', 'Hugo Weaving', 'Stephen Rea', 'Stephen Fry']},
#  {'imdbID': 'tt0050976',
#   'Title': 'The Seventh Seal',
#   'Actors': ['Gunnar Björnstrand',
#    'Bengt Ekerot',
#    'Nils Poppe',
#    'Max von Sydow']},
#  {'imdbID': 'tt1291584',
#   'Title': 'Warrior',
#   'Actors': ['Joel Edgerton', 'Tom Hardy', 'Nick Nolte', 'Jennifer Morrison']},
#  {'imdbID': 'tt3170832',
#   'Title': 'Room',
#   'Actors': ['Brie Larson',
#    'Jacob Tremblay',
#    'Sean Bridgers',
#    'Wendy Crewson']},
#  {'imdbID': 'tt0477348',
#   'Title': 'No Country for Old Men',
#   'Actors': ['Tommy Lee Jones',
#    'Javier Bardem',
#    'Josh Brolin',
#    'Woody Harrelson']},
#  {'imdbID': 'tt0117951',
#   'Title': 'Trainspotting',
#   'Actors': ['Ewan McGregor',
#    'Ewen Bremner',
#    'Jonny Lee Miller',
#    'Kevin McKidd']},
#  {'imdbID': 'tt0080678',
#   'Title': 'The Elephant Man',
#   'Actors': ['Anthony Hopkins', 'John Hurt', 'Anne Bancroft', 'John Gielgud']},
#  {'imdbID': 'tt0167404',
#   'Title': 'The Sixth Sense',
#   'Actors': ['Bruce Willis',
#    'Haley Joel Osment',
#    'Toni Collette',
#    'Olivia Williams']},
#  {'imdbID': 'tt1130884',
#   'Title': 'Shutter Island',
#   'Actors': ['Leonardo DiCaprio',
#    'Mark Ruffalo',
#    'Ben Kingsley',
#    'Max von Sydow']},
#  {'imdbID': 'tt8108198',
#   'Title': 'Andhadhun',
#   'Actors': ['Ayushmann Khurrana', 'Tabu', 'Radhika Apte', 'Anil Dhawan']},
#  {'imdbID': 'tt0084787',
#   'Title': 'The Thing',
#   'Actors': ['Kurt Russell',
#    'Wilford Brimley',
#    'T.K. Carter',
#    'David Clennon']},
#  {'imdbID': 'tt0031381',
#   'Title': 'Gone with the Wind',
#   'Actors': ['Thomas Mitchell',
#    "Barbara O'Neil",
#    'Vivien Leigh',
#    'Evelyn Keyes']},
#  {'imdbID': 'tt0050212',
#   'Title': 'The Bridge on the River Kwai',
#   'Actors': ['William Holden',
#    'Alec Guinness',
#    'Jack Hawkins',
#    'Sessue Hayakawa']},
#  {'imdbID': 'tt0083658',
#   'Title': 'Blade Runner',
#   'Actors': ['Harrison Ford',
#    'Rutger Hauer',
#    'Sean Young',
#    'Edward James Olmos']},
#  {'imdbID': 'tt0041959',
#   'Title': 'The Third Man',
#   'Actors': ['Joseph Cotten', 'Alida Valli', 'Orson Welles', 'Trevor Howard']},
#  {'imdbID': 'tt0047296',
#   'Title': 'On the Waterfront',
#   'Actors': ['Marlon Brando', 'Karl Malden', 'Lee J. Cobb', 'Rod Steiger']},
#  {'imdbID': 'tt0107290',
#   'Title': 'Jurassic Park',
#   'Actors': ['Sam Neill',
#    'Laura Dern',
#    'Jeff Goldblum',
#    'Richard Attenborough']},
#  {'imdbID': 'tt0050986',
#   'Title': 'Wild Strawberries',
#   'Actors': ['Victor Sjöström',
#    'Bibi Andersson',
#    'Ingrid Thulin',
#    'Gunnar Björnstrand']},
#  {'imdbID': 'tt0266543',
#   'Title': 'Finding Nemo',
#   'Actors': ['Albert Brooks',
#    'Ellen DeGeneres',
#    'Alexander Gould',
#    'Willem Dafoe']},
#  {'imdbID': 'tt0116231',
#   'Title': 'The Bandit',
#   'Actors': ['Sener Sen', 'Ugur Yücel', 'Sermin Hürmeriç', 'Yesim Salkim']},
#  {'imdbID': 'tt1205489',
#   'Title': 'Gran Torino',
#   'Actors': ['Clint Eastwood', 'Christopher Carley', 'Bee Vang', 'Ahney Her']},
#  {'imdbID': 'tt0116282',
#   'Title': 'Fargo',
#   'Actors': ['William H. Macy',
#    'Steve Buscemi',
#    'Peter Stormare',
#    'Kristin Rudrüd']},
#  {'imdbID': 'tt0266697',
#   'Title': 'Kill Bill: Vol. 1',
#   'Actors': ['Uma Thurman', 'Lucy Liu', 'Vivica A. Fox', 'Daryl Hannah']},
#  {'imdbID': 'tt0077416',
#   'Title': 'The Deer Hunter',
#   'Actors': ['Robert De Niro',
#    'John Cazale',
#    'John Savage',
#    'Christopher Walken']},
#  {'imdbID': 'tt0079944',
#   'Title': 'Stalker',
#   'Actors': ['Alisa Freyndlikh',
#    'Aleksandr Kaydanovskiy',
#    'Anatoliy Solonitsyn',
#    'Nikolay Grinko']},
#  {'imdbID': 'tt0120382',
#   'Title': 'The Truman Show',
#   'Actors': ['Jim Carrey',
#    'Laura Linney',
#    'Noah Emmerich',
#    'Natascha McElhone']},
#  {'imdbID': 'tt0118715',
#   'Title': 'The Big Lebowski',
#   'Actors': ['Jeff Bridges',
#    'John Goodman',
#    'Julianne Moore',
#    'Steve Buscemi']},
#  {'imdbID': 'tt0046438',
#   'Title': 'Tokyo Story',
#   'Actors': ['Chishû Ryû',
#    'Chieko Higashiyama',
#    'Setsuko Hara',
#    'Haruko Sugimura']},
#  {'imdbID': 'tt3011894',
#   'Title': 'Wild Tales',
#   'Actors': ['Darío Grandinetti',
#    'María Marull',
#    'Mónica Villa',
#    'Diego Starosta']},
#  {'imdbID': 'tt0978762',
#   'Title': 'Mary and Max',
#   'Actors': ['Christopher Massey',
#    'Oliver Marks',
#    'Daisy Kocher',
#    'Daniel Marks']},
#  {'imdbID': 'tt0107207',
#   'Title': 'In the Name of the Father',
#   'Actors': ['Alison Crosbie',
#    'Daniel Day-Lewis',
#    'Philip King',
#    'Emma Thompson']},
#  {'imdbID': 'tt2267998',
#   'Title': 'Gone Girl',
#   'Actors': ['Ben Affleck',
#    'Rosamund Pike',
#    'Neil Patrick Harris',
#    'Tyler Perry']},
#  {'imdbID': 'tt2119532',
#   'Title': 'Hacksaw Ridge',
#   'Actors': ['Andrew Garfield',
#    'Richard Pyros',
#    'Jacob Warner',
#    'Milo Gibson']},
#  {'imdbID': 'tt0017925',
#   'Title': 'The General',
#   'Actors': ['Marion Mack', 'Glen Cavender', 'Jim Farley', 'Frederick Vroom']},
#  {'imdbID': 'tt0015324',
#   'Title': 'Sherlock Jr.',
#   'Actors': ['Buster Keaton',
#    'Kathryn McGuire',
#    'Joe Keaton',
#    'Erwin Connelly']},
#  {'imdbID': 'tt0892769',
#   'Title': 'How to Train Your Dragon',
#   'Actors': ['Jay Baruchel',
#    'Gerard Butler',
#    'Craig Ferguson',
#    'America Ferrera']},
#  {'imdbID': 'tt0031679',
#   'Title': 'Mr. Smith Goes to Washington',
#   'Actors': ['Jean Arthur', 'James Stewart', 'Claude Rains', 'Edward Arnold']},
#  {'imdbID': 'tt0353969',
#   'Title': 'Memories of Murder',
#   'Actors': ['Kang-ho Song', 'Sang-kyung Kim', 'Roe-ha Kim', 'Jae-ho Song']},
#  {'imdbID': 'tt2278388',
#   'Title': 'The Grand Budapest Hotel',
#   'Actors': ['Ralph Fiennes',
#    'F. Murray Abraham',
#    'Mathieu Amalric',
#    'Adrien Brody']},
#  {'imdbID': 'tt0060827',
#   'Title': 'Persona',
#   'Actors': ['Bibi Andersson',
#    'Liv Ullmann',
#    'Margaretha Krook',
#    'Gunnar Björnstrand']},
#  {'imdbID': 'tt0112471',
#   'Title': 'Before Sunrise',
#   'Actors': ['Ethan Hawke', 'Julie Delpy', 'Andrea Eckert', 'Hanno Pöschl']},
#  {'imdbID': 'tt0264464',
#   'Title': 'Catch Me If You Can',
#   'Actors': ['Leonardo DiCaprio',
#    'Tom Hanks',
#    'Christopher Walken',
#    'Martin Sheen']},
#  {'imdbID': 'tt0758758',
#   'Title': 'Into the Wild',
#   'Actors': ['Emile Hirsch',
#    'Marcia Gay Harden',
#    'William Hurt',
#    'Jena Malone']},
#  {'imdbID': 'tt0061512',
#   'Title': 'Cool Hand Luke',
#   'Actors': ['Paul Newman', 'George Kennedy', 'J.D. Cannon', 'Lou Antonio']},
#  {'imdbID': 'tt0046268',
#   'Title': 'The Wages of Fear',
#   'Actors': ['Yves Montand',
#    'Charles Vanel',
#    'Folco Lulli',
#    'Peter van Eyck']},
#  {'imdbID': 'tt2024544',
#   'Title': '12 Years a Slave',
#   'Actors': ['Chiwetel Ejiofor',
#    'Dwight Henry',
#    'Dickie Gravois',
#    'Bryan Batt']},
#  {'imdbID': 'tt1392214',
#   'Title': 'Prisoners',
#   'Actors': ['Hugh Jackman', 'Jake Gyllenhaal', 'Viola Davis', 'Maria Bello']},
#  {'imdbID': 'tt0074958',
#   'Title': 'Network',
#   'Actors': ['Faye Dunaway',
#    'William Holden',
#    'Peter Finch',
#    'Robert Duvall']},
#  {'imdbID': 'tt0040725',
#   'Title': 'The Red Shoes',
#   'Actors': ['Marius Goring', 'Jean Short', 'Gordon Littmann', 'Julia Lang']},
#  {'imdbID': 'tt0079470',
#   'Title': "Monty Python's Life of Brian",
#   'Actors': ['Graham Chapman', 'John Cleese', 'Terry Gilliam', 'Eric Idle']},
#  {'imdbID': 'tt0092005',
#   'Title': 'Stand by Me',
#   'Actors': ['Wil Wheaton',
#    'River Phoenix',
#    'Corey Feldman',
#    "Jerry O'Connell"]},
#  {'imdbID': 'tt1392190',
#   'Title': 'Mad Max: Fury Road',
#   'Actors': ['Tom Hardy',
#    'Charlize Theron',
#    'Nicholas Hoult',
#    'Hugh Keays-Byrne']},
#  {'imdbID': 'tt0019254',
#   'Title': 'The Passion of Joan of Arc',
#   'Actors': ['Maria Falconetti',
#    'Eugene Silvain',
#    'André Berley',
#    'Maurice Schutz']},
#  {'imdbID': 'tt0405508',
#   'Title': 'Rang De Basanti',
#   'Actors': ['Aamir Khan', 'Siddharth', 'Sharman Joshi', 'Kunal Kapoor']},
#  {'imdbID': 'tt0091763',
#   'Title': 'Platoon',
#   'Actors': ['Tom Berenger',
#    'Keith David',
#    'Willem Dafoe',
#    'Forest Whitaker']},
#  {'imdbID': 'tt0060107',
#   'Title': 'Andrei Rublev',
#   'Actors': ['Anatoliy Solonitsyn',
#    'Ivan Lapikov',
#    'Nikolay Grinko',
#    'Nikolay Sergeev']},
#  {'imdbID': 'tt0405159',
#   'Title': 'Million Dollar Baby',
#   'Actors': ['Clint Eastwood',
#    'Hilary Swank',
#    'Morgan Freeman',
#    'Jay Baruchel']},
#  {'imdbID': 'tt1979320',
#   'Title': 'Rush',
#   'Actors': ['Chris Hemsworth',
#    'Daniel Brühl',
#    'Olivia Wilde',
#    'Alexandra Maria Lara']},
#  {'imdbID': 'tt1028532',
#   'Title': "Hachi: A Dog's Tale",
#   'Actors': ['Richard Gere',
#    'Joan Allen',
#    'Cary-Hiroyuki Tagawa',
#    'Sarah Roemer']},
#  {'imdbID': 'tt3315342',
#   'Title': 'Logan',
#   'Actors': ['Hugh Jackman',
#    'Patrick Stewart',
#    'Dafne Keen',
#    'Boyd Holbrook']},
#  {'imdbID': 'tt0072684',
#   'Title': 'Barry Lyndon',
#   'Actors': ["Ryan O'Neal",
#    'Marisa Berenson',
#    'Patrick Magee',
#    'Hardy Krüger']},
#  {'imdbID': 'tt0052618',
#   'Title': 'Ben-Hur',
#   'Actors': ['Charlton Heston',
#    'Jack Hawkins',
#    'Haya Harareet',
#    'Stephen Boyd']},
#  {'imdbID': 'tt0087544',
#   'Title': 'Nausicaä of the Valley of the Wind',
#   'Actors': ['Sumi Shimamoto',
#    'Mahito Tsujimura',
#    'Hisako Kyôda',
#    'Gorô Naya']},
#  {'imdbID': 'tt0395169',
#   'Title': 'Hotel Rwanda',
#   'Actors': ['Xolani Mali',
#    'Don Cheadle',
#    'Desmond Dube',
#    'Hakeem Kae-Kazim']},
#  {'imdbID': 'tt0245712',
#   'Title': 'Amores Perros',
#   'Actors': ['Emilio Echevarría',
#    'Gael García Bernal',
#    'Goya Toledo',
#    'Álvaro Guerrero']},
#  {'imdbID': 'tt1201607',
#   'Title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'Actors': ['Ralph Fiennes',
#    'Michael Gambon',
#    'Alan Rickman',
#    'Daniel Radcliffe']},
#  {'imdbID': 'tt0053198',
#   'Title': 'The 400 Blows',
#   'Actors': ['Jean-Pierre Léaud',
#    'Claire Maurier',
#    'Albert Rémy',
#    'Guy Decomble']},
#  {'imdbID': 'tt1895587',
#   'Title': 'Spotlight',
#   'Actors': ['Mark Ruffalo',
#    'Michael Keaton',
#    'Rachel McAdams',
#    'Liev Schreiber']},
#  {'imdbID': 'tt0097165',
#   'Title': 'Dead Poets Society',
#   'Actors': ['Robin Williams',
#    'Robert Sean Leonard',
#    'Ethan Hawke',
#    'Josh Charles']},
#  {'imdbID': 'tt0042041',
#   'Title': 'White Heat',
#   'Actors': ['James Cagney',
#    'Virginia Mayo',
#    "Edmond O'Brien",
#    'Margaret Wycherly']},
#  {'imdbID': 'tt0043338',
#   'Title': 'Ace in the Hole',
#   'Actors': ['Kirk Douglas', 'Jan Sterling', 'Robert Arthur', 'Porter Hall']},
#  {'imdbID': 'tt0032976',
#   'Title': 'Rebecca',
#   'Actors': ['Laurence Olivier',
#    'Joan Fontaine',
#    'George Sanders',
#    'Judith Anderson']},
#  {'imdbID': 'tt0075148',
#   'Title': 'Rocky',
#   'Actors': ['Sylvester Stallone',
#    'Talia Shire',
#    'Burt Young',
#    'Carl Weathers']},
#  {'imdbID': 'tt0198781',
#   'Title': 'Monsters, Inc.',
#   'Actors': ['John Goodman', 'Billy Crystal', 'Mary Gibbs', 'Steve Buscemi']},
#  {'imdbID': 'tt0025316',
#   'Title': 'It Happened One Night',
#   'Actors': ['Clark Gable',
#    'Claudette Colbert',
#    'Walter Connolly',
#    'Roscoe Karns']},
#  {'imdbID': 'tt0113247',
#   'Title': 'La Haine',
#   'Actors': ['Vincent Cassel',
#    'Hubert Koundé',
#    'Saïd Taghmaoui',
#    'Abdel Ahmed Ghili']},
#  {'imdbID': 'tt4016934',
#   'Title': 'The Handmaiden',
#   'Actors': ['Min-hee Kim', 'Tae-ri Kim', 'Jung-woo Ha', 'Jin-woong Cho']},
#  {'imdbID': 'tt1954470',
#   'Title': 'Gangs of Wasseypur',
#   'Actors': ['Manoj Bajpayee',
#    'Richa Chadha',
#    'Nawazuddin Siddiqui',
#    'Tigmanshu Dhulia']},
#  {'imdbID': 'tt0169102',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Actors': ['Aamir Khan',
#    'Gracy Singh',
#    'Rachel Shelley',
#    'Paul Blackthorne']},
#  {'imdbID': 'tt0093779',
#   'Title': 'The Princess Bride',
#   'Actors': ['Cary Elwes',
#    'Mandy Patinkin',
#    'Chris Sarandon',
#    'Christopher Guest']},
#  {'imdbID': 'tt2338151',
#   'Title': 'PK',
#   'Actors': ['Aamir Khan', 'Anushka Sharma', 'Saurabh Shukla', 'Sanjay Dutt']},
#  {'imdbID': 'tt0374887',
#   'Title': 'Munna Bhai M.B.B.S.',
#   'Actors': ['Sanjay Dutt', 'Arshad Warsi', 'Gracy Singh', 'Sunil Dutt']},
#  {'imdbID': 'tt0064115',
#   'Title': 'Butch Cassidy and the Sundance Kid',
#   'Actors': ['Paul Newman',
#    'Robert Redford',
#    'Katharine Ross',
#    'Strother Martin']},
#  {'imdbID': 'tt0381681',
#   'Title': 'Before Sunset',
#   'Actors': ['Ethan Hawke',
#    'Julie Delpy',
#    'Vernon Dobtcheff',
#    'Louise Lemoine Torrès']},
#  {'imdbID': 'tt1454029',
#   'Title': 'The Help',
#   'Actors': ['Emma Stone',
#    'Viola Davis',
#    'Bryce Dallas Howard',
#    'Octavia Spencer']},
#  {'imdbID': 'tt0094625',
#   'Title': 'Akira',
#   'Actors': ['Mitsuo Iwata', 'Nozomu Sasaki', 'Mami Koyama', 'Tesshô Genda']},
#  {'imdbID': 'tt0088247',
#   'Title': 'The Terminator',
#   'Actors': ['Arnold Schwarzenegger',
#    'Michael Biehn',
#    'Linda Hamilton',
#    'Paul Winfield']},
#  {'imdbID': 'tt0118694',
#   'Title': 'In the Mood for Love',
#   'Actors': ['Maggie Cheung',
#    'Tony Chiu-Wai Leung',
#    'Ping Lam Siu',
#    "Tung Cho 'Joe' Cheung"]},
#  {'imdbID': 'tt0367110',
#   'Title': 'Swades',
#   'Actors': ['Shah Rukh Khan',
#    'Gayatri Joshi',
#    'Kishori Ballal',
#    'Smit Sheth']},
#  {'imdbID': 'tt0087884',
#   'Title': 'Paris, Texas',
#   'Actors': ['Harry Dean Stanton',
#    'Nastassja Kinski',
#    'Dean Stockwell',
#    'Aurore Clément']},
#  {'imdbID': 'tt0103639',
#   'Title': 'Aladdin',
#   'Actors': ['Scott Weinger',
#    'Robin Williams',
#    'Linda Larkin',
#    'Jonathan Freeman']},
#  {'imdbID': 'tt2015381',
#   'Title': 'Guardians of the Galaxy',
#   'Actors': ['Chris Pratt', 'Zoe Saldana', 'Dave Bautista', 'Vin Diesel']},
#  {'imdbID': 'tt0338564',
#   'Title': 'Infernal Affairs',
#   'Actors': ['Andy Lau',
#    'Tony Chiu-Wai Leung',
#    'Anthony Chau-Sang Wong',
#    'Eric Tsang']},
#  {'imdbID': 'tt0058946',
#   'Title': 'The Battle of Algiers',
#   'Actors': ['Jean Martin', 'Yacef Saadi', 'Brahim Hadjadj', 'Tommaso Neri']},
#  {'imdbID': 'tt0092067',
#   'Title': 'Castle in the Sky',
#   'Actors': ['Anna Paquin',
#    'James Van Der Beek',
#    'Cloris Leachman',
#    'Mark Hamill']},
#  {'imdbID': 'tt0120731',
#   'Title': 'The Legend of 1900',
#   'Actors': ['Tim Roth',
#    'Pruitt Taylor Vince',
#    'Mélanie Thierry',
#    'Bill Nunn']},
#  {'imdbID': 'tt0050613',
#   'Title': 'Throne of Blood',
#   'Actors': ['Toshirô Mifune',
#    'Isuzu Yamada',
#    'Takashi Shimura',
#    'Akira Kubo']}]

# %%
# Making tuple list for Actors Table
movie_list_actors = []
for movie in imdb_actors:
    
    for i , value in enumerate(movie['Actors']):
        actor_tuple = (movie['imdbID'], movie['Title'],movie['Actors'][i])
        movie_list_actors.append(actor_tuple)
            
movie_list_actors
# Out:
# [('tt0111161', 'The Shawshank Redemption', 'Tim Robbins'),
#  ('tt0111161', 'The Shawshank Redemption', 'Morgan Freeman'),
#  ('tt0111161', 'The Shawshank Redemption', 'Bob Gunton'),
#  ('tt0111161', 'The Shawshank Redemption', 'William Sadler'),
#  ('tt0068646', 'The Godfather', 'Marlon Brando'),
#  ('tt0068646', 'The Godfather', 'Al Pacino'),
#  ('tt0068646', 'The Godfather', 'James Caan'),
#  ('tt0068646', 'The Godfather', 'Richard S. Castellano'),
#  ('tt0071562', 'The Godfather: Part II', 'Al Pacino'),
#  ('tt0071562', 'The Godfather: Part II', 'Robert Duvall'),
#  ('tt0071562', 'The Godfather: Part II', 'Diane Keaton'),
#  ('tt0071562', 'The Godfather: Part II', 'Robert De Niro'),
#  ('tt0468569', 'The Dark Knight', 'Christian Bale'),
#  ('tt0468569', 'The Dark Knight', 'Heath Ledger'),
#  ('tt0468569', 'The Dark Knight', 'Aaron Eckhart'),
#  ('tt0468569', 'The Dark Knight', 'Michael Caine'),
#  ('tt0050083', '12 Angry Men', 'Martin Balsam'),
#  ('tt0050083', '12 Angry Men', 'John Fiedler'),
#  ('tt0050083', '12 Angry Men', 'Lee J. Cobb'),
#  ('tt0050083', '12 Angry Men', 'E.G. Marshall'),
#  ('tt0108052', "Schindler's List", 'Liam Neeson'),
#  ('tt0108052', "Schindler's List", 'Ben Kingsley'),
#  ('tt0108052', "Schindler's List", 'Ralph Fiennes'),
#  ('tt0108052', "Schindler's List", 'Caroline Goodall'),
#  ('tt0167260',
#   'The Lord of the Rings: The Return of the King',
#   'Noel Appleby'),
#  ('tt0167260', 'The Lord of the Rings: The Return of the King', 'Ali Astin'),
#  ('tt0167260', 'The Lord of the Rings: The Return of the King', 'Sean Astin'),
#  ('tt0167260', 'The Lord of the Rings: The Return of the King', 'David Aston'),
#  ('tt0110912', 'Pulp Fiction', 'Tim Roth'),
#  ('tt0110912', 'Pulp Fiction', 'Amanda Plummer'),
#  ('tt0110912', 'Pulp Fiction', 'Laura Lovelace'),
#  ('tt0110912', 'Pulp Fiction', 'John Travolta'),
#  ('tt0060196', 'The Good, the Bad and the Ugly', 'Eli Wallach'),
#  ('tt0060196', 'The Good, the Bad and the Ugly', 'Clint Eastwood'),
#  ('tt0060196', 'The Good, the Bad and the Ugly', 'Lee Van Cleef'),
#  ('tt0060196', 'The Good, the Bad and the Ugly', 'Aldo Giuffrè'),
#  ('tt0137523', 'Fight Club', 'Edward Norton'),
#  ('tt0137523', 'Fight Club', 'Brad Pitt'),
#  ('tt0137523', 'Fight Club', 'Meat Loaf'),
#  ('tt0137523', 'Fight Club', 'Zach Grenier'),
#  ('tt0120737',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Alan Howard'),
#  ('tt0120737',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Noel Appleby'),
#  ('tt0120737',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Sean Astin'),
#  ('tt0120737',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Sala Baker'),
#  ('tt0109830', 'Forrest Gump', 'Tom Hanks'),
#  ('tt0109830', 'Forrest Gump', 'Rebecca Williams'),
#  ('tt0109830', 'Forrest Gump', 'Sally Field'),
#  ('tt0109830', 'Forrest Gump', 'Michael Conner Humphreys'),
#  ('tt1375666', 'Inception', 'Leonardo DiCaprio'),
#  ('tt1375666', 'Inception', 'Joseph Gordon-Levitt'),
#  ('tt1375666', 'Inception', 'Ellen Page'),
#  ('tt1375666', 'Inception', 'Tom Hardy'),
#  ('tt0080684',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'Mark Hamill'),
#  ('tt0080684',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'Harrison Ford'),
#  ('tt0080684',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'Carrie Fisher'),
#  ('tt0080684',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'Billy Dee Williams'),
#  ('tt7286456', 'Joker', 'Joaquin Phoenix'),
#  ('tt7286456', 'Joker', 'Robert De Niro'),
#  ('tt7286456', 'Joker', 'Zazie Beetz'),
#  ('tt7286456', 'Joker', 'Frances Conroy'),
#  ('tt0167261', 'The Lord of the Rings: The Two Towers', 'Bruce Allpress'),
#  ('tt0167261', 'The Lord of the Rings: The Two Towers', 'Sean Astin'),
#  ('tt0167261', 'The Lord of the Rings: The Two Towers', 'John Bach'),
#  ('tt0167261', 'The Lord of the Rings: The Two Towers', 'Sala Baker'),
#  ('tt0133093', 'The Matrix', 'Keanu Reeves'),
#  ('tt0133093', 'The Matrix', 'Laurence Fishburne'),
#  ('tt0133093', 'The Matrix', 'Carrie-Anne Moss'),
#  ('tt2278388', 'The Grand Budapest Hotel', 'F. Murray Abraham'),
#  ('tt2278388', 'The Grand Budapest Hotel', 'Mathieu Amalric'),
#  ('tt2278388', 'The Grand Budapest Hotel', 'Adrien Brody'),
#  ('tt0060827', 'Persona', 'Bibi Andersson'),
#  ('tt0060827', 'Persona', 'Liv Ullmann'),
#  ('tt0060827', 'Persona', 'Margaretha Krook'),
#  ('tt0060827', 'Persona', 'Gunnar Björnstrand'),
#  ('tt0112471', 'Before Sunrise', 'Ethan Hawke'),
#  ('tt0112471', 'Before Sunrise', 'Julie Delpy'),
#  ('tt0112471', 'Before Sunrise', 'Andrea Eckert'),
#  ('tt0112471', 'Before Sunrise', 'Hanno Pöschl'),
#  ('tt0264464', 'Catch Me If You Can', 'Leonardo DiCaprio'),
#  ('tt0264464', 'Catch Me If You Can', 'Tom Hanks'),
#  ('tt0264464', 'Catch Me If You Can', 'Christopher Walken'),
#  ('tt0264464', 'Catch Me If You Can', 'Martin Sheen'),
#  ('tt0758758', 'Into the Wild', 'Emile Hirsch'),
#  ('tt0758758', 'Into the Wild', 'Marcia Gay Harden'),
#  ('tt0758758', 'Into the Wild', 'William Hurt'),
#  ('tt0758758', 'Into the Wild', 'Jena Malone'),
#  ('tt0061512', 'Cool Hand Luke', 'Paul Newman'),
#  ('tt0061512', 'Cool Hand Luke', 'George Kennedy'),
#  ('tt0061512', 'Cool Hand Luke', 'J.D. Cannon'),
#  ('tt0061512', 'Cool Hand Luke', 'Lou Antonio'),
#  ('tt0046268', 'The Wages of Fear', 'Yves Montand'),
#  ('tt0046268', 'The Wages of Fear', 'Charles Vanel'),
#  ('tt0046268', 'The Wages of Fear', 'Folco Lulli'),
#  ('tt0046268', 'The Wages of Fear', 'Peter van Eyck'),
#  ('tt2024544', '12 Years a Slave', 'Chiwetel Ejiofor'),
#  ('tt2024544', '12 Years a Slave', 'Dwight Henry'),
#  ('tt2024544', '12 Years a Slave', 'Dickie Gravois'),
#  ('tt2024544', '12 Years a Slave', 'Bryan Batt'),
#  ('tt1392214', 'Prisoners', 'Hugh Jackman'),
#  ('tt1392214', 'Prisoners', 'Jake Gyllenhaal'),
#  ('tt1392214', 'Prisoners', 'Viola Davis'),
#  ('tt1392214', 'Prisoners', 'Maria Bello'),
#  ('tt0074958', 'Network', 'Faye Dunaway'),
#  ('tt0074958', 'Network', 'William Holden'),
#  ('tt0074958', 'Network', 'Peter Finch'),
#  ('tt0074958', 'Network', 'Robert Duvall'),
#  ('tt0040725', 'The Red Shoes', 'Marius Goring'),
#  ('tt0040725', 'The Red Shoes', 'Jean Short'),
#  ('tt0040725', 'The Red Shoes', 'Gordon Littmann'),
#  ('tt0040725', 'The Red Shoes', 'Julia Lang'),
#  ('tt0079470', "Monty Python's Life of Brian", 'Graham Chapman'),
#  ('tt0079470', "Monty Python's Life of Brian", 'John Cleese'),
#  ('tt0079470', "Monty Python's Life of Brian", 'Terry Gilliam'),
#  ('tt0079470', "Monty Python's Life of Brian", 'Eric Idle'),
#  ('tt0120731', 'The Legend of 1900', 'Tim Roth'),
#  ('tt0120731', 'The Legend of 1900', 'Pruitt Taylor Vince'),
#  ('tt0120731', 'The Legend of 1900', 'Mélanie Thierry'),
#  ('tt0120731', 'The Legend of 1900', 'Bill Nunn'),
#  ('tt0050613', 'Throne of Blood', 'Toshirô Mifune'),
#  ('tt0050613', 'Throne of Blood', 'Isuzu Yamada'),
#  ('tt0050613', 'Throne of Blood', 'Takashi Shimura'),
#  ('tt0050613', 'Throne of Blood', 'Akira Kubo')]

# %%
# Inserting into table Actors
insert_stmt = "INSERT IGNORE OMDb_Actors ( movie_id,movie_name, actors) VALUES (%s, %s, %s)"
cursor.executemany(insert_stmt, movie_list_actors)
cnx.commit()
time.sleep(0.1)

# %% [markdown]
# # Populating Table Directors

# %%
# Loop to Get response for all the urls & Parsing results with the keys I need for the Directors table

imdb_db_director = []

for x in urls:

    
        page1 = requests.get(x)
        data = page1.json()
        keys = ['imdbID', 'Title', 'Director']
        parsed_results = {key: (data[key] if key in data else 'Null') for key in keys}
        imdb_db_director.append(parsed_results)
        time.sleep(0.1)

# %%
imdb_db_director = imdb_db_director.copy()

# %%
imdb_db_director
# Out:
# [{'imdbID': 'tt0111161',
#   'Title': 'The Shawshank Redemption',
#   'Director': 'Frank Darabont'},
#  {'imdbID': 'tt0068646',
#   'Title': 'The Godfather',
#   'Director': 'Francis Ford Coppola'},
#  {'imdbID': 'tt0071562',
#   'Title': 'The Godfather: Part II',
#   'Director': 'Francis Ford Coppola'},
#  {'imdbID': 'tt0468569',
#   'Title': 'The Dark Knight',
#   'Director': 'Christopher Nolan'},
#  {'imdbID': 'tt0050083', 'Title': '12 Angry Men', 'Director': 'Sidney Lumet'},
#  {'imdbID': 'tt0108052',
#   'Title': "Schindler's List",
#   'Director': 'Steven Spielberg'},
#  {'imdbID': 'tt0167260',
#   'Title': 'The Lord of the Rings: The Return of the King',
#   'Director': 'Peter Jackson'},
#  {'imdbID': 'tt0110912',
#   'Title': 'Pulp Fiction',
#   'Director': 'Quentin Tarantino'},
#  {'imdbID': 'tt0060196',
#   'Title': 'The Good, the Bad and the Ugly',
#   'Director': 'Sergio Leone'},
#  {'imdbID': 'tt0137523', 'Title': 'Fight Club', 'Director': 'David Fincher'},
#  {'imdbID': 'tt0120737',
#   'Title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'Director': 'Peter Jackson'},
#  {'imdbID': 'tt0109830',
#   'Title': 'Forrest Gump',
#   'Director': 'Robert Zemeckis'},
#  {'imdbID': 'tt1375666',
#   'Title': 'Inception',
#   'Director': 'Christopher Nolan'},
#  {'imdbID': 'tt0080684',
#   'Title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'Director': 'Irvin Kershner'},
#  {'imdbID': 'tt7286456', 'Title': 'Joker', 'Director': 'Todd Phillips'},
#  {'imdbID': 'tt0167261',
#   'Title': 'The Lord of the Rings: The Two Towers',
#   'Director': 'Peter Jackson'},
#  {'imdbID': 'tt0133093',
#   'Title': 'The Matrix',
#   'Director': 'Lana Wachowski, Lilly Wachowski'},
#  {'imdbID': 'tt0073486',
#   'Title': "One Flew Over the Cuckoo's Nest",
#   'Director': 'Milos Forman'},
#  {'imdbID': 'tt0099685', 'Title': 'Goodfellas', 'Director': 'Martin Scorsese'},
#  {'imdbID': 'tt0047478',
#   'Title': 'Seven Samurai',
#   'Director': 'Akira Kurosawa'},
#  {'imdbID': 'tt0114369', 'Title': 'Se7en', 'Director': 'David Fincher'},
#  {'imdbID': 'tt0317248',
#   'Title': 'City of God',
#   'Director': 'Fernando Meirelles, Kátia Lund(co-director)'},
#  {'imdbID': 'tt0118799',
#   'Title': 'Life Is Beautiful',
#   'Director': 'Roberto Benigni'},
#  {'imdbID': 'tt0102926',
#   'Title': 'The Silence of the Lambs',
#   'Director': 'Jonathan Demme'},
#  {'imdbID': 'tt0038650',
#   'Title': "It's a Wonderful Life",
#   'Director': 'Frank Capra'},
#  {'imdbID': 'tt0076759',
#   'Title': 'Star Wars: Episode IV - A New Hope',
#   'Director': 'George Lucas'},
#  {'imdbID': 'tt0120815',
#   'Title': 'Saving Private Ryan',
#   'Director': 'Steven Spielberg'},
#  {'imdbID': 'tt0245429',
#   'Title': 'Spirited Away',
#   'Director': 'Hayao Miyazaki'},
#  {'imdbID': 'tt0120689',
#   'Title': 'The Green Mile',
#   'Director': 'Frank Darabont'},
#  {'imdbID': 'tt0110413',
#   'Title': 'Léon: The Professional',
#   'Director': 'Luc Besson'},
#  {'imdbID': 'tt0816692',
#   'Title': 'Interstellar',
#   'Director': 'Christopher Nolan'},
#  {'imdbID': 'tt0056058', 'Title': 'Harakiri', 'Director': 'Masaki Kobayashi'},
#  {'imdbID': 'tt0114814',
#   'Title': 'The Usual Suspects',
#   'Director': 'Bryan Singer'},
#  {'imdbID': 'tt0110357',
#   'Title': 'The Lion King',
#   'Director': 'Roger Allers, Rob Minkoff'},
#  {'imdbID': 'tt0120586',
#   'Title': 'American History X',
#   'Director': 'Tony Kaye'},
#  {'imdbID': 'tt0088763',
#   'Title': 'Back to the Future',
#   'Director': 'Robert Zemeckis'},
#  {'imdbID': 'tt0253474', 'Title': 'The Pianist', 'Director': 'Roman Polanski'},
#  {'imdbID': 'tt0027977',
#   'Title': 'Modern Times',
#   'Director': 'Charles Chaplin'},
#  {'imdbID': 'tt0103064',
#   'Title': 'Terminator 2: Judgment Day',
#   'Director': 'James Cameron'},
#  {'imdbID': 'tt0054215', 'Title': 'Psycho', 'Director': 'Alfred Hitchcock'},
#  {'imdbID': 'tt1675434',
#   'Title': 'The Intouchables',
#   'Director': 'Olivier Nakache, Éric Toledano'},
#  {'imdbID': 'tt0172495', 'Title': 'Gladiator', 'Director': 'Ridley Scott'},
#  {'imdbID': 'tt0021749',
#   'Title': 'City Lights',
#   'Director': 'Charles Chaplin'},
#  {'imdbID': 'tt0407887',
#   'Title': 'The Departed',
#   'Director': 'Martin Scorsese'},
#  {'imdbID': 'tt2582802', 'Title': 'Whiplash', 'Director': 'Damien Chazelle'},
#  {'imdbID': 'tt0064116',
#   'Title': 'Once Upon a Time in the West',
#   'Director': 'Sergio Leone'},
#  {'imdbID': 'tt0482571',
#   'Title': 'The Prestige',
#   'Director': 'Christopher Nolan'},
#  {'imdbID': 'tt0034583', 'Title': 'Casablanca', 'Director': 'Michael Curtiz'},
#  {'imdbID': 'tt0095327',
#   'Title': 'Grave of the Fireflies',
#   'Director': 'Isao Takahata'},
#  {'imdbID': 'tt4154796',
#   'Title': 'Avengers: Endgame',
#   'Director': 'Anthony Russo, Joe Russo'},
#  {'imdbID': 'tt0047396',
#   'Title': 'Rear Window',
#   'Director': 'Alfred Hitchcock'},
#  {'imdbID': 'tt6751668', 'Title': 'Parasite', 'Director': 'Bong Joon Ho'},
#  {'imdbID': 'tt0095765',
#   'Title': 'Cinema Paradiso',
#   'Director': 'Giuseppe Tornatore'},
#  {'imdbID': 'tt0078748', 'Title': 'Alien', 'Director': 'Ridley Scott'},
#  {'imdbID': 'tt0082971',
#   'Title': 'Raiders of the Lost Ark',
#   'Director': 'Steven Spielberg'},
#  {'imdbID': 'tt0209144', 'Title': 'Memento', 'Director': 'Christopher Nolan'},
#  {'imdbID': 'tt0078788',
#   'Title': 'Apocalypse Now',
#   'Director': 'Francis Ford Coppola, Francis Ford Coppola'},
#  {'imdbID': 'tt0032553',
#   'Title': 'The Great Dictator',
#   'Director': 'Charles Chaplin'},
#  {'imdbID': 'tt0405094',
#   'Title': 'The Lives of Others',
#   'Director': 'Florian Henckel von Donnersmarck'},
#  {'imdbID': 'tt1853728',
#   'Title': 'Django Unchained',
#   'Director': 'Quentin Tarantino'},
#  {'imdbID': 'tt4154756',
#   'Title': 'Avengers: Infinity War',
#   'Director': 'Anthony Russo, Joe Russo'},
#  {'imdbID': 'tt0081505',
#   'Title': 'The Shining',
#   'Director': 'Stanley Kubrick'},
#  {'imdbID': 'tt4633694',
#   'Title': 'Spider-Man: Into the Spider-Verse',
#   'Director': 'Bob Persichetti, Peter Ramsey, Rodney Rothman'},
#  {'imdbID': 'tt0050825',
#   'Title': 'Paths of Glory',
#   'Director': 'Stanley Kubrick'},
#  {'imdbID': 'tt0910970', 'Title': 'WALL·E', 'Director': 'Andrew Stanton'},
#  {'imdbID': 'tt0119698',
#   'Title': 'Princess Mononoke',
#   'Director': 'Hayao Miyazaki'},
#  {'imdbID': 'tt0043014', 'Title': 'Sunset Blvd.', 'Director': 'Billy Wilder'},
#  {'imdbID': 'tt0057012',
#   'Title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'Director': 'Stanley Kubrick'},
#  {'imdbID': 'tt0364569', 'Title': 'Oldboy', 'Director': 'Chan-wook Park'},
#  {'imdbID': 'tt0051201',
#   'Title': 'Witness for the Prosecution',
#   'Director': 'Billy Wilder'},
#  {'imdbID': 'tt1345836',
#   'Title': 'The Dark Knight Rises',
#   'Director': 'Christopher Nolan'},
#  {'imdbID': 'tt0087843',
#   'Title': 'Once Upon a Time in America',
#   'Director': 'Sergio Leone'},
#  {'imdbID': 'tt0090605', 'Title': 'Aliens', 'Director': 'James Cameron'},
#  {'imdbID': 'tt0169547', 'Title': 'American Beauty', 'Director': 'Sam Mendes'},
#  {'imdbID': 'tt5311514', 'Title': 'Your Name.', 'Director': 'Makoto Shinkai'},
#  {'imdbID': 'tt2380307',
#   'Title': 'Coco',
#   'Director': 'Lee Unkrich, Adrian Molina(co-director)'},
#  {'imdbID': 'tt0112573', 'Title': 'Braveheart', 'Director': 'Mel Gibson'},
#  {'imdbID': 'tt0082096', 'Title': 'Das Boot', 'Director': 'Wolfgang Petersen'},
#  {'imdbID': 'tt1187043', 'Title': '3 Idiots', 'Director': 'Rajkumar Hirani'},
#  {'imdbID': 'tt0986264',
#   'Title': 'Like Stars on Earth',
#   'Director': 'Aamir Khan, Amole Gupte'},
#  {'imdbID': 'tt0086190',
#   'Title': 'Star Wars: Episode VI - Return of the Jedi',
#   'Director': 'Richard Marquand'},
#  {'imdbID': 'tt0114709', 'Title': 'Toy Story', 'Director': 'John Lasseter'},
#  {'imdbID': 'tt0105236',
#   'Title': 'Reservoir Dogs',
#   'Director': 'Quentin Tarantino'},
#  {'imdbID': 'tt0086879', 'Title': 'Amadeus', 'Director': 'Milos Forman'},
#  {'imdbID': 'tt5074352', 'Title': 'Dangal', 'Director': 'Nitesh Tiwari'},
#  {'imdbID': 'tt0361748',
#   'Title': 'Inglourious Basterds',
#   'Director': 'Quentin Tarantino'},
#  {'imdbID': 'tt0119217',
#   'Title': 'Good Will Hunting',
#   'Director': 'Gus Van Sant'},
#  {'imdbID': 'tt0022100', 'Title': 'M', 'Director': 'Fritz Lang'},
#  {'imdbID': 'tt0180093',
#   'Title': 'Requiem for a Dream',
#   'Director': 'Darren Aronofsky'},
#  {'imdbID': 'tt0062622',
#   'Title': '2001: A Space Odyssey',
#   'Director': 'Stanley Kubrick'},
#  {'imdbID': 'tt0052357', 'Title': 'Vertigo', 'Director': 'Alfred Hitchcock'},
#  {'imdbID': 'tt0338013',
#   'Title': 'Eternal Sunshine of the Spotless Mind',
#   'Director': 'Michel Gondry'},
#  {'imdbID': 'tt0033467', 'Title': 'Citizen Kane', 'Director': 'Orson Welles'},
#  {'imdbID': 'tt2106476', 'Title': 'The Hunt', 'Director': 'Thomas Vinterberg'},
#  {'imdbID': 'tt0093058',
#   'Title': 'Full Metal Jacket',
#   'Director': 'Stanley Kubrick'},
#  {'imdbID': 'tt0053125',
#   'Title': 'North by Northwest',
#   'Director': 'Alfred Hitchcock'},
#  {'imdbID': 'tt0066921',
#   'Title': 'A Clockwork Orange',
#   'Director': 'Stanley Kubrick'},
#  {'imdbID': 'tt0208092', 'Title': 'Snatch', 'Director': 'Guy Ritchie'},
#  {'imdbID': 'tt0012349', 'Title': 'The Kid', 'Director': 'Charles Chaplin'},
#  {'imdbID': 'tt0211915', 'Title': 'Amélie', 'Director': 'Jean-Pierre Jeunet'},
#  {'imdbID': 'tt0040522',
#   'Title': 'Bicycle Thieves',
#   'Director': 'Vittorio De Sica'},
#  {'imdbID': 'tt0086250', 'Title': 'Scarface', 'Director': 'Brian De Palma'},
#  {'imdbID': 'tt0045152',
#   'Title': "Singin' in the Rain",
#   'Director': 'Stanley Donen, Gene Kelly'},
#  {'imdbID': 'tt0056172',
#   'Title': 'Lawrence of Arabia',
#   'Director': 'David Lean'},
#  {'imdbID': 'tt0075314',
#   'Title': 'Taxi Driver',
#   'Director': 'Martin Scorsese'},
#  {'imdbID': 'tt0435761', 'Title': 'Toy Story 3', 'Director': 'Lee Unkrich'},
#  {'imdbID': 'tt0070735', 'Title': 'The Sting', 'Director': 'George Roy Hill'},
#  {'imdbID': 'tt0017136', 'Title': 'Metropolis', 'Director': 'Fritz Lang'},
#  {'imdbID': 'tt0059578',
#   'Title': 'For a Few Dollars More',
#   'Director': 'Sergio Leone'},
#  {'imdbID': 'tt0044741', 'Title': 'Ikiru', 'Director': 'Akira Kurosawa'},
#  {'imdbID': 'tt1832382',
#   'Title': 'A Separation',
#   'Director': 'Asghar Farhadi'},
#  {'imdbID': 'tt0036775',
#   'Title': 'Double Indemnity',
#   'Director': 'Billy Wilder'},
#  {'imdbID': 'tt0056592',
#   'Title': 'To Kill a Mockingbird',
#   'Director': 'Robert Mulligan'},
#  {'imdbID': 'tt8267604', 'Title': 'Capernaum', 'Director': 'Nadine Labaki'},
#  {'imdbID': 'tt0097576',
#   'Title': 'Indiana Jones and the Last Crusade',
#   'Director': 'Steven Spielberg'},
#  {'imdbID': 'tt0053604', 'Title': 'The Apartment', 'Director': 'Billy Wilder'},
#  {'imdbID': 'tt1049413',
#   'Title': 'Up',
#   'Director': 'Pete Docter, Bob Peterson(co-director)'},
#  {'imdbID': 'tt0119488',
#   'Title': 'L.A. Confidential',
#   'Director': 'Curtis Hanson'},
#  {'imdbID': 'tt0071853',
#   'Title': 'Monty Python and the Holy Grail',
#   'Director': 'Terry Gilliam, Terry Jones'},
#  {'imdbID': 'tt1255953', 'Title': 'Incendies', 'Director': 'Denis Villeneuve'},
#  {'imdbID': 'tt0113277', 'Title': 'Heat', 'Director': 'Michael Mann'},
#  {'imdbID': 'tt0042876', 'Title': 'Rashomon', 'Director': 'Akira Kurosawa'},
#  {'imdbID': 'tt0055630', 'Title': 'Yojimbo', 'Director': 'Akira Kurosawa'},
#  {'imdbID': 'tt0372784',
#   'Title': 'Batman Begins',
#   'Director': 'Christopher Nolan'},
#  {'imdbID': 'tt0095016', 'Title': 'Die Hard', 'Director': 'John McTiernan'},
#  {'imdbID': 'tt0105695', 'Title': 'Unforgiven', 'Director': 'Clint Eastwood'},
#  {'imdbID': 'tt6966692', 'Title': 'Green Book', 'Director': 'Peter Farrelly'},
#  {'imdbID': 'tt0363163',
#   'Title': 'Downfall',
#   'Director': 'Oliver Hirschbiegel'},
#  {'imdbID': 'tt0118849',
#   'Title': 'Children of Heaven',
#   'Director': 'Majid Majidi'},
#  {'imdbID': 'tt0053291',
#   'Title': 'Some Like It Hot',
#   'Director': 'Billy Wilder'},
#  {'imdbID': 'tt0347149',
#   'Title': "Howl's Moving Castle",
#   'Director': 'Hayao Miyazaki'},
#  {'imdbID': 'tt0057115',
#   'Title': 'The Great Escape',
#   'Director': 'John Sturges'},
#  {'imdbID': 'tt0096283',
#   'Title': 'My Neighbor Totoro',
#   'Director': 'Hayao Miyazaki'},
#  {'imdbID': 'tt0089881', 'Title': 'Ran', 'Director': 'Akira Kurosawa'},
#  {'imdbID': 'tt0268978',
#   'Title': 'A Beautiful Mind',
#   'Director': 'Ron Howard'},
#  {'imdbID': 'tt0042192',
#   'Title': 'All About Eve',
#   'Director': 'Joseph L. Mankiewicz'},
#  {'imdbID': 'tt0457430',
#   'Title': "Pan's Labyrinth",
#   'Director': 'Guillermo del Toro'},
#  {'imdbID': 'tt0091251', 'Title': 'Come and See', 'Director': 'Elem Klimov'},
#  {'imdbID': 'tt0112641', 'Title': 'Casino', 'Director': 'Martin Scorsese'},
#  {'imdbID': 'tt1305806',
#   'Title': 'The Secret in Their Eyes',
#   'Director': 'Juan José Campanella'},
#  {'imdbID': 'tt0081398',
#   'Title': 'Raging Bull',
#   'Director': 'Martin Scorsese'},
#  {'imdbID': 'tt0120735',
#   'Title': 'Lock, Stock and Two Smoking Barrels',
#   'Director': 'Guy Ritchie'},
#  {'imdbID': 'tt3417422', 'Title': 'Drishyam', 'Director': 'Jeethu Joseph'},
#  {'imdbID': 'tt0040897',
#   'Title': 'The Treasure of the Sierra Madre',
#   'Director': 'John Huston'},
#  {'imdbID': 'tt0993846',
#   'Title': 'The Wolf of Wall Street',
#   'Director': 'Martin Scorsese'},
#  {'imdbID': 'tt0476735',
#   'Title': 'My Father and My Son',
#   'Director': 'Çagan Irmak'},
#  {'imdbID': 'tt0055031',
#   'Title': 'Judgment at Nuremberg',
#   'Director': 'Stanley Kramer'},
#  {'imdbID': 'tt5027774',
#   'Title': 'Three Billboards Outside Ebbing, Missouri',
#   'Director': 'Martin McDonagh'},
#  {'imdbID': 'tt0071315', 'Title': 'Chinatown', 'Director': 'Roman Polanski'},
#  {'imdbID': 'tt0015864',
#   'Title': 'The Gold Rush',
#   'Director': 'Charles Chaplin'},
#  {'imdbID': 'tt0046912',
#   'Title': 'Dial M for Murder',
#   'Director': 'Alfred Hitchcock'},
#  {'imdbID': 'tt0469494',
#   'Title': 'There Will Be Blood',
#   'Director': 'Paul Thomas Anderson'},
#  {'imdbID': 'tt2096673',
#   'Title': 'Inside Out',
#   'Director': 'Pete Docter, Ronnie Del Carmen(co-director)'},
#  {'imdbID': 'tt0434409',
#   'Title': 'V for Vendetta',
#   'Director': 'James McTeigue'},
#  {'imdbID': 'tt0050976',
#   'Title': 'The Seventh Seal',
#   'Director': 'Ingmar Bergman'},
#  {'imdbID': 'tt1291584', 'Title': 'Warrior', 'Director': "Gavin O'Connor"},
#  {'imdbID': 'tt3170832', 'Title': 'Room', 'Director': 'Lenny Abrahamson'},
#  {'imdbID': 'tt0477348',
#   'Title': 'No Country for Old Men',
#   'Director': 'Ethan Coen, Joel Coen'},
#  {'imdbID': 'tt0117951', 'Title': 'Trainspotting', 'Director': 'Danny Boyle'},
#  {'imdbID': 'tt0080678',
#   'Title': 'The Elephant Man',
#   'Director': 'David Lynch'},
#  {'imdbID': 'tt0167404',
#   'Title': 'The Sixth Sense',
#   'Director': 'M. Night Shyamalan'},
#  {'imdbID': 'tt1130884',
#   'Title': 'Shutter Island',
#   'Director': 'Martin Scorsese'},
#  {'imdbID': 'tt8108198', 'Title': 'Andhadhun', 'Director': 'Sriram Raghavan'},
#  {'imdbID': 'tt0084787', 'Title': 'The Thing', 'Director': 'John Carpenter'},
#  {'imdbID': 'tt0031381',
#   'Title': 'Gone with the Wind',
#   'Director': 'Victor Fleming, George Cukor, Sam Wood'},
#  {'imdbID': 'tt0050212',
#   'Title': 'The Bridge on the River Kwai',
#   'Director': 'David Lean'},
#  {'imdbID': 'tt0083658', 'Title': 'Blade Runner', 'Director': 'Ridley Scott'},
#  {'imdbID': 'tt0041959', 'Title': 'The Third Man', 'Director': 'Carol Reed'},
#  {'imdbID': 'tt0047296',
#   'Title': 'On the Waterfront',
#   'Director': 'Elia Kazan'},
#  {'imdbID': 'tt0107290',
#   'Title': 'Jurassic Park',
#   'Director': 'Steven Spielberg'},
#  {'imdbID': 'tt0050986',
#   'Title': 'Wild Strawberries',
#   'Director': 'Ingmar Bergman'},
#  {'imdbID': 'tt0266543',
#   'Title': 'Finding Nemo',
#   'Director': 'Andrew Stanton, Lee Unkrich(co-director)'},
#  {'imdbID': 'tt0116231', 'Title': 'The Bandit', 'Director': 'Yavuz Turgul'},
#  {'imdbID': 'tt1205489', 'Title': 'Gran Torino', 'Director': 'Clint Eastwood'},
#  {'imdbID': 'tt0116282',
#   'Title': 'Fargo',
#   'Director': 'Joel Coen, Ethan Coen'},
#  {'imdbID': 'tt0266697',
#   'Title': 'Kill Bill: Vol. 1',
#   'Director': 'Quentin Tarantino'},
#  {'imdbID': 'tt0077416',
#   'Title': 'The Deer Hunter',
#   'Director': 'Michael Cimino'},
#  {'imdbID': 'tt0079944', 'Title': 'Stalker', 'Director': 'Andrei Tarkovsky'},
#  {'imdbID': 'tt0120382', 'Title': 'The Truman Show', 'Director': 'Peter Weir'},
#  {'imdbID': 'tt0118715',
#   'Title': 'The Big Lebowski',
#   'Director': 'Joel Coen, Ethan Coen'},
#  {'imdbID': 'tt0046438', 'Title': 'Tokyo Story', 'Director': 'Yasujirô Ozu'},
#  {'imdbID': 'tt3011894', 'Title': 'Wild Tales', 'Director': 'Damián Szifron'},
#  {'imdbID': 'tt0978762', 'Title': 'Mary and Max', 'Director': 'Adam Elliot'},
#  {'imdbID': 'tt0107207',
#   'Title': 'In the Name of the Father',
#   'Director': 'Jim Sheridan'},
#  {'imdbID': 'tt2267998', 'Title': 'Gone Girl', 'Director': 'David Fincher'},
#  {'imdbID': 'tt2119532', 'Title': 'Hacksaw Ridge', 'Director': 'Mel Gibson'},
#  {'imdbID': 'tt0017925',
#   'Title': 'The General',
#   'Director': 'Clyde Bruckman, Buster Keaton'},
#  {'imdbID': 'tt0015324', 'Title': 'Sherlock Jr.', 'Director': 'Buster Keaton'},
#  {'imdbID': 'tt0892769',
#   'Title': 'How to Train Your Dragon',
#   'Director': 'Dean DeBlois, Chris Sanders'},
#  {'imdbID': 'tt0031679',
#   'Title': 'Mr. Smith Goes to Washington',
#   'Director': 'Frank Capra'},
#  {'imdbID': 'tt0353969',
#   'Title': 'Memories of Murder',
#   'Director': 'Bong Joon Ho'},
#  {'imdbID': 'tt2278388',
#   'Title': 'The Grand Budapest Hotel',
#   'Director': 'Wes Anderson'},
#  {'imdbID': 'tt0060827', 'Title': 'Persona', 'Director': 'Ingmar Bergman'},
#  {'imdbID': 'tt0112471',
#   'Title': 'Before Sunrise',
#   'Director': 'Richard Linklater'},
#  {'imdbID': 'tt0264464',
#   'Title': 'Catch Me If You Can',
#   'Director': 'Steven Spielberg'},
#  {'imdbID': 'tt0758758', 'Title': 'Into the Wild', 'Director': 'Sean Penn'},
#  {'imdbID': 'tt0061512',
#   'Title': 'Cool Hand Luke',
#   'Director': 'Stuart Rosenberg'},
#  {'imdbID': 'tt0046268',
#   'Title': 'The Wages of Fear',
#   'Director': 'Henri-Georges Clouzot'},
#  {'imdbID': 'tt2024544',
#   'Title': '12 Years a Slave',
#   'Director': 'Steve McQueen'},
#  {'imdbID': 'tt1392214', 'Title': 'Prisoners', 'Director': 'Denis Villeneuve'},
#  {'imdbID': 'tt0074958', 'Title': 'Network', 'Director': 'Sidney Lumet'},
#  {'imdbID': 'tt0040725',
#   'Title': 'The Red Shoes',
#   'Director': 'Michael Powell, Emeric Pressburger'},
#  {'imdbID': 'tt0079470',
#   'Title': "Monty Python's Life of Brian",
#   'Director': 'Terry Jones'},
#  {'imdbID': 'tt0092005', 'Title': 'Stand by Me', 'Director': 'Rob Reiner'},
#  {'imdbID': 'tt1392190',
#   'Title': 'Mad Max: Fury Road',
#   'Director': 'George Miller'},
#  {'imdbID': 'tt0019254',
#   'Title': 'The Passion of Joan of Arc',
#   'Director': 'Carl Theodor Dreyer'},
#  {'imdbID': 'tt0405508',
#   'Title': 'Rang De Basanti',
#   'Director': 'Rakeysh Omprakash Mehra'},
#  {'imdbID': 'tt0091763', 'Title': 'Platoon', 'Director': 'Oliver Stone'},
#  {'imdbID': 'tt0060107',
#   'Title': 'Andrei Rublev',
#   'Director': 'Andrei Tarkovsky'},
#  {'imdbID': 'tt0405159',
#   'Title': 'Million Dollar Baby',
#   'Director': 'Clint Eastwood'},
#  {'imdbID': 'tt1979320', 'Title': 'Rush', 'Director': 'Ron Howard'},
#  {'imdbID': 'tt1028532',
#   'Title': "Hachi: A Dog's Tale",
#   'Director': 'Lasse Hallström'},
#  {'imdbID': 'tt3315342', 'Title': 'Logan', 'Director': 'James Mangold'},
#  {'imdbID': 'tt0072684',
#   'Title': 'Barry Lyndon',
#   'Director': 'Stanley Kubrick'},
#  {'imdbID': 'tt0052618', 'Title': 'Ben-Hur', 'Director': 'William Wyler'},
#  {'imdbID': 'tt0087544',
#   'Title': 'Nausicaä of the Valley of the Wind',
#   'Director': 'Hayao Miyazaki'},
#  {'imdbID': 'tt0395169', 'Title': 'Hotel Rwanda', 'Director': 'Terry George'},
#  {'imdbID': 'tt0245712',
#   'Title': 'Amores Perros',
#   'Director': 'Alejandro G. Iñárritu'},
#  {'imdbID': 'tt1201607',
#   'Title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'Director': 'David Yates'},
#  {'imdbID': 'tt0053198',
#   'Title': 'The 400 Blows',
#   'Director': 'François Truffaut'},
#  {'imdbID': 'tt1895587', 'Title': 'Spotlight', 'Director': 'Tom McCarthy'},
#  {'imdbID': 'tt0097165',
#   'Title': 'Dead Poets Society',
#   'Director': 'Peter Weir'},
#  {'imdbID': 'tt0042041', 'Title': 'White Heat', 'Director': 'Raoul Walsh'},
#  {'imdbID': 'tt0043338',
#   'Title': 'Ace in the Hole',
#   'Director': 'Billy Wilder'},
#  {'imdbID': 'tt0032976', 'Title': 'Rebecca', 'Director': 'Alfred Hitchcock'},
#  {'imdbID': 'tt0075148', 'Title': 'Rocky', 'Director': 'John G. Avildsen'},
#  {'imdbID': 'tt0198781',
#   'Title': 'Monsters, Inc.',
#   'Director': 'Pete Docter, David Silverman(co-director), Lee Unkrich(co-director)'},
#  {'imdbID': 'tt0025316',
#   'Title': 'It Happened One Night',
#   'Director': 'Frank Capra'},
#  {'imdbID': 'tt0113247', 'Title': 'La Haine', 'Director': 'Mathieu Kassovitz'},
#  {'imdbID': 'tt4016934',
#   'Title': 'The Handmaiden',
#   'Director': 'Chan-wook Park'},
#  {'imdbID': 'tt1954470',
#   'Title': 'Gangs of Wasseypur',
#   'Director': 'Anurag Kashyap'},
#  {'imdbID': 'tt0169102',
#   'Title': 'Lagaan: Once Upon a Time in India',
#   'Director': 'Ashutosh Gowariker'},
#  {'imdbID': 'tt0093779',
#   'Title': 'The Princess Bride',
#   'Director': 'Rob Reiner'},
#  {'imdbID': 'tt2338151', 'Title': 'PK', 'Director': 'Rajkumar Hirani'},
#  {'imdbID': 'tt0374887',
#   'Title': 'Munna Bhai M.B.B.S.',
#   'Director': 'Rajkumar Hirani'},
#  {'imdbID': 'tt0064115',
#   'Title': 'Butch Cassidy and the Sundance Kid',
#   'Director': 'George Roy Hill'},
#  {'imdbID': 'tt0381681',
#   'Title': 'Before Sunset',
#   'Director': 'Richard Linklater'},
#  {'imdbID': 'tt1454029', 'Title': 'The Help', 'Director': 'Tate Taylor'},
#  {'imdbID': 'tt0094625', 'Title': 'Akira', 'Director': 'Katsuhiro Ôtomo'},
#  {'imdbID': 'tt0088247',
#   'Title': 'The Terminator',
#   'Director': 'James Cameron'},
#  {'imdbID': 'tt0118694',
#   'Title': 'In the Mood for Love',
#   'Director': 'Kar-Wai Wong'},
#  {'imdbID': 'tt0367110', 'Title': 'Swades', 'Director': 'Ashutosh Gowariker'},
#  {'imdbID': 'tt0087884', 'Title': 'Paris, Texas', 'Director': 'Wim Wenders'},
#  {'imdbID': 'tt0103639',
#   'Title': 'Aladdin',
#   'Director': 'Ron Clements, John Musker'},
#  {'imdbID': 'tt2015381',
#   'Title': 'Guardians of the Galaxy',
#   'Director': 'James Gunn'},
#  {'imdbID': 'tt0338564',
#   'Title': 'Infernal Affairs',
#   'Director': 'Andrew Lau, Alan Mak'},
#  {'imdbID': 'tt0058946',
#   'Title': 'The Battle of Algiers',
#   'Director': 'Gillo Pontecorvo'},
#  {'imdbID': 'tt0092067',
#   'Title': 'Castle in the Sky',
#   'Director': 'Hayao Miyazaki'},
#  {'imdbID': 'tt0120731',
#   'Title': 'The Legend of 1900',
#   'Director': 'Giuseppe Tornatore'},
#  {'imdbID': 'tt0050613',
#   'Title': 'Throne of Blood',
#   'Director': 'Akira Kurosawa'}]

# %%
# spliting the directors that are in a list of list into separate director names
for movie in imdb_db_director:
    movie['Director'] = movie['Director'].split(',')
    movie['Director'] = [i.strip() for i in movie['Director']]

# %%
# Making tuple list for Directors Table
movie_list_directors = []
for movie in imdb_db_director:
    
    for i , value in enumerate(movie['Director']):
        actor_tuple = (movie['imdbID'], movie['Title'],movie['Director'][i])
        movie_list_directors.append(actor_tuple)
            
movie_list_directors
# Out:
# [('tt0111161', 'The Shawshank Redemption', 'Frank Darabont'),
#  ('tt0068646', 'The Godfather', 'Francis Ford Coppola'),
#  ('tt0071562', 'The Godfather: Part II', 'Francis Ford Coppola'),
#  ('tt0468569', 'The Dark Knight', 'Christopher Nolan'),
#  ('tt0050083', '12 Angry Men', 'Sidney Lumet'),
#  ('tt0108052', "Schindler's List", 'Steven Spielberg'),
#  ('tt0167260',
#   'The Lord of the Rings: The Return of the King',
#   'Peter Jackson'),
#  ('tt0110912', 'Pulp Fiction', 'Quentin Tarantino'),
#  ('tt0060196', 'The Good, the Bad and the Ugly', 'Sergio Leone'),
#  ('tt0137523', 'Fight Club', 'David Fincher'),
#  ('tt0120737',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Peter Jackson'),
#  ('tt0109830', 'Forrest Gump', 'Robert Zemeckis'),
#  ('tt1375666', 'Inception', 'Christopher Nolan'),
#  ('tt0080684',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'Irvin Kershner'),
#  ('tt7286456', 'Joker', 'Todd Phillips'),
#  ('tt0167261', 'The Lord of the Rings: The Two Towers', 'Peter Jackson'),
#  ('tt0133093', 'The Matrix', 'Lana Wachowski'),
#  ('tt0133093', 'The Matrix', 'Lilly Wachowski'),
#  ('tt0073486', "One Flew Over the Cuckoo's Nest", 'Milos Forman'),
#  ('tt0099685', 'Goodfellas', 'Martin Scorsese'),
#  ('tt0047478', 'Seven Samurai', 'Akira Kurosawa'),
#  ('tt0114369', 'Se7en', 'David Fincher'),
#  ('tt0317248', 'City of God', 'Fernando Meirelles'),
#  ('tt0317248', 'City of God', 'Kátia Lund(co-director)'),
#  ('tt0118799', 'Life Is Beautiful', 'Roberto Benigni'),
#  ('tt0102926', 'The Silence of the Lambs', 'Jonathan Demme'),
#  ('tt0038650', "It's a Wonderful Life", 'Frank Capra'),
#  ('tt0076759', 'Star Wars: Episode IV - A New Hope', 'George Lucas'),
#  ('tt0120815', 'Saving Private Ryan', 'Steven Spielberg'),
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'Stanley Kubrick'),
#  ('tt0364569', 'Oldboy', 'Chan-wook Park'),
#  ('tt0051201', 'Witness for the Prosecution', 'Billy Wilder'),
#  ('tt1345836', 'The Dark Knight Rises', 'Christopher Nolan'),
#  ('tt0087843', 'Once Upon a Time in America', 'Sergio Leone'),
#  ('tt0090605', 'Aliens', 'James Cameron'),
#  ('tt0169547', 'American Beauty', 'Sam Mendes'),
#  ('tt5311514', 'Your Name.', 'Makoto Shinkai'),
#  ('tt2380307', 'Coco', 'Lee Unkrich'),
#  ('tt2380307', 'Coco', 'Adrian Molina(co-director)'),
#  ('tt0112573', 'Braveheart', 'Mel Gibson'),
#  ('tt0082096', 'Das Boot', 'Wolfgang Petersen'),
#  ('tt1187043', '3 Idiots', 'Rajkumar Hirani'),
#  ('tt0986264', 'Like Stars on Earth', 'Aamir Khan'),
#  ('tt0986264', 'Like Stars on Earth', 'Amole Gupte'),
#  ('tt0086190',
#   'Star Wars: Episode VI - Return of the Jedi',
#   'Richard Marquand'),
#  ('tt0114709', 'Toy Story', 'John Lasseter'),
#  ('tt0105236', 'Reservoir Dogs', 'Quentin Tarantino'),
#  ('tt0086879', 'Amadeus', 'Milos Forman'),
#  ('tt5074352', 'Dangal', 'Nitesh Tiwari'),
#  ('tt0361748', 'Inglourious Basterds', 'Quentin Tarantino'),
#  ('tt0119217', 'Good Will Hunting', 'Gus Van Sant'),
#  ('tt0022100', 'M', 'Fritz Lang'),
#  ('tt0180093', 'Requiem for a Dream', 'Darren Aronofsky'),
#  ('tt0062622', '2001: A Space Odyssey', 'Stanley Kubrick'),
#  ('tt0052357', 'Vertigo', 'Alfred Hitchcock'),
#  ('tt0338013', 'Eternal Sunshine of the Spotless Mind', 'Michel Gondry'),
#  ('tt0033467', 'Citizen Kane', 'Orson Welles'),
#  ('tt2106476', 'The Hunt', 'Thomas Vinterberg'),
#  ('tt0093058', 'Full Metal Jacket', 'Stanley Kubrick'),
#  ('tt0053125', 'North by Northwest', 'Alfred Hitchcock'),
#  ('tt0066921', 'A Clockwork Orange', 'Stanley Kubrick'),
#  ('tt0208092', 'Snatch', 'Guy Ritchie'),
#  ('tt0012349', 'The Kid', 'Charles Chaplin'),
#  ('tt0211915', 'Amélie', 'Jean-Pierre Jeunet'),
#  ('tt0040522', 'Bicycle Thieves', 'Vittorio De Sica'),
#  ('tt0086250', 'Scarface', 'Brian De Palma'),
#  ('tt0045152', "Singin' in the Rain", 'Stanley Donen'),
#  ('tt0045152', "Singin' in the Rain", 'Gene Kelly'),
#  ('tt0056172', 'Lawrence of Arabia', 'David Lean'),
#  ('tt0075314', 'Taxi Driver', 'Martin Scorsese'),
#  ('tt0435761', 'Toy Story 3', 'Lee Unkrich'),
#  ('tt0070735', 'The Sting', 'George Roy Hill'),
#  ('tt0017136', 'Metropolis', 'Fritz Lang'),
#  ('tt0059578', 'For a Few Dollars More', 'Sergio Leone'),
#  ('tt2096673', 'Inside Out', 'Ronnie Del Carmen(co-director)'),
#  ('tt0434409', 'V for Vendetta', 'James McTeigue'),
#  ('tt0050976', 'The Seventh Seal', 'Ingmar Bergman'),
#  ('tt1291584', 'Warrior', "Gavin O'Connor"),
#  ('tt3170832', 'Room', 'Lenny Abrahamson'),
#  ('tt0477348', 'No Country for Old Men', 'Ethan Coen'),
#  ('tt0477348', 'No Country for Old Men', 'Joel Coen'),
#  ('tt0117951', 'Trainspotting', 'Danny Boyle'),
#  ('tt0080678', 'The Elephant Man', 'David Lynch'),
#  ('tt0167404', 'The Sixth Sense', 'M. Night Shyamalan'),
#  ('tt1130884', 'Shutter Island', 'Martin Scorsese'),
#  ('tt8108198', 'Andhadhun', 'Sriram Raghavan'),
#  ('tt0084787', 'The Thing', 'John Carpenter'),
#  ('tt0031381', 'Gone with the Wind', 'Victor Fleming'),
#  ('tt0031381', 'Gone with the Wind', 'George Cukor'),
#  ('tt0031381', 'Gone with the Wind', 'Sam Wood'),
#  ('tt0050212', 'The Bridge on the River Kwai', 'David Lean'),
#  ('tt0083658', 'Blade Runner', 'Ridley Scott'),
#  ('tt0041959', 'The Third Man', 'Carol Reed'),
#  ('tt0047296', 'On the Waterfront', 'Elia Kazan'),
#  ('tt0107290', 'Jurassic Park', 'Steven Spielberg'),
#  ('tt0050986', 'Wild Strawberries', 'Ingmar Bergman'),
#  ('tt0266543', 'Finding Nemo', 'Andrew Stanton'),
#  ('tt0266543', 'Finding Nemo', 'Lee Unkrich(co-director)'),
#  ('tt0116231', 'The Bandit', 'Yavuz Turgul'),
#  ('tt1205489', 'Gran Torino', 'Clint Eastwood'),
#  ('tt0116282', 'Fargo', 'Joel Coen'),
#  ('tt0116282', 'Fargo', 'Ethan Coen'),
#  ('tt0266697', 'Kill Bill: Vol. 1', 'Quentin Tarantino'),
#  ('tt0077416', 'The Deer Hunter', 'Michael Cimino'),
#  ('tt0079944', 'Stalker', 'Andrei Tarkovsky'),
#  ('tt0120382', 'The Truman Show', 'Peter Weir'),
#  ('tt0118715', 'The Big Lebowski', 'Joel Coen'),
#  ('tt0118715', 'The Big Lebowski', 'Ethan Coen'),
#  ('tt0046438', 'Tokyo Story', 'Yasujirô Ozu'),
#  ('tt3011894', 'Wild Tales', 'Damián Szifron'),
#  ('tt0978762', 'Mary and Max', 'Adam Elliot'),
#  ('tt0107207', 'In the Name of the Father', 'Jim Sheridan'),
#  ('tt2267998', 'Gone Girl', 'David Fincher'),
#  ('tt2119532', 'Hacksaw Ridge', 'Mel Gibson'),
#  ('tt0017925', 'The General', 'Clyde Bruckman'),
#  ('tt0017925', 'The General', 'Buster Keaton'),
#  ('tt0015324', 'Sherlock Jr.', 'Buster Keaton'),
#  ('tt0892769', 'How to Train Your Dragon', 'Dean DeBlois'),
#  ('tt0892769', 'How to Train Your Dragon', 'Chris Sanders'),
#  ('tt0031679', 'Mr. Smith Goes to Washington', 'Frank Capra'),
#  ('tt0353969', 'Memories of Murder', 'Bong Joon Ho'),
#  ('tt2338151', 'PK', 'Rajkumar Hirani'),
#  ('tt0374887', 'Munna Bhai M.B.B.S.', 'Rajkumar Hirani'),
#  ('tt0064115', 'Butch Cassidy and the Sundance Kid', 'George Roy Hill'),
#  ('tt0381681', 'Before Sunset', 'Richard Linklater'),
#  ('tt1454029', 'The Help', 'Tate Taylor'),
#  ('tt0094625', 'Akira', 'Katsuhiro Ôtomo'),
#  ('tt0088247', 'The Terminator', 'James Cameron'),
#  ('tt0118694', 'In the Mood for Love', 'Kar-Wai Wong'),
#  ('tt0367110', 'Swades', 'Ashutosh Gowariker'),
#  ('tt0087884', 'Paris, Texas', 'Wim Wenders'),
#  ('tt0103639', 'Aladdin', 'Ron Clements'),
#  ('tt0103639', 'Aladdin', 'John Musker'),
#  ('tt2015381', 'Guardians of the Galaxy', 'James Gunn'),
#  ('tt0338564', 'Infernal Affairs', 'Andrew Lau'),
#  ('tt0338564', 'Infernal Affairs', 'Alan Mak'),
#  ('tt0058946', 'The Battle of Algiers', 'Gillo Pontecorvo'),
#  ('tt0092067', 'Castle in the Sky', 'Hayao Miyazaki'),
#  ('tt0120731', 'The Legend of 1900', 'Giuseppe Tornatore'),
#  ('tt0050613', 'Throne of Blood', 'Akira Kurosawa')]

# %%
# Inserting into table Directors
insert_stmt = "INSERT IGNORE INTO OMDb_Directors ( movie_id,movie_name, director) VALUES (%s, %s, %s)"
cursor.executemany(insert_stmt, movie_list_directors)
cnx.commit()
time.sleep(0.1)

# %% [markdown]
# # Making DataFrames

# %%
#connecting to MySQL database
cnx = mysql.connector.connect(
    host = config_project1.host,
    user = config_project1.user,
    passwd = config_project1.password,
    database = 'Movies'
)
cursor = cnx.cursor()


# cursor.execute(  """SELECT * 
#                     FROM Movies.OMDb_Top_250_and_Low_100 l
#                     INNER JOIN Movies.OMDb_Actors  a where a.movie_id = l.movie_id
#                     order by a.Actors;""")
                        
# df = pd.DataFrame(cursor.fetchall())

# df.columns=['imdbID', 'Title', 'Rated','imdbRating','imdbVotes', 'Metascore', 'Year', 'Runtime','imdbID', 'Title', 'Actors']

# %% [markdown]
# # Actors in 8 or higher IMDb Rating

# %%
#calling the joined tables of Movies and Actors tables(w/ freq count of actors, actor name, and the actors avg imdb rating)
cursor.execute(  """SELECT a.actors,count(a.actors), avg(imdb_rating)
                    FROM Movies.OMDb_Top_250_and_Low_100 l
                    INNER JOIN Movies.OMDb_Actors  a 
                    ON a.movie_id = l.movie_id and imdb_rating >=8
                    GROUP BY a.actors
                    HAVING count(a.actors)>1
                    ORDER BY count(a.actors) desc limit 30
                    ;""")
#assigning database (pointed in MySql) as a dataframe using pandas                         
df_rating_freq = pd.DataFrame(cursor.fetchall())


#assigning the column names 
df_rating_freq.columns=['Actors','Frequency','ImdbRating']

# %%
df_rating_freq
# Out:
#                 Actors  Frequency  ImdbRating
# 0       Robert De Niro          8    8.462500
# 1    Leonardo DiCaprio          6    8.350000
# 2        Harrison Ford          6    8.383333
# 3           Aamir Khan          6    8.283333
# 4            Tom Hanks          6    8.450000
# 5       Clint Eastwood          5    8.300000
# 6            Al Pacino          4    8.675000
# 7      Charles Chaplin          4    8.375000
# 8       Jack Nicholson          4    8.450000
# 9        James Stewart          4    8.375000
# 10           Tom Hardy          4    8.375000
# 11      Morgan Freeman          4    8.550000
# 12        Mark Ruffalo          4    8.300000
# 13      Christian Bale          4    8.525000
# 14           Brad Pitt          4    8.500000
# 15         Mark Hamill          4    8.400000
# 16       Ralph Fiennes          3    8.366667
# 17      Toshirô Mifune          3    8.333333
# 18        Hugh Jackman          3    8.233334
# 19         Paul Newman          3    8.133334
# 20  Gunnar Björnstrand          3    8.166667
# 21       Steve Buscemi          3    8.066667
# 22       Michael Caine          3    8.566667
# 23       Carrie Fisher          3    8.533333
# 24     Takashi Shimura          3    8.366667
# 25     Tatsuya Nakadai          3    8.366666
# 26        Jack Hawkins          3    8.166667
# 27      William Holden          3    8.200000
# 28       Robert Duvall          3    8.500000
# 29          Sean Astin          3    8.800000

# %%
# Graph of frequency of Actors with a  Avg IMDB Movie rating of 8 or Higher ***  W/ OVERLAYING BARS

plt.bar(df_rating_freq.Actors,df_rating_freq.ImdbRating, width= 0.90, label = 'Avg. Rating', color = 'red')
plt.bar(df_rating_freq.Actors, df_rating_freq['Frequency'],  width= 0.40, label= 'Frequency', color = 'cyan')
plt.legend(loc='upper center', bbox_to_anchor=(-0.22, 1.00), fancybox=True, shadow=True)
plt.title('Frequency of actors with multiple IMDB Rating of 8 or higher ranking movies')
plt.xticks(list(df_rating_freq.Actors), rotation = 90)
plt.yticks(np.arange(3,9,0.5))
plt.xlabel('Actors')   
plt.ylabel('Values')
plt.ylim(2.75,9)
# Out:
# (2.75, 9)

# %%
# summary of the DATAFRAME
df_rating_freq.describe()
# Out:
#        Frequency  ImdbRating
# count  30.000000   30.000000
# mean    3.966667    8.385139
# std     1.272612    0.160443
# min     3.000000    8.066667
# 25%     3.000000    8.300000
# 50%     4.000000    8.375000
# 75%     4.000000    8.490625
# max     8.000000    8.800000

# %% [markdown]
# # Actors in movies with a IMDb Rating of 4.5 or lower

# %%
cursor.execute(  """SELECT a.actors,count(a.actors), avg(imdb_rating)
                    FROM Movies.OMDb_Top_250_and_Low_100 l
                    INNER JOIN Movies.OMDb_Actors  a 
                    ON a.movie_id = l.movie_id 
                    WHERE imdb_rating <=4.5
                    GROUP BY a.actors
                    HAVING count(a.actors)>1
                    ORDER BY count(a.actors) desc
                    ;""")
                        
df_low_rating_freq = pd.DataFrame(cursor.fetchall())

df_low_rating_freq.columns=['Actors','Frequency','ImdbRating']

# %%
df_low_rating_freq
# Out:
#                    Actors  Frequency  ImdbRating
# 0           Stephen Dorff          3        3.00
# 1           Marlon Wayans          2        3.55
# 2            Nicolas Cage          2        3.40
# 3        Shaquille O'Neal          2        2.85
# 4             Chris Klein          2        3.40
# 5          Diedrich Bader          2        3.30
# 6            Skyler Shaye          2        2.45
# 7             Uma Thurman          2        3.75
# 8             Matt Lanter          2        2.65
# 9           Adam Campbell          2        2.60
# 10             Mike Myers          2        3.85
# 11  Arnold Schwarzenegger          2        3.50
# 12              Simon Rex          2        2.65
# 13             Robin Shou          2        3.70
# 14     Laurence R. Harvey          2        3.30
# 15           Paris Hilton          2        1.85
# 16           Adam Sandler          2        2.55
# 17               Udo Kier          2        3.25

# %%
#Graph of frequency of Actors with a IMDB Movie rating of 8 or Higher

plt.bar(df_low_rating_freq.Actors,df_low_rating_freq.ImdbRating, width= 0.75, label = 'Avg. Rating', color = 'navy')
plt.bar(df_low_rating_freq.Actors, df_low_rating_freq['Frequency'],  width= 0.25, label= 'Frequency', color = 'cyan')
plt.title('Frequency of actors in multiple 4.5 or lower ranking movies')
plt.legend(loc='upper center', bbox_to_anchor=(-0.22, 1.00), fancybox=True, shadow=True)
plt.xticks(list(df_low_rating_freq.Actors), rotation = 90)
plt.yticks(np.arange(0,5,0.5))
plt.xlabel('Actors')   
plt.ylabel('Values')
plt.ylim(1,4)
# Out:
# (1, 4)

# %% [markdown]
# # Avg revenue of top Actors

# %% [markdown]
# # """Not 100% finished"""

# %%
cursor.execute(  """SELECT l.actors, count(l.actors), avg(a.revenue)
                    FROM Movies.OMDb_Top_250_and_Low_100  m
                    INNER JOIN Movies.OMDb_Actors l ON m.movie_name = l.movie_name
                    INNER JOIN Movies.The_Movie_Db  a ON m.movie_name = a.movie_name
                    GROUP BY l.actors
                    ORDER BY avg(a.revenue) desc 
                    LIMIT 122
                    ;""")
                    ### had to limit 122 last 3 zero on revenue
    
df_rating_freq_all = pd.DataFrame(cursor.fetchall())

#naming the columns in new Dataframe
df_rating_freq_all.columns=['Actors', 'Frequency', 'Avg Revenue']

# %%
df_rating_freq_all
# Out:
#                    Actors  Frequency      Avg Revenue
# 0       Robert Downey Jr.          2  2096861642.0000
# 1             Chris Evans          2  2096861642.0000
# 2            Mark Ruffalo          2  2096861642.0000
# 3         Chris Hemsworth          2  2096861642.0000
# 4          Patrick Macnee          1  1519557910.0000
# 5            Sean Connery          1  1519557910.0000
# 6           Ralph Fiennes          2  1430778955.0000
# 7          Michael Gambon          1  1342000000.0000
# 8            Alan Rickman          1  1342000000.0000
# 9        Daniel Radcliffe          1  1342000000.0000
# 10         Rowan Atkinson          2  1318580267.0000
# 11      Matthew Broderick          2  1318580267.0000
# 12   Niketa Calame-Harris          2  1318580267.0000
# 13           Jim Cummings          2  1318580267.0000
# 14         Robin Williams          1  1047612394.0000
# 15           Linda Larkin          1  1047612394.0000
# 16       Jonathan Freeman          1  1047612394.0000
# 17          Scott Weinger          1  1047612394.0000
# 18           Heath Ledger          1  1004558444.0000
# 19          Aaron Eckhart          1  1004558444.0000
# 20   Joseph Gordon-Levitt          2   955235931.5000
# 21              Tom Hardy          2   955235931.5000
# 22          Albert Brooks          1   940335536.0000
# 23        Ellen DeGeneres          1   940335536.0000
# 24        Alexander Gould          1   940335536.0000
# 25           Willem Dafoe          1   940335536.0000
# 26           Noel Appleby          1   871368364.0000
# 27             Sean Astin          1   871368364.0000
# 28             Sala Baker          1   871368364.0000
# 29            Alan Howard          1   871368364.0000
# ..                    ...        ...              ...
# 92          Vivica A. Fox          1   180949045.0000
# 93          Edward Norton          1   100853753.0000
# 94              Brad Pitt          1   100853753.0000
# 95              Meat Loaf          1   100853753.0000
# 96           Zach Grenier          1   100853753.0000
# 97           Sun-kyun Lee          1    90156442.0000
# 98           Yeo-jeong Jo          1    90156442.0000
# 99           Woo-sik Choi          1    90156442.0000
# 100          Kang-ho Song          1    90156442.0000
# 101         Michael Biehn          1    78371200.0000
# 102         Paul Winfield          1    78371200.0000
# 103             Jean Reno          1    45284974.0000
# 104       Natalie Portman          1    45284974.0000
# 105          Danny Aiello          1    45284974.0000
# 106        Shelley Duvall          1    44781695.0000
# 107           Danny Lloyd          1    44781695.0000
# 108      Scatman Crothers          1    44781695.0000
# 109        Jack Nicholson          1    44781695.0000
# 110           Tim Robbins          1    28341469.0000
# 111        Morgan Freeman          1    28341469.0000
# 112            Bob Gunton          1    28341469.0000
# 113        William Sadler          1    28341469.0000
# 114         Patrick Magee          1    26589000.0000
# 115         Michael Bates          1    26589000.0000
# 116         Warren Clarke          1    26589000.0000
# 117      Malcolm McDowell          1    26589000.0000
# 118          Kevin McKidd          1    16491080.0000
# 119         Ewan McGregor          1    16491080.0000
# 120          Ewen Bremner          1    16491080.0000
# 121      Jonny Lee Miller          1    16491080.0000
#
# [122 rows x 3 columns]

# %%
# secondary_y = np.arange(0,5,0.5)

plt.bar(df_rating_freq_all.Actors, df_rating_freq_all['Avg Revenue'],  width= 0.8, label= 'Avg. Revenue', color = 'green')
plt.plot(df_rating_freq_all.Actors, df_rating_freq_all['Frequency'], label= 'Frequency', color = 'cyan') ### need second y axis
plt.title('Line plot of the Avg IMDb Rating')
plt.legend(loc='upper center', bbox_to_anchor=(-0.22, 1.00), fancybox=True, shadow=True)
plt.xticks(list(df_rating_freq_all.Actors), rotation = 90)
# plt.yticks(np.arange(0,5,0.5))
plt.xlabel('Actors')   
plt.ylabel('Avg Revenue (in millions)')
# plt.ylim(1,4)

plt.show()

# %%
plt.scatter(df_rating_freq_all.Actors, df_rating_freq_all['Frequency'], label= 'Frequency', s=10, c='red', alpha=1)
plt.title('Scatter plot of the Avg IMDb Rating')
plt.xlabel('Actors')
plt.ylabel('Avg Revenue (in millions)')
plt.xticks(list(df_rating_freq_all.Actors), rotation = 90)

# plt.figure(figsize=(5000,200))
plt.show()

# %%
fig, ax1 = plt.subplots(figsize = (30,10))

ax2 = ax1.twinx()

ax1.bar(df_rating_freq_all.Actors, df_rating_freq_all['Avg Revenue'], width = .85, label= 'Avg. Revenue', color = 'green')
ax2.bar(df_rating_freq_all.Actors, df_rating_freq_all['Frequency'], width = .2, label= 'Frequency', color = 'orange')




plt.title('Relationship of Actors and Avg Revenue in Movie They Featured')
plt.legend(loc='upper center', bbox_to_anchor=(-0.22, 1.00), fancybox=True, shadow=True)
plt.xticks(list(df_rating_freq_all.Actors), rotation = 90)

# plt.yticks(np.arange(0,5,0.5))
plt.xlabel('Actors')   
plt.ylabel('Avg Revenue (in millions)')
# plt.ylim(1,4)

plt.show()
